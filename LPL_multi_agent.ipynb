# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2044 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1510        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011675965 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00488     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 0.00911     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 1467         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0074835597 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.776       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0185      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00866     |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0065413946 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00643      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00837     |
# |    value_loss           | 0.00792      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.38        |
# | time/                   |             |
# |    fps                  | 1428        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007316229 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 3.38         |
# | time/                   |              |
# |    fps                  | 1429         |
# |    iterations           | 6            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0076769846 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00785     |
# |    value_loss           | 0.00739      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 4.18       |
# | time/                   |            |
# |    fps                  | 1379       |
# |    iterations           | 7          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00846958 |
# |    clip_fraction        | 0.091      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.424      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00246   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0119    |
# |    value_loss           | 0.00848    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 4.18        |
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008240707 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00679    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.006       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 4.18         |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 9            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0041054916 |
# |    clip_fraction        | 0.0838       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0242       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.025       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00852     |
# |    value_loss           | 0.00603      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.02        |
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008127839 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | -0.0653     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.02        |
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006997763 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0098     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0085     |
# |    value_loss           | 0.00709     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 9.93       |
# | time/                   |            |
# |    fps                  | 1305       |
# |    iterations           | 12         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01091681 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.97      |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0102     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0136    |
# |    value_loss           | 0.011      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 9.93        |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009502133 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00772     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010803026 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00348    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00925    |
# |    value_loss           | 0.00864     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 1313         |
# |    iterations           | 15           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0064897295 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0114       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00501     |
# |    value_loss           | 0.0102       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 16          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006841054 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00185     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 0.00803     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009464037 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0097     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012354851 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00734     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 0.00886     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 19          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016046315 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 1322        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007987212 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 0.0073      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008160876 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000374    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 0.00943     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 20.6       |
# | time/                   |            |
# |    fps                  | 1300       |
# |    iterations           | 22         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00900091 |
# |    clip_fraction        | 0.0939     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.848     |
# |    explained_variance   | 0.0303     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.027     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00844   |
# |    value_loss           | 0.0112     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 20.6       |
# | time/                   |            |
# |    fps                  | 1305       |
# |    iterations           | 23         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00924723 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.787     |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0109    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00418   |
# |    value_loss           | 0.00731    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 22.4        |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 24          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009454692 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 22.4        |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 25          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013611121 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00628    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 0.00768     |
# -----------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 30.661636037346398
# Cumulative Return: 0.0030661636037346398
# Win Rate: 0.7393526405451448
# Profit Factor: 11.965030983084887
# Sharpe Ratio: 0.6198733913000698
# Sortino Ratio: 2.06968293469031
# Maximum Drawdown: 0.1871856440463482
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1550 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010026263 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009423854 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00426     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00863    |
# |    value_loss           | 0.0166      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 3.02         |
# | time/                   |              |
# |    fps                  | 1198         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0053631747 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000732     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00853     |
# |    value_loss           | 0.0076       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.75        |
# | time/                   |             |
# |    fps                  | 1226        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009639824 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.75        |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006170739 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00923    |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 4.35        |
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009546319 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 4.35       |
# | time/                   |            |
# |    fps                  | 1249       |
# |    iterations           | 8          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00858139 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | -0.0411    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0343    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.015     |
# |    value_loss           | 0.00971    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 4.35       |
# | time/                   |            |
# |    fps                  | 1262       |
# |    iterations           | 9          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00819069 |
# |    clip_fraction        | 0.0742     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.101      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00672    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00859   |
# |    value_loss           | 0.00749    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.81        |
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009162366 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.0297      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0297     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.81        |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011865614 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00479    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 0.00605     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007224608 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 1251        |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010287837 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00652     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 1259        |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007610128 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 0.00744     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 15          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006886778 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.0105      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00062    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00936     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 1272         |
# |    iterations           | 16           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0073428154 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.934       |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0162       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 0.00713      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.2        |
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 17          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015569208 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 0.00875     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.2        |
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011173777 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.042       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007857681 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00147    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 20          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009354688 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00364     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00846    |
# |    value_loss           | 0.00781     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21          |
# | time/                   |             |
# |    fps                  | 1250        |
# |    iterations           | 21          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008346224 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00403     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 0.00801     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21          |
# | time/                   |             |
# |    fps                  | 1253        |
# |    iterations           | 22          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009930012 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.0467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 0.00937     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21          |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 23          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012092501 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00599     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 0.00745     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 22.6        |
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 24          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011780326 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00932     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 22.6        |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 25          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008402556 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.0092      |
# -----------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 28.14823440354121
# Cumulative Return: 0.002814823440354121
# Win Rate: 0.7079303675048356
# Profit Factor: 10.568926814512901
# Sharpe Ratio: 0.5756309932536235
# Sortino Ratio: 2.2713294427939053
# Maximum Drawdown: 0.20840032924849816
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1950 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1652        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008915354 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 1.73        |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007069192 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00244    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00815    |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 1470         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0053428686 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00231     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00742     |
# |    value_loss           | 0.00844      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 3.15         |
# | time/                   |              |
# |    fps                  | 1437         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0100163445 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.014       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.00883      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.15        |
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007786347 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 0.00637     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# |    fps                  | 1305        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009324288 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0341     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00978     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009143522 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.0063      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 5.82         |
# | time/                   |              |
# |    fps                  | 1317         |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0073962826 |
# |    clip_fraction        | 0.0866       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0281      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 0.0086       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 5.82        |
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008358063 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 0.00833     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 9.08        |
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008037133 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00904     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 9.08        |
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012443112 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00174    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 0.00816     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 9.08         |
# | time/                   |              |
# |    fps                  | 1317         |
# |    iterations           | 16           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0082289465 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00527      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00704     |
# |    value_loss           | 0.0062       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 1303        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010080358 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 0.0111      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 1277        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007368589 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00874     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.0082      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010626344 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00414    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00845    |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1275        |
# |    iterations           | 20          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010527717 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.052       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0092     |
# |    value_loss           | 0.00771     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 1281         |
# |    iterations           | 21           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0091030095 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.028       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00951     |
# |    value_loss           | 0.00836      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 22          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011654025 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00722     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 23          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008731764 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00973    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 0.00926     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 19.7         |
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 24           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0053783134 |
# |    clip_fraction        | 0.0812       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 19.7       |
# | time/                   |            |
# |    fps                  | 1294       |
# |    iterations           | 25         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01265149 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.809     |
# |    explained_variance   | 0.719      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00967   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00294   |
# |    value_loss           | 0.00931    |
# ----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 29.490098366233724
# Cumulative Return: 0.0029490098366233724
# Win Rate: 0.7072758037225042
# Profit Factor: 11.437865703061535
# Sharpe Ratio: 0.6141305885367764
# Sortino Ratio: 2.3196269225897326
# Maximum Drawdown: 0.18732613865033798
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 29.829584912248507
# Cumulative Return: 0.0029829584912248503
# Win Rate: 0.7276761794645393
# Profit Factor: 11.775190058467036
# Sharpe Ratio: 0.6166090932021807
# Sortino Ratio: 2.146241115929458
# Maximum Drawdown: 0.2082202313433183
# --- Agent 1 Testing Metrics ---
# Total Profit: 15.488312469746234
# Cumulative Return: 0.0015488312469746233
# Win Rate: 0.7112676056338029
# Profit Factor: 12.216306043546064
# Sharpe Ratio: 0.5954843466198841
# Sortino Ratio: 2.2673831923102146
# Maximum Drawdown: 0.1709351015184315
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 14.213979580063096
# Cumulative Return: 0.0014213979580063097
# Win Rate: 0.6809651474530831
# Profit Factor: 9.341936015831147
# Sharpe Ratio: 0.5775209116965766
# Sortino Ratio: 2.391268667197248
# Maximum Drawdown: 0.1311282970552341
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 15.924829204339403
# Cumulative Return: 0.0015924829204339403
# Win Rate: 0.7282608695652174
# Profit Factor: 14.81678924058342
# Sharpe Ratio: 0.6554693496055152
# Sortino Ratio: 3.2305319095771603
# Maximum Drawdown: 0.08429676239265105
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 16.14484375418033
# Cumulative Return: 0.0016144843754180328
# Win Rate: 0.720626631853786
# Profit Factor: 12.46582632121593
# Sharpe Ratio: 0.6642295817182032
# Sortino Ratio: 2.8920256945091944
# Maximum Drawdown: 0.16859352478530254
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 15.482799159441877
# Cumulative Return: 0.0015482799159441877
# Win Rate: 0.7112093566255203
# Profit Factor: 12.300659005042121
# Sharpe Ratio: 0.6254143682580359
# Sortino Ratio: 2.7157985912523026
# Maximum Drawdown: 0.13830652782925332

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 0.669    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1190     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000353 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1129     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58e-05 |
# |    n_updates        | 9530     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | -4.19    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1294     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000107 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | -2.58    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1201     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.95e-05 |
# |    n_updates        | 9530     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 6.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1121     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000393 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1093     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000205 |
# |    n_updates        | 9530     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 3.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1093     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000446 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 5.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1186     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000975 |
# |    n_updates        | 9530     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 3.4822401623412023
# Cumulative Return: 0.0003482240162341203
# Win Rate: 0.5372281275282118
# Profit Factor: 1.5625128433410267
# Sharpe Ratio: 0.13754769345791076
# Sortino Ratio: 0.25757908114327943
# Maximum Drawdown: 0.770768067218526
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 3.7942641174379776
# Cumulative Return: 0.0003794264117437978
# Win Rate: 0.544714851486559
# Profit Factor: 1.8419472026760504
# Sharpe Ratio: 0.17139263987399084
# Sortino Ratio: 0.3660959196306178
# Maximum Drawdown: 0.49752512631545165

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=100000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 904      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -148     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0464  |
# |    value_loss         | 0.00573  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 954       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -1.71e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.0148   |
# |    value_loss         | 0.00697   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 972       |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -2.25e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -0.0924   |
# |    value_loss         | 0.00876   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 975       |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -1.81e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.0629    |
# |    value_loss         | 0.0059    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 981       |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -5.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.0243    |
# |    value_loss         | 0.000974  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 981      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -701     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00784  |
# |    value_loss         | 0.00145  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 981      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -9.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.00853 |
# |    value_loss         | 0.000182 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 982      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -498     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.00361  |
# |    value_loss         | 0.000119 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 984      |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -409     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.000714 |
# |    value_loss         | 0.000157 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 987      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -2.8e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0178   |
# |    value_loss         | 0.001    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 990      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -324     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0207   |
# |    value_loss         | 0.000926 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 992      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.917   |
# |    explained_variance | -564     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00056  |
# |    value_loss         | 6.55e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 993      |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.603   |
# |    explained_variance | -432     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0134  |
# |    value_loss         | 0.000367 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 995      |
# |    iterations         | 1400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.706   |
# |    explained_variance | -85.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00723 |
# |    value_loss         | 9.65e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 997      |
# |    iterations         | 1500     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.812   |
# |    explained_variance | -15.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.00142 |
# |    value_loss         | 2.22e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 998       |
# |    iterations         | 1600      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -2.17e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0127   |
# |    value_loss         | 0.000286  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 999      |
# |    iterations         | 1700     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -69.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0138  |
# |    value_loss         | 0.000355 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 999       |
# |    iterations         | 1800      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -9.78e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -3.82e-06 |
# |    value_loss         | 1.44e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 997      |
# |    iterations         | 1900     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.973   |
# |    explained_variance | -191     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00377  |
# |    value_loss         | 4.55e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 992      |
# |    iterations         | 2000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -17      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00471  |
# |    value_loss         | 1.93e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 2100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -131     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00444 |
# |    value_loss         | 1.96e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 970       |
# |    iterations         | 2200      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -1.77e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.00498   |
# |    value_loss         | 6.36e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 967      |
# |    iterations         | 2300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -13      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.00167  |
# |    value_loss         | 3.78e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 957       |
# |    iterations         | 2400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -1.95e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -5.13e-05 |
# |    value_loss         | 3.55e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 945      |
# |    iterations         | 2500     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.95    |
# |    explained_variance | -3.73    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00126  |
# |    value_loss         | 1.63e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 946      |
# |    iterations         | 2600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.774   |
# |    explained_variance | -6.6     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000141 |
# |    value_loss         | 2.83e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 949      |
# |    iterations         | 2700     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.975   |
# |    explained_variance | -47.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.00295 |
# |    value_loss         | 1.77e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 951      |
# |    iterations         | 2800     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.918   |
# |    explained_variance | -95.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00191  |
# |    value_loss         | 4.38e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 952      |
# |    iterations         | 2900     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.908   |
# |    explained_variance | -20      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000445 |
# |    value_loss         | 1.38e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 943      |
# |    iterations         | 3000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.924   |
# |    explained_variance | -802     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00119  |
# |    value_loss         | 6.81e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 943       |
# |    iterations         | 3100      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.801    |
# |    explained_variance | -6.43     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -5.92e-05 |
# |    value_loss         | 1.52e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 942      |
# |    iterations         | 3200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.839   |
# |    explained_variance | -37.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00313  |
# |    value_loss         | 1.74e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 942      |
# |    iterations         | 3300     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -7.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00733  |
# |    value_loss         | 5.19e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 943      |
# |    iterations         | 3400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.956   |
# |    explained_variance | -53.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00123 |
# |    value_loss         | 2.89e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 944       |
# |    iterations         | 3500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.992    |
# |    explained_variance | -5.32     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -4.55e-05 |
# |    value_loss         | 3.77e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 944       |
# |    iterations         | 3600      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.872    |
# |    explained_variance | -267      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.000415 |
# |    value_loss         | 4.97e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 946       |
# |    iterations         | 3700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.985    |
# |    explained_variance | -17.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.000185 |
# |    value_loss         | 2.23e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 947      |
# |    iterations         | 3800     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -7.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00213  |
# |    value_loss         | 7.99e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 947       |
# |    iterations         | 3900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -290      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.000935 |
# |    value_loss         | 1.72e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 946       |
# |    iterations         | 4000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -66       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000695 |
# |    value_loss         | 2.21e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 946       |
# |    iterations         | 4100      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -117      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.000439 |
# |    value_loss         | 4.99e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 942      |
# |    iterations         | 4200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -24.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.00112  |
# |    value_loss         | 1.83e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 942      |
# |    iterations         | 4300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.85    |
# |    explained_variance | -60      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000125 |
# |    value_loss         | 2.11e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 943      |
# |    iterations         | 4400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | -7.01    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.00222  |
# |    value_loss         | 1.22e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 943       |
# |    iterations         | 4500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.833    |
# |    explained_variance | -9.7      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.000731 |
# |    value_loss         | 2.28e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 4600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -1.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00164 |
# |    value_loss         | 5.12e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 934       |
# |    iterations         | 4700      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.888    |
# |    explained_variance | -13.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -0.000961 |
# |    value_loss         | 3.15e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 4800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -66      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.00554 |
# |    value_loss         | 5.09e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 932      |
# |    iterations         | 4900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.97    |
# |    explained_variance | -8.91    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00265 |
# |    value_loss         | 6.34e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 932       |
# |    iterations         | 5000      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -3.97e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -0.00131  |
# |    value_loss         | 8.69e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 5100     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -20.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00124 |
# |    value_loss         | 5.61e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 5200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -46.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0058  |
# |    value_loss         | 2.8e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.974   |
# |    explained_variance | -7.08    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0017   |
# |    value_loss         | 2.45e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 5400      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -17.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000651 |
# |    value_loss         | 7.05e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 5500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.988   |
# |    explained_variance | -8.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.000163 |
# |    value_loss         | 2.33e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 5600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -6.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.00149  |
# |    value_loss         | 5.32e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 5700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.951   |
# |    explained_variance | -40.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.000574 |
# |    value_loss         | 9.41e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 5800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.884   |
# |    explained_variance | -40.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.00118  |
# |    value_loss         | 1.48e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5900     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.884   |
# |    explained_variance | -7.46    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00308  |
# |    value_loss         | 9.83e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6000     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.888   |
# |    explained_variance | -28.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.000919 |
# |    value_loss         | 5.4e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6100     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.857   |
# |    explained_variance | -661     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.00265 |
# |    value_loss         | 4.84e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 927       |
# |    iterations         | 6200      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.652    |
# |    explained_variance | -1.34e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 0.000165  |
# |    value_loss         | 1.48e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 928      |
# |    iterations         | 6300     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.848   |
# |    explained_variance | -53.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.00263 |
# |    value_loss         | 1.21e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 929      |
# |    iterations         | 6400     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.494   |
# |    explained_variance | -352     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.00015 |
# |    value_loss         | 1.08e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 929       |
# |    iterations         | 6500      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.501    |
# |    explained_variance | -0.919    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -2.93e-05 |
# |    value_loss         | 3.55e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 928      |
# |    iterations         | 6600     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | -53.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.00371  |
# |    value_loss         | 1.39e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 6700     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.298   |
# |    explained_variance | -103     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000525 |
# |    value_loss         | 7.98e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 6800      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.288    |
# |    explained_variance | -782      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0.000291 |
# |    value_loss         | 2.47e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 6900     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | -10.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.000401 |
# |    value_loss         | 7.64e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 918      |
# |    iterations         | 7000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.187   |
# |    explained_variance | -5.28    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 7.89e-06 |
# |    value_loss         | 2.49e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 913      |
# |    iterations         | 7100     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.122   |
# |    explained_variance | -1.99    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 9.89e-05 |
# |    value_loss         | 1.79e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 904       |
# |    iterations         | 7200      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.168    |
# |    explained_variance | -28.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -5.17e-06 |
# |    value_loss         | 1.74e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 896      |
# |    iterations         | 7300     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -21.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.000534 |
# |    value_loss         | 4.79e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 888       |
# |    iterations         | 7400      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.328    |
# |    explained_variance | -3.03     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -8.24e-05 |
# |    value_loss         | 2e-06     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 887      |
# |    iterations         | 7500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | -2.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 7.77e-05 |
# |    value_loss         | 2.59e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 7600     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | -113     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 1.57e-06 |
# |    value_loss         | 1.24e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 885       |
# |    iterations         | 7700      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.139    |
# |    explained_variance | -216      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -1.97e-05 |
# |    value_loss         | 2.22e-06  |
# -------------------------------------
# ------------------------------------
# ...
# | time/                 |           |
# |    fps                | 829       |
# |    iterations         | 17800     |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.0473   |
# |    explained_variance | -57       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -1.62e-06 |
# |    value_loss         | 1.51e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 830       |
# |    iterations         | 17900     |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.0127   |
# |    explained_variance | -571      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -1.74e-06 |
# |    value_loss         | 2.66e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 831      |
# |    iterations         | 18000    |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.0197  |
# |    explained_variance | -145     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 1.42e-06 |
# |    value_loss         | 4.07e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 831       |
# |    iterations         | 18100     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -0.00727  |
# |    explained_variance | -32.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | -2.45e-07 |
# |    value_loss         | 9.35e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 832      |
# |    iterations         | 18200    |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.0148  |
# |    explained_variance | -26.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | -2.4e-06 |
# |    value_loss         | 6.07e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 833       |
# |    iterations         | 18300     |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.00738  |
# |    explained_variance | -666      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -3.53e-07 |
# |    value_loss         | 1.09e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 834       |
# |    iterations         | 18400     |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.00876  |
# |    explained_variance | -14.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -6.17e-07 |
# |    value_loss         | 1.35e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 18500    |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -0.0113  |
# |    explained_variance | -111     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 3.38e-07 |
# |    value_loss         | 4.03e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 835       |
# |    iterations         | 18600     |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -0.00681  |
# |    explained_variance | -12.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | -7.75e-07 |
# |    value_loss         | 1.85e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 18700    |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.00804 |
# |    explained_variance | -24.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 5.76e-08 |
# |    value_loss         | 2.97e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 18800    |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.00674 |
# |    explained_variance | -11.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 1.87e-06 |
# |    value_loss         | 5.47e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 838       |
# |    iterations         | 18900     |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.00706  |
# |    explained_variance | -3.92e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | 3.98e-08  |
# |    value_loss         | 1.94e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 838       |
# |    iterations         | 19000     |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.00556  |
# |    explained_variance | -0.0848   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -7.51e-07 |
# |    value_loss         | 1.41e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 19100    |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.006   |
# |    explained_variance | -15.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 6.42e-07 |
# |    value_loss         | 1.36e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 840      |
# |    iterations         | 19200    |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.0338  |
# |    explained_variance | -6.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 1.48e-05 |
# |    value_loss         | 9.31e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 841       |
# |    iterations         | 19300     |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.0241   |
# |    explained_variance | -3.85e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | 1.22e-05  |
# |    value_loss         | 1.56e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 841      |
# |    iterations         | 19400    |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.0309  |
# |    explained_variance | -63.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 2.33e-05 |
# |    value_loss         | 3.53e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 842       |
# |    iterations         | 19500     |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.017    |
# |    explained_variance | -42.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -1.42e-06 |
# |    value_loss         | 7.51e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 843      |
# |    iterations         | 19600    |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.0112  |
# |    explained_variance | -95.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 2.82e-06 |
# |    value_loss         | 4.1e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 844       |
# |    iterations         | 19700     |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.0107   |
# |    explained_variance | -0.987    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -1.33e-06 |
# |    value_loss         | 9.03e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 844       |
# |    iterations         | 19800     |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.0131   |
# |    explained_variance | -6.39     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -2.75e-06 |
# |    value_loss         | 2.37e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -4.78    |
# | time/                 |          |
# |    fps                | 845      |
# |    iterations         | 19900    |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.0267  |
# |    explained_variance | -20.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 2.09e-06 |
# |    value_loss         | 7.38e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -4.78     |
# | time/                 |           |
# |    fps                | 846       |
# |    iterations         | 20000     |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.0116   |
# |    explained_variance | -8.29     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -3.17e-06 |
# |    value_loss         | 4.59e-06  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 34.591035953197206
# Cumulative Return: 0.0034591035953197204
# Win Rate: 0.7561374795417348
# Profit Factor: 12.352663613168984
# Sharpe Ratio: 0.6393828176129972
# Sortino Ratio: 3.1861916945840494
# Maximum Drawdown: 0.2201082129141447
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 9.352744331331632
# Cumulative Return: 0.0009352744331331631
# Win Rate: 0.7756755493979479
# Profit Factor: 16.09453386234789
# Sharpe Ratio: 0.715312007715559
# Sortino Ratio: 4.219003382766699
# Maximum Drawdown: 0.27362574100053616
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2093 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005869644 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.036       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009179682 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00397     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 1554        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008925153 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.0087      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 1498        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007640232 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008846923 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00585    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00922     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007768939 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00271    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00844     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 1467        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010252811 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00119     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00885     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 4.05       |
# | time/                   |            |
# |    fps                  | 1459       |
# |    iterations           | 9          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00661426 |
# |    clip_fraction        | 0.0657     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0102     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00748   |
# |    value_loss           | 0.00625    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.11        |
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008142577 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00593    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00825     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.78e+03  |
# |    ep_rew_mean          | 7.11      |
# | time/                   |           |
# |    fps                  | 1425      |
# |    iterations           | 11        |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0071454 |
# |    clip_fraction        | 0.0847    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | 0.838     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0126   |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.0106   |
# |    value_loss           | 0.00648   |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 1421         |
# |    iterations           | 12           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0076826317 |
# |    clip_fraction        | 0.0858       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00138     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 1417        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007674669 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 0.00806     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 12.9        |
# | time/                   |             |
# |    fps                  | 1408        |
# |    iterations           | 14          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009608377 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00905    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00776     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 12.9        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007996857 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 1401         |
# |    iterations           | 16           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0082386285 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 0.00624      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 17          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008970335 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00126     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00986    |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 1407        |
# |    iterations           | 18          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018733311 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 1391        |
# |    iterations           | 19          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007570173 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00663     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.01        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.78e+03  |
# |    ep_rew_mean          | 18        |
# | time/                   |           |
# |    fps                  | 1372      |
# |    iterations           | 20        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0080503 |
# |    clip_fraction        | 0.103     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.816    |
# |    explained_variance   | 0.567     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.045    |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.00747  |
# |    value_loss           | 0.00709   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 21          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014622018 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00847    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 0.00824     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007906135 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 0.00809     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 1344        |
# |    iterations           | 23          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006830737 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00664    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 0.0074      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 24          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010218516 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00422    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 25          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008201193 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 0.00978     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 3.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1299     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000219 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 2.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1267     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000268 |
# |    n_updates        | 9530     |
# ----------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.52     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0048  |
# |    value_loss         | 0.000363 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 903      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -39.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.106    |
# |    value_loss         | 0.0174   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 733      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.986   |
# |    explained_variance | -37.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0149  |
# |    value_loss         | 0.00166  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 610      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -11      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0185  |
# |    value_loss         | 0.00058  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 588      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.581   |
# |    explained_variance | -0.572   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0747   |
# |    value_loss         | 0.00717  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 585      |
# |    iterations         | 600      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -96.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0229   |
# |    value_loss         | 0.000859 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 573      |
# |    iterations         | 700      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | -9.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0158   |
# |    value_loss         | 0.000439 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 568      |
# |    iterations         | 800      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.498   |
# |    explained_variance | -4.1     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.106   |
# |    value_loss         | 0.00487  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 589      |
# |    iterations         | 900      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.275   |
# |    explained_variance | -258     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0132   |
# |    value_loss         | 0.000502 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 1.06      |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 1000      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.517    |
# |    explained_variance | -1.65e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.00102  |
# |    value_loss         | 8.83e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 624      |
# |    iterations         | 1100     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | -6.84    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.00112 |
# |    value_loss         | 3.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 1200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.407   |
# |    explained_variance | 0.0477   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.025    |
# |    value_loss         | 0.00181  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 1300     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.44    |
# |    explained_variance | -0.307   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.012    |
# |    value_loss         | 0.000314 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 1.06      |
# | time/                 |           |
# |    fps                | 616       |
# |    iterations         | 1400      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.279    |
# |    explained_variance | -29.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.000351 |
# |    value_loss         | 0.000321  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 1.06      |
# | time/                 |           |
# |    fps                | 606       |
# |    iterations         | 1500      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.3      |
# |    explained_variance | -95.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.000653 |
# |    value_loss         | 3.52e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 605      |
# |    iterations         | 1600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.336   |
# |    explained_variance | -548     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.0119   |
# |    value_loss         | 0.00782  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 604      |
# |    iterations         | 1700     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.363   |
# |    explained_variance | -61.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.000253 |
# |    value_loss         | 3.79e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 1800     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.873   |
# |    explained_variance | -303     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0741   |
# |    value_loss         | 0.00592  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 1.06     |
# | time/                 |          |
# |    fps                | 611      |
# |    iterations         | 1900     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | -0.511   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00219  |
# |    value_loss         | 1.05e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 0.162     |
# | time/                 |           |
# |    fps                | 619       |
# |    iterations         | 2000      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.153    |
# |    explained_variance | -24.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -1.35e-05 |
# |    value_loss         | 2.13e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 2100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.256   |
# |    explained_variance | -992     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.00072  |
# |    value_loss         | 0.000908 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 2200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.508   |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.00179 |
# |    value_loss         | 0.000115 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 2300     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.512   |
# |    explained_variance | 0.153    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.000185 |
# |    value_loss         | 2.05e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 2400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | -27.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00851  |
# |    value_loss         | 0.000143 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 628      |
# |    iterations         | 2500     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | 0.694    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.000353 |
# |    value_loss         | 6.15e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 0.162     |
# | time/                 |           |
# |    fps                | 626       |
# |    iterations         | 2600      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.466    |
# |    explained_variance | -68.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.000291 |
# |    value_loss         | 7.33e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 631      |
# |    iterations         | 2700     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.978   |
# |    explained_variance | -1.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0886  |
# |    value_loss         | 0.00936  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.162    |
# | time/                 |          |
# |    fps                | 636      |
# |    iterations         | 2800     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0464   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0166  |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 636      |
# |    iterations         | 2900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -0.0276  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0531   |
# |    value_loss         | 0.0035   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 3000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | -19      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00221  |
# |    value_loss         | 5.14e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 647      |
# |    iterations         | 3100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.428   |
# |    explained_variance | -0.329   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.0764   |
# |    value_loss         | 0.0145   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.525    |
# | time/                 |           |
# |    fps                | 653       |
# |    iterations         | 3200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.942    |
# |    explained_variance | -5.46e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -0.287    |
# |    value_loss         | 0.07      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 658      |
# |    iterations         | 3300     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.96    |
# |    explained_variance | 0.586    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00472  |
# |    value_loss         | 4.04e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 3400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | -8.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00304 |
# |    value_loss         | 1.31e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 669      |
# |    iterations         | 3500     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.273   |
# |    explained_variance | -0.271   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00191  |
# |    value_loss         | 2.9e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 3600     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -5.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00115 |
# |    value_loss         | 0.000121 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 678      |
# |    iterations         | 3700     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.846   |
# |    explained_variance | -29.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0439   |
# |    value_loss         | 0.00308  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.525   |
# | time/                 |          |
# |    fps                | 683      |
# |    iterations         | 3800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.707   |
# |    explained_variance | -0.354   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0017   |
# |    value_loss         | 5.04e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.0716  |
# | time/                 |          |
# |    fps                | 688      |
# |    iterations         | 3900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | -0.00926 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0739   |
# |    value_loss         | 0.00643  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.0716  |
# | time/                 |          |
# |    fps                | 692      |
# |    iterations         | 4000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | -0.772   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 4.79e-05 |
# |    value_loss         | 8.24e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.0716  |
# | time/                 |          |
# |    fps                | 695      |
# |    iterations         | 4100     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.261   |
# |    explained_variance | -0.112   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0202   |
# |    value_loss         | 0.000412 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.0716  |
# | time/                 |          |
# |    fps                | 700      |
# |    iterations         | 4200     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.0662   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00524 |
# ...
# |    n_updates          | 7599      |
# |    policy_loss        | 0.00968   |
# |    value_loss         | 0.00028   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.53     |
# | time/                 |           |
# |    fps                | 675       |
# |    iterations         | 7700      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.723    |
# |    explained_variance | -4.24e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | 0.00013   |
# |    value_loss         | 3.89e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 7800     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.694   |
# |    explained_variance | -4.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.000845 |
# |    value_loss         | 1.9e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.53     |
# | time/                 |           |
# |    fps                | 677       |
# |    iterations         | 7900      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -0.685    |
# |    explained_variance | -51.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -7.09e-05 |
# |    value_loss         | 5.02e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 8000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | -6.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -0.00273 |
# |    value_loss         | 2.89e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 8100     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.177   |
# |    explained_variance | -719     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.00235 |
# |    value_loss         | 7.11e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 8200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.127   |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 3.42e-06 |
# |    value_loss         | 3.45e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 678      |
# |    iterations         | 8300     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | -0.0191  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 6.57e-05 |
# |    value_loss         | 1.15e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 8400     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.176   |
# |    explained_variance | -41.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.000183 |
# |    value_loss         | 2.78e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 8500     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.812   |
# |    explained_variance | -42.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.00466  |
# |    value_loss         | 8.78e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.53    |
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 8600     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.0646  |
# |    explained_variance | -35.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | 6.72e-06 |
# |    value_loss         | 8.96e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.55     |
# | time/                 |           |
# |    fps                | 674       |
# |    iterations         | 8700      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.554    |
# |    explained_variance | -1.11e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000163 |
# |    value_loss         | 3.81e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.55    |
# | time/                 |          |
# |    fps                | 672      |
# |    iterations         | 8800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.564   |
# |    explained_variance | -55.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 0.00128  |
# |    value_loss         | 5.56e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.55     |
# | time/                 |           |
# |    fps                | 672       |
# |    iterations         | 8900      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.604    |
# |    explained_variance | 0.106     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.000836 |
# |    value_loss         | 8.43e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.55    |
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 9000     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.301   |
# |    explained_variance | -27      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 0.000255 |
# |    value_loss         | 1.19e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.55    |
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 9100     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -0.0544  |
# |    explained_variance | -4.51    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 6.29e-06 |
# |    value_loss         | 8.88e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.55    |
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 9200     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.0557  |
# |    explained_variance | -41.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 2.32e-06 |
# |    value_loss         | 6.61e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.55     |
# | time/                 |           |
# |    fps                | 676       |
# |    iterations         | 9300      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -0.056    |
# |    explained_variance | -2.49e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.08e-06  |
# |    value_loss         | 9.95e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.55     |
# | time/                 |           |
# |    fps                | 676       |
# |    iterations         | 9400      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -0.0453   |
# |    explained_variance | -157      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | -3.72e-05 |
# |    value_loss         | 4.09e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.55    |
# | time/                 |          |
# |    fps                | 678      |
# |    iterations         | 9500     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -0.0502  |
# |    explained_variance | -25.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | 2.33e-05 |
# |    value_loss         | 1.08e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.511    |
# | time/                 |           |
# |    fps                | 679       |
# |    iterations         | 9600      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.286    |
# |    explained_variance | -4.42     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | -7.43e-05 |
# |    value_loss         | 1.08e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.511   |
# | time/                 |          |
# |    fps                | 680      |
# |    iterations         | 9700     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | -0.379   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | 0.00201  |
# |    value_loss         | 5.85e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.511   |
# | time/                 |          |
# |    fps                | 681      |
# |    iterations         | 9800     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | -32.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 4.92e-05 |
# |    value_loss         | 1.06e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.511    |
# | time/                 |           |
# |    fps                | 682       |
# |    iterations         | 9900      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -0.274    |
# |    explained_variance | -3.65     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | -7.55e-05 |
# |    value_loss         | 2.35e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.511    |
# | time/                 |           |
# |    fps                | 682       |
# |    iterations         | 10000     |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -0.0199   |
# |    explained_variance | -3.94e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 0.000408  |
# |    value_loss         | 6.47e-06  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.8066060050243768
# Cumulative Return: 0.00018066060050243773
# Win Rate: 0.5145612478952688
# Profit Factor: 1.534556638470176
# Sharpe Ratio: 0.12712386459176406
# Sortino Ratio: 0.2320201804175825
# Maximum Drawdown: 0.85404043444748
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 11.348185273763502
# Cumulative Return: 0.0011348185273763502
# Win Rate: 0.6294836890652864
# Profit Factor: 5.117982886032262
# Sharpe Ratio: 0.4368287412070657
# Sortino Ratio: 1.643421101343359
# Maximum Drawdown: 0.26804201022790597
