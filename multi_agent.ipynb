# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'AAPL_TRAINING.csv'
    test_file = 'AAPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1901 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010690697 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -31         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00715    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 0.00909     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1489        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009339673 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -4.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.00826     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 1450        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006306541 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.255      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00698    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006430068 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0024      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 0.00278     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 1413        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008016726 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0169      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000897   |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 1379        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008873714 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.669      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00419     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007293091 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.0909     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.00201     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 1.03         |
# | time/                   |              |
# |    fps                  | 1371         |
# |    iterations           | 9            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0059502125 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00772     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 0.0023       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005696525 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0849      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00776     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007115298 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | -0.0917     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0313     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00398     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 2.59        |
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 12          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005899769 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00477    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 2.59        |
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 13          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010299347 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00441     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 2.59        |
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009442701 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0266     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.06e+03 |
# |    ep_rew_mean          | 2.59     |
# | time/                   |          |
# |    fps                  | 1342     |
# |    iterations           | 15       |
# |    time_elapsed         | 22       |
# |    total_timesteps      | 30720    |
# | train/                  |          |
# |    approx_kl            | 0.007877 |
# |    clip_fraction        | 0.098    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.942   |
# |    explained_variance   | -0.166   |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0142  |
# |    n_updates            | 140      |
# |    policy_gradient_loss | -0.0112  |
# |    value_loss           | 0.00331  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 4.71         |
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 16           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0056867786 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 0.0739       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00411     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00956     |
# |    value_loss           | 0.00181      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 4.71        |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009052293 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 0.00248     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 4.71         |
# | time/                   |              |
# |    fps                  | 1326         |
# |    iterations           | 18           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0100556575 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.529        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0211      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 4.71        |
# | time/                   |             |
# |    fps                  | 1327        |
# |    iterations           | 19          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012116373 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0283     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00399     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7.08         |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 20           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0073850956 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00955      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 0.00178      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7.08         |
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 21           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0074084997 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.341        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00488     |
# |    value_loss           | 0.00292      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 7.08        |
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 22          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008497221 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.003       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 7.08        |
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 23          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008173041 |
# |    clip_fraction        | 0.0645      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0312     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 0.00339     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 9.76         |
# | time/                   |              |
# |    fps                  | 1315         |
# |    iterations           | 24           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0072239153 |
# |    clip_fraction        | 0.0875       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.303        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0357       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 0.00149      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 9.76        |
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 25          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011670638 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00879    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 0.00446     |
# -----------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 6.6450791413699335
# Cumulative Return: 0.0006645079141369934
# Win Rate: 0.6155202821869489
# Profit Factor: 3.0022945228642723
# Sharpe Ratio: 0.31544780520587173
# Sortino Ratio: 0.588513223631336
# Maximum Drawdown: 0.18747499031839254
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1829 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1551        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008883713 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -13.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0278      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 0.00676     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006828581 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 0.00797     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.16       |
# | time/                   |             |
# |    fps                  | 1404        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009132082 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 0.00283     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.16       |
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011061808 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00969     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 0.00279     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.16       |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005168004 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.66       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00777     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -1.16        |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0065157358 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.578        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00704      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00789     |
# |    value_loss           | 0.00492      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.953       |
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005273252 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 0.953        |
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057247756 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00847     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 0.00211      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.953       |
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010679375 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00926    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.953       |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008559164 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | -0.186      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0304     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 1312         |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0052361013 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.988       |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0023       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008095218 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 1305         |
# |    iterations           | 14           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0059661753 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | -0.268       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0013       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00894     |
# |    value_loss           | 0.00169      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 1299        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008122459 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00146     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00451     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 16          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008465841 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0277     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008418083 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0177      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 0.00239     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 1299        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009217181 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.0336      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009227041 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 8.47        |
# | time/                   |             |
# |    fps                  | 1297        |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013116536 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00166    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06e+03   |
# |    ep_rew_mean          | 8.47       |
# | time/                   |            |
# |    fps                  | 1293       |
# |    iterations           | 21         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01034347 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.88      |
# |    explained_variance   | 0.733      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000478  |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00831   |
# |    value_loss           | 0.0027     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 8.47        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 22          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011573677 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.034      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00911    |
# |    value_loss           | 0.00301     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 8.47         |
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 23           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0072845886 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00937      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00881     |
# |    value_loss           | 0.00372      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 24          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006148795 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0016     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 0.00168     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 25          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010170038 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00632    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 0.00332     |
# -----------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 7.558197945227221
# Cumulative Return: 0.000755819794522722
# Win Rate: 0.6302895322939867
# Profit Factor: 3.738466732879697
# Sharpe Ratio: 0.3936607734355012
# Sortino Ratio: 0.8130232158749753
# Maximum Drawdown: 0.22485231273551842
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1824 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1548         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0107613355 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -15          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00442     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 0.00683      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010431262 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -3.6e-05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.19       |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007355922 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 0.00454     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -1.19        |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0030043318 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0126      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 0.00378      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.19       |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003319287 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -1.19       |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# ...
# |    fps                  | 1300        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009154338 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | -0.205      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 1.4          |
# | time/                   |              |
# |    fps                  | 1303         |
# |    iterations           | 11           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0066813794 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.312       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00832     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 0.0038       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 4.02        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 12          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007430659 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.0988      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0032     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 4.02        |
# | time/                   |             |
# |    fps                  | 1298        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008929463 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 4.02        |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007843744 |
# |    clip_fraction        | 0.084       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00316     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 4.02         |
# | time/                   |              |
# |    fps                  | 1296         |
# |    iterations           | 15           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0076047434 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | -0.0267      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0231      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.00347      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 6.51         |
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 16           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0075810817 |
# |    clip_fraction        | 0.0824       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0314      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00895     |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 6.51        |
# | time/                   |             |
# |    fps                  | 1293        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015860913 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00945    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 0.00302     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 6.51        |
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011912199 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000413    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 6.51        |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011001916 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0442     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.00388     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 9.54        |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008143669 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 9.54         |
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 21           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0075156176 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00767      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 0.00369      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 9.54        |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 22          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010797927 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0366     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00303     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 9.54         |
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 23           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0065567233 |
# |    clip_fraction        | 0.0674       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0145      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00696     |
# |    value_loss           | 0.00409      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06e+03   |
# |    ep_rew_mean          | 12.8       |
# | time/                   |            |
# |    fps                  | 1285       |
# |    iterations           | 24         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00732337 |
# |    clip_fraction        | 0.094      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | 0.348      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0114    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00446   |
# |    value_loss           | 0.00165    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 25          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008718032 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00849    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 0.00374     |
# -----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 9.64702229627801
# Cumulative Return: 0.0009647022296278009
# Win Rate: 0.6570327552986512
# Profit Factor: 5.10879135046187
# Sharpe Ratio: 0.4330131118578292
# Sortino Ratio: 1.3490184061928472
# Maximum Drawdown: 0.1393878236527244
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 8.55964785623463
# Cumulative Return: 0.0008559647856234631
# Win Rate: 0.6358496327560474
# Profit Factor: 4.196823090902751
# Sharpe Ratio: 0.3821426615651304
# Sortino Ratio: 1.011608327663824
# Maximum Drawdown: 0.1906081834247055
#
# --- Agent 1 Testing Metrics ---
# Total Profit: 27.616991397093443
# Cumulative Return: 0.002761699139709344
# Win Rate: 0.6988416988416989
# Profit Factor: 8.986765089185157
# Sharpe Ratio: 0.5582383872979765
# Sortino Ratio: 2.5221990071231817
# Maximum Drawdown: 0.10441162859014685
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 23.807878332574546
# Cumulative Return: 0.0023807878332574544
# Win Rate: 0.6982872200263505
# Profit Factor: 7.6375532767260905
# Sharpe Ratio: 0.5124610286118527
# Sortino Ratio: 1.936412521795653
# Maximum Drawdown: 0.19130795140702617
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 26.137917352916702
# Cumulative Return: 0.0026137917352916703
# Win Rate: 0.7295208655332303
# Profit Factor: 9.557957482442093
# Sharpe Ratio: 0.5878642445540805
# Sortino Ratio: 2.3569175658621884
# Maximum Drawdown: 0.13298028266693063
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 26.804322021598637
# Cumulative Return: 0.0026804322021598635
# Win Rate: 0.6972704714640199
# Profit Factor: 8.299508934938943
# Sharpe Ratio: 0.5282149211525075
# Sortino Ratio: 2.200277759004247
# Maximum Drawdown: 0.1271985312466306
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 26.13042990330981
# Cumulative Return: 0.0026130429903309807
# Win Rate: 0.7065796064485531
# Profit Factor: 8.658129236502472
# Sharpe Ratio: 0.5482227537486197
# Sortino Ratio: 2.262730853426239
# Maximum Drawdown: 0.1379595386651934

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'AAPL_TRAINING.csv'
    test_file = 'AAPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1222     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00013  |
# |    n_updates        | 8035     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1224     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.49e-05 |
# |    n_updates        | 8035     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | -5.21    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1239     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00042  |
# |    n_updates        | 8035     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | 0.235    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1219     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.32e-05 |
# |    n_updates        | 8035     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.2451243122847042
# Cumulative Return: 0.00012451243122847043
# Win Rate: 0.5180995604881522
# Profit Factor: 1.4882456553355718
# Sharpe Ratio: 0.1192488352091203
# Sortino Ratio: 0.23060523717830422
# Maximum Drawdown: 0.32672657054338633
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.0626485370993648
# Cumulative Return: 0.00010626485370993647
# Win Rate: 0.4975596978941629
# Profit Factor: 1.079143870555969
# Sharpe Ratio: 0.025581242624805413
# Sortino Ratio: 0.04044075980956406
# Maximum Drawdown: 1.7948851472980092

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'AAPL_TRAINING.csv'
    test_file = 'AAPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=100000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 1432     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.829   |
# |    explained_variance | -355     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0766  |
# |    value_loss         | 0.0289   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1567     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.9     |
# |    explained_variance | -735     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0407  |
# |    value_loss         | 0.00128  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1624      |
# |    iterations         | 300       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.834    |
# |    explained_variance | -5.33e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.0208    |
# |    value_loss         | 0.00102   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1653     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.744   |
# |    explained_variance | -29.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0125   |
# |    value_loss         | 0.00293  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1676     |
# |    iterations         | 500      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.567   |
# |    explained_variance | -165     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0301  |
# |    value_loss         | 0.00265  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1690      |
# |    iterations         | 600       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.617    |
# |    explained_variance | -1.62e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.0224   |
# |    value_loss         | 0.00212   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1699      |
# |    iterations         | 700       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.409    |
# |    explained_variance | -3.28e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.00389  |
# |    value_loss         | 0.00103   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1707      |
# |    iterations         | 800       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.461    |
# |    explained_variance | -6.35e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.0287   |
# |    value_loss         | 0.00221   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1711     |
# |    iterations         | 900      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.2     |
# |    explained_variance | -175     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.00026 |
# |    value_loss         | 0.000147 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1718     |
# |    iterations         | 1000     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.455   |
# |    explained_variance | -27.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.053   |
# |    value_loss         | 0.00206  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1723      |
# |    iterations         | 1100      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.269    |
# |    explained_variance | -112      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -0.000117 |
# |    value_loss         | 7.82e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1727      |
# |    iterations         | 1200      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.153    |
# |    explained_variance | -1.39e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.000876  |
# |    value_loss         | 0.000783  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1729     |
# |    iterations         | 1300     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.31    |
# |    explained_variance | -1.7e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.00128 |
# |    value_loss         | 0.000281 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1721      |
# |    iterations         | 1400      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.271    |
# |    explained_variance | -106      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.000361 |
# |    value_loss         | 0.000252  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1724     |
# |    iterations         | 1500     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.298   |
# |    explained_variance | -473     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00363  |
# |    value_loss         | 0.00011  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1727     |
# |    iterations         | 1600     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.155   |
# |    explained_variance | -83.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.026    |
# |    value_loss         | 0.000735 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1730     |
# |    iterations         | 1700     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | -103     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 5.77e-05 |
# |    value_loss         | 3.45e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1733     |
# |    iterations         | 1800     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.0973  |
# |    explained_variance | -85.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -5e-05   |
# |    value_loss         | 3.71e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1734     |
# |    iterations         | 1900     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.0809  |
# |    explained_variance | -11      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.000113 |
# |    value_loss         | 7.8e-05  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1735      |
# |    iterations         | 2000      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0855   |
# |    explained_variance | -152      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000203 |
# |    value_loss         | 0.000231  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1737      |
# |    iterations         | 2100      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.129    |
# |    explained_variance | -6.52e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.000143 |
# |    value_loss         | 5.58e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1739      |
# |    iterations         | 2200      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.071    |
# |    explained_variance | -75.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -8.21e-05 |
# |    value_loss         | 6.33e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1741      |
# |    iterations         | 2300      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.0426   |
# |    explained_variance | -4.26     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -1.71e-05 |
# |    value_loss         | 1.28e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1743      |
# |    iterations         | 2400      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.0503   |
# |    explained_variance | -1.23e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 6.09e-05  |
# |    value_loss         | 6.61e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1744      |
# |    iterations         | 2500      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.0271   |
# |    explained_variance | -1.06e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -1.81e-06 |
# |    value_loss         | 3.49e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1745      |
# |    iterations         | 2600      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.0175   |
# |    explained_variance | -54.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -1.96e-05 |
# |    value_loss         | 8.38e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1746      |
# |    iterations         | 2700      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.0152   |
# |    explained_variance | -1.74     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -5.99e-06 |
# |    value_loss         | 1.07e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1746     |
# |    iterations         | 2800     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.0154  |
# |    explained_variance | -779     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 1.33e-06 |
# |    value_loss         | 1.11e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1747      |
# |    iterations         | 2900      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.0121   |
# |    explained_variance | -109      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -3.97e-06 |
# |    value_loss         | 1.03e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1710      |
# |    iterations         | 3000      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00935  |
# |    explained_variance | -27.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -4.69e-06 |
# |    value_loss         | 1.88e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1712     |
# |    iterations         | 3100     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.00966 |
# |    explained_variance | -74.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 3.8e-06  |
# |    value_loss         | 1.99e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1714     |
# |    iterations         | 3200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.00601 |
# |    explained_variance | -281     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 3.15e-07 |
# |    value_loss         | 2.47e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1712      |
# |    iterations         | 3300      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.00686  |
# |    explained_variance | -88.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -1.89e-06 |
# |    value_loss         | 8.16e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1714     |
# |    iterations         | 3400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.0068  |
# |    explained_variance | -9.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 6.79e-07 |
# |    value_loss         | 1.94e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1716     |
# |    iterations         | 3500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.00616 |
# |    explained_variance | -54.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 3.87e-07 |
# |    value_loss         | 1.63e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1716      |
# |    iterations         | 3600      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.00616  |
# |    explained_variance | -0.983    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -6.69e-07 |
# |    value_loss         | 1.42e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1704     |
# |    iterations         | 3700     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.00619 |
# |    explained_variance | -33.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -4.7e-06 |
# |    value_loss         | 5.03e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1702      |
# |    iterations         | 3800      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.012    |
# |    explained_variance | -21.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -2.71e-06 |
# |    value_loss         | 8.94e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1701      |
# |    iterations         | 3900      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.0126   |
# |    explained_variance | -34       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -3.61e-06 |
# |    value_loss         | 6.74e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1699      |
# |    iterations         | 4000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0126   |
# |    explained_variance | -72       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.73e-06 |
# |    value_loss         | 3.44e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1694      |
# |    iterations         | 4100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0132   |
# |    explained_variance | -61.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -2.12e-06 |
# |    value_loss         | 3.35e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1691      |
# |    iterations         | 4200      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.0134   |
# |    explained_variance | -8.91     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -1.61e-06 |
# |    value_loss         | 4.93e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1686     |
# |    iterations         | 4300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.0133  |
# |    explained_variance | -7.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 1.16e-06 |
# |    value_loss         | 1.92e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1684     |
# |    iterations         | 4400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.00729 |
# |    explained_variance | -393     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 2.79e-06 |
# |    value_loss         | 1.38e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1684      |
# |    iterations         | 4500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.00798  |
# |    explained_variance | -49.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -2.61e-06 |
# |    value_loss         | 8.46e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1679      |
# |    iterations         | 4600      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.00692  |
# |    explained_variance | -2.73e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -1.27e-08 |
# |    value_loss         | 4.13e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1532     |
# |    iterations         | 4700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.00708 |
# |    explained_variance | -53.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 4.56e-07 |
# |    value_loss         | 2.15e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1394      |
# |    iterations         | 4800      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.00655  |
# |    explained_variance | -12.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -3.34e-08 |
# |    value_loss         | 5.47e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1294      |
# |    iterations         | 4900      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.00545  |
# |    explained_variance | -1.45     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -3.64e-07 |
# |    value_loss         | 5.38e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1217     |
# |    iterations         | 5000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.00569 |
# |    explained_variance | -36.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 9.47e-07 |
# |    value_loss         | 2.67e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 1132     |
# |    iterations         | 5100     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.00905 |
# |    explained_variance | -25.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 7.89e-07 |
# |    value_loss         | 1.45e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1065      |
# |    iterations         | 5200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.00884  |
# |    explained_variance | -1.72e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 3.45e-07  |
# |    value_loss         | 3.72e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 1018      |
# |    iterations         | 5300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.00864  |
# |    explained_variance | -3.18     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -2.17e-06 |
# |    value_loss         | 4.45e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 980      |
# |    iterations         | 5400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.0093  |
# |    explained_variance | -10.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 1.94e-06 |
# |    value_loss         | 4.48e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 944      |
# |    iterations         | 5500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.0104  |
# |    explained_variance | -88.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 4.08e-06 |
# |    value_loss         | 1.66e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 909      |
# |    iterations         | 5600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.00833 |
# |    explained_variance | -16.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 3.99e-06 |
# |    value_loss         | 1.76e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 878       |
# |    iterations         | 5700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.00894  |
# |    explained_variance | -197      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -3.22e-06 |
# |    value_loss         | 1.23e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 852      |
# |    iterations         | 5800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.0146  |
# |    explained_variance | -81.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 1.75e-06 |
# |    value_loss         | 2.18e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 828       |
# |    iterations         | 5900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.0142   |
# |    explained_variance | -0.657    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -1.46e-05 |
# |    value_loss         | 6.74e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 805       |
# |    iterations         | 6000      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.0108   |
# |    explained_variance | -2.73     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -3.77e-07 |
# |    value_loss         | 4.4e-07   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 784      |
# |    iterations         | 6100     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.0161  |
# |    explained_variance | -628     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 6.54e-06 |
# |    value_loss         | 1.19e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 768       |
# |    iterations         | 6200      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.0162   |
# |    explained_variance | -1.19e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 1.48e-06  |
# |    value_loss         | 7.16e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 752      |
# |    iterations         | 6300     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.0136  |
# |    explained_variance | -16.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 1.99e-06 |
# |    value_loss         | 1.93e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 736       |
# |    iterations         | 6400      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.0154   |
# |    explained_variance | -12.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000953 |
# |    value_loss         | 2.66e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 6500      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.00843  |
# |    explained_variance | -13.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -1.49e-06 |
# |    value_loss         | 5.82e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 692      |
# |    iterations         | 6600     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.0107  |
# |    explained_variance | -29.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 4.73e-07 |
# |    value_loss         | 5.4e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 678      |
# |    iterations         | 6700     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.00842 |
# |    explained_variance | -4.77    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 7.41e-08 |
# |    value_loss         | 7.06e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 664       |
# |    iterations         | 6800      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.00824  |
# |    explained_variance | -2.17e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 7.17e-08  |
# |    value_loss         | 4.75e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 645       |
# |    iterations         | 6900      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.00942  |
# |    explained_variance | -18.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -2.26e-07 |
# |    value_loss         | 1.53e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 7000      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.00963  |
# |    explained_variance | -6.57     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -1.15e-06 |
# |    value_loss         | 1.37e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 7100     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.00952 |
# |    explained_variance | -7.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 2.27e-06 |
# |    value_loss         | 4.14e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 611      |
# |    iterations         | 7200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.00674 |
# |    explained_variance | -32.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 9.74e-07 |
# |    value_loss         | 3.67e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 7300      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.00681  |
# |    explained_variance | -8.63e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -1.23e-07 |
# |    value_loss         | 7.19e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 594      |
# |    iterations         | 7400     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.00643 |
# |    explained_variance | -63.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 8.31e-07 |
# |    value_loss         | 1.62e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 585       |
# |    iterations         | 7500      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -0.00802  |
# |    explained_variance | -35       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -4.37e-06 |
# |    value_loss         | 2.75e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 7600      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -0.00678  |
# |    explained_variance | -23.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -4.68e-07 |
# |    value_loss         | 6.53e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 567       |
# |    iterations         | 7700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.00561  |
# |    explained_variance | -11       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -5.27e-07 |
# |    value_loss         | 9.41e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 559       |
# |    iterations         | 7800      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -0.00497  |
# |    explained_variance | -1.36e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# ...
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 17800     |
# |    time_elapsed       | 241       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.766    |
# |    explained_variance | -21.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -0.000297 |
# |    value_loss         | 8.03e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 17900     |
# |    time_elapsed       | 243       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.969    |
# |    explained_variance | -1.85     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -0.000282 |
# |    value_loss         | 2.02e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 18000    |
# |    time_elapsed       | 244      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.937   |
# |    explained_variance | -91.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | -0.00163 |
# |    value_loss         | 2.89e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 18100    |
# |    time_elapsed       | 246      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.825   |
# |    explained_variance | -2.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 3.44e-05 |
# |    value_loss         | 1.16e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 18200     |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.82     |
# |    explained_variance | -2.93e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -0.000697 |
# |    value_loss         | 4.17e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 18300     |
# |    time_elapsed       | 249       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.996    |
# |    explained_variance | -4.08e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -5.08e-05 |
# |    value_loss         | 1.23e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 18400    |
# |    time_elapsed       | 252      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.957   |
# |    explained_variance | -1.05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 0.000251 |
# |    value_loss         | 2.69e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 18500    |
# |    time_elapsed       | 254      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -4.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.000954 |
# |    value_loss         | 1.75e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 18600    |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -17.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.000124 |
# |    value_loss         | 2.23e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 18700    |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.864   |
# |    explained_variance | -86      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.00022 |
# |    value_loss         | 7.75e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 18800    |
# |    time_elapsed       | 259      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.971   |
# |    explained_variance | -39.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 0.000501 |
# |    value_loss         | 5.56e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 18900    |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.799   |
# |    explained_variance | -37.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.00012  |
# |    value_loss         | 8.84e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 19000     |
# |    time_elapsed       | 263       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.872    |
# |    explained_variance | -1.72e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | 0.000261  |
# |    value_loss         | 5.86e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 19100     |
# |    time_elapsed       | 264       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.466    |
# |    explained_variance | -28.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -1.88e-05 |
# |    value_loss         | 3.86e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 19200     |
# |    time_elapsed       | 266       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.661    |
# |    explained_variance | -1.8      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -0.000551 |
# |    value_loss         | 6.14e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 19300    |
# |    time_elapsed       | 268      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.981   |
# |    explained_variance | -4.36    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 0.000923 |
# |    value_loss         | 1.29e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 19400    |
# |    time_elapsed       | 269      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.758   |
# |    explained_variance | -69.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 0.00172  |
# |    value_loss         | 1.73e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 19500     |
# |    time_elapsed       | 271       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.851    |
# |    explained_variance | -8.79     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -0.000436 |
# |    value_loss         | 5.68e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 19600    |
# |    time_elapsed       | 273      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.814   |
# |    explained_variance | -8.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 0.00149  |
# |    value_loss         | 4.44e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 19700     |
# |    time_elapsed       | 274       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.652    |
# |    explained_variance | -4.31     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -0.000131 |
# |    value_loss         | 1.41e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -8.06    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 19800    |
# |    time_elapsed       | 276      |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | -67.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.000356 |
# |    value_loss         | 3.38e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 19900     |
# |    time_elapsed       | 278       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -0.487    |
# |    explained_variance | -699      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -4.25e-05 |
# |    value_loss         | 2.66e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -8.06     |
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 20000     |
# |    time_elapsed       | 279       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.627    |
# |    explained_variance | -3.79     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -0.000602 |
# |    value_loss         | 8.53e-06  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 3.3629395216713527
# Cumulative Return: 0.00033629395216713527
# Win Rate: 0.7582791505361918
# Profit Factor: 3.5891248092570214
# Sharpe Ratio: 0.3820956524880323
# Sortino Ratio: 0.7784789101427615
# Maximum Drawdown: 0.5255349547425977
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 2.032416996721492
# Cumulative Return: 0.0002032416996721492
# Win Rate: 0.6151706532128585
# Profit Factor: 1.4255329958539384
# Sharpe Ratio: 0.13015453477651706
# Sortino Ratio: 0.23470906120501084
# Maximum Drawdown: 0.7893591778801712
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'AAPL_TRAINING.csv'
    test_file = 'AAPL_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1833 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1532        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009541928 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -11.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0574     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00842    |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008237675 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.51       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0038      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 0.00808     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -0.726      |
# | time/                   |             |
# |    fps                  | 1405        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009579824 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0305     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -0.726       |
# | time/                   |              |
# |    fps                  | 1384         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0068128617 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0327      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00134     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 0.00264      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -0.726      |
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007884741 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -1.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -0.726       |
# | time/                   |              |
# |    fps                  | 1361         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0071974546 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.267       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0173      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00845     |
# |    value_loss           | 0.00396      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 0.407        |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0056475922 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.0783      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00373     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00703     |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06e+03   |
# |    ep_rew_mean          | 0.407      |
# | time/                   |            |
# |    fps                  | 1353       |
# |    iterations           | 9          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00909776 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.194      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0364    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00927   |
# |    value_loss           | 0.00226    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.407       |
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008222571 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.102      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 0.407       |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006782726 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0071     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.00465     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.06e+03 |
# |    ep_rew_mean          | 3.3      |
# | time/                   |          |
# |    fps                  | 1329     |
# |    iterations           | 12       |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 0.010345 |
# |    clip_fraction        | 0.0878   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.02    |
# |    explained_variance   | -0.00734 |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0343  |
# |    n_updates            | 110      |
# |    policy_gradient_loss | -0.0113  |
# |    value_loss           | 0.00185  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.3         |
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008067064 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00487    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.3         |
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007959874 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00269    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00957    |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.3         |
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009454431 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.0816      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00111     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00388     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06e+03   |
# |    ep_rew_mean          | 7          |
# | time/                   |            |
# |    fps                  | 1323       |
# |    iterations           | 16         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00703675 |
# |    clip_fraction        | 0.076      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.962     |
# |    explained_variance   | 0.166      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0125    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00471   |
# |    value_loss           | 0.00192    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7            |
# | time/                   |              |
# |    fps                  | 1313         |
# |    iterations           | 17           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0061582215 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0347      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00645     |
# |    value_loss           | 0.00298      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 7           |
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006716544 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00466    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7            |
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 19           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0089728655 |
# |    clip_fraction        | 0.0888       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 0.00404      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.06e+03  |
# |    ep_rew_mean          | 10.1      |
# | time/                   |           |
# |    fps                  | 1285      |
# |    iterations           | 20        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0054311 |
# |    clip_fraction        | 0.0862    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.922    |
# |    explained_variance   | 0.391     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000264 |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.0044   |
# |    value_loss           | 0.00184   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012655828 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00428     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000782   |
# |    value_loss           | 0.0032      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 22          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010820518 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0241      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 23          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007381567 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 0.00473     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 1274         |
# |    iterations           | 24           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077052624 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | 0.309        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0135      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 25          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008343903 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.735      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00595     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00218     |
# |    value_loss           | 0.00413     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1154     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000283 |
# |    n_updates        | 8035     |
# ----------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 899       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -1.27e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0928    |
# |    value_loss         | 0.0117    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 896      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -0.53    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0891  |
# |    value_loss         | 0.00658  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -165     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0177   |
# |    value_loss         | 0.000582 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 887      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -2       |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0397  |
# |    value_loss         | 0.00155  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 887      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -462     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0804   |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 887      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -106     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00332 |
# |    value_loss         | 0.00187  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -19.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0661   |
# |    value_loss         | 0.00458  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -101     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.00169 |
# |    value_loss         | 0.000417 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -9.14    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.00357  |
# |    value_loss         | 2.31e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 890      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.262   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0123  |
# |    value_loss         | 0.000739 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 891      |
# |    iterations         | 1100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -60.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.00159  |
# |    value_loss         | 0.000142 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 891      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -20.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0105   |
# |    value_loss         | 0.000107 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 891      |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.995   |
# |    explained_variance | 0.54     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.00319 |
# |    value_loss         | 1.26e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 890      |
# |    iterations         | 1400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.636   |
# |    explained_variance | 0.203    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.036    |
# |    value_loss         | 0.000555 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 890      |
# |    iterations         | 1500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.978   |
# |    explained_variance | -17.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00318  |
# |    value_loss         | 1.61e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 887       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.67     |
# |    explained_variance | -0.309    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.000556 |
# |    value_loss         | 1.15e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.847   |
# |    explained_variance | -0.0508  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00867  |
# |    value_loss         | 0.000234 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 1800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.798   |
# |    explained_variance | -7.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0022   |
# |    value_loss         | 0.000311 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 1900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | 0.508    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0013  |
# |    value_loss         | 1.72e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | -1.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00898  |
# |    value_loss         | 0.000139 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 2100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.99    |
# |    explained_variance | -745     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0375   |
# |    value_loss         | 0.00572  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.934   |
# |    explained_variance | -1.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0241   |
# |    value_loss         | 0.00247  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.88     |
# | time/                 |           |
# |    fps                | 888       |
# |    iterations         | 2300      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -1.16e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.0095    |
# |    value_loss         | 0.00279   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.837   |
# |    explained_variance | -68.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0362  |
# |    value_loss         | 0.00338  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.88     |
# | time/                 |           |
# |    fps                | 889       |
# |    iterations         | 2500      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.743    |
# |    explained_variance | -1.75e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -0.000338 |
# |    value_loss         | 7.98e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -1.95    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0363  |
# |    value_loss         | 0.00314  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.924   |
# |    explained_variance | -31.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.00195 |
# |    value_loss         | 1.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 2800     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.798   |
# |    explained_variance | -1.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.000521 |
# |    value_loss         | 5.01e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 2900     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.554   |
# |    explained_variance | -1.34    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000364 |
# |    value_loss         | 5.52e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.806   |
# |    explained_variance | -0.681   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000896 |
# |    value_loss         | 6.27e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 3100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.564   |
# |    explained_variance | -0.268   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00037  |
# |    value_loss         | 4.16e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | -114     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 2.14e-06 |
# |    value_loss         | 9.81e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 3300     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.339   |
# |    explained_variance | -4.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000149 |
# |    value_loss         | 1.07e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.33     |
# | time/                 |           |
# |    fps                | 888       |
# |    iterations         | 3400      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.207    |
# |    explained_variance | -1.27e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 0.000388  |
# |    value_loss         | 0.000151  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3500     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.598   |
# |    explained_variance | 0.112    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.012    |
# |    value_loss         | 0.000922 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | -15.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00591 |
# |    value_loss         | 0.000208 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3700     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | -7e+03   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00508  |
# |    value_loss         | 0.00531  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3800     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | 0.416    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0198  |
# |    value_loss         | 0.00414  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 3900     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | -0.339   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00656 |
# |    value_loss         | 0.000323 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 4000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.42    |
# |    explained_variance | -9.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0306  |
# |    value_loss         | 0.00211  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 4100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | -3.71    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.000775 |
# |    value_loss         | 8.86e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.33     |
# | time/                 |           |
# |    fps                | 887       |
# |    iterations         | 4200      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.57     |
# |    explained_variance | -4.22e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.017    |
# |    value_loss         | 0.000917  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 4300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | -6.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.00523  |
# |    value_loss         | 5.68e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.33    |
# | time/                 |          |
# |    fps                | 883      |
# |    iterations         | 4400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | -14.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.00328  |
# |    value_loss         | 9.78e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# ...
# |    n_updates          | 7599      |
# |    policy_loss        | -0.000462 |
# |    value_loss         | 1.54e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.473    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 7700     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | 0.0799   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.00245  |
# |    value_loss         | 1.72e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.473    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 7800     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.803   |
# |    explained_variance | -0.00335 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.00346  |
# |    value_loss         | 7.69e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.473    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 7900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.897   |
# |    explained_variance | 0.0181   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.0161   |
# |    value_loss         | 0.000476 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.473    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 8000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.883   |
# |    explained_variance | 0.0344   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.0136   |
# |    value_loss         | 0.000149 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 8100     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | -0.571   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.000575 |
# |    value_loss         | 1.01e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 885      |
# |    iterations         | 8200     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.757   |
# |    explained_variance | -0.0149  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0.00513 |
# |    value_loss         | 3.37e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | 0.168     |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 8300      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -0.331    |
# |    explained_variance | -0.739    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -2.93e-05 |
# |    value_loss         | 1.92e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 8400     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.317   |
# |    explained_variance | 0.0583   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.000966 |
# |    value_loss         | 1.54e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 8500     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.323   |
# |    explained_variance | -24.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 1.03e-05 |
# |    value_loss         | 5.44e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | 0.168     |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 8600      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.336    |
# |    explained_variance | -0.16     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -0.000729 |
# |    value_loss         | 5.71e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 8700     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.97    |
# |    explained_variance | -0.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 0.0935   |
# |    value_loss         | 0.00818  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 8800     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.611   |
# |    explained_variance | -9.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | -0.0479  |
# |    value_loss         | 0.00293  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | 0.168     |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 8900      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.351    |
# |    explained_variance | -16.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.000329 |
# |    value_loss         | 9.87e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -0.827   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0231  |
# |    value_loss         | 0.00209  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | 0.168     |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 9100      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.478    |
# |    explained_variance | -86.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -5.99e-05 |
# |    value_loss         | 1.71e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9200     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | 0.197    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | -0.00458 |
# |    value_loss         | 4.07e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9300     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | -0.0301  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 0.00756  |
# |    value_loss         | 3.24e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | 0.168     |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 9400      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -0.681    |
# |    explained_variance | -0.000513 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | -0.0593   |
# |    value_loss         | 0.00813   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9500     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | -0.0269  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | 0.0171   |
# |    value_loss         | 0.000751 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | 0.168    |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9600     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.288   |
# |    explained_variance | -0.0673  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | 0.000366 |
# |    value_loss         | 2.43e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -0.0118   |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 9700      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -0.183    |
# |    explained_variance | -36.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | -0.000293 |
# |    value_loss         | 1.19e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -0.0118  |
# | time/                 |          |
# |    fps                | 882      |
# |    iterations         | 9800     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -0.274   |
# |    explained_variance | -249     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 4.56e-05 |
# |    value_loss         | 7.27e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -0.0118   |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 9900      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -0.218    |
# |    explained_variance | -4.39e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | -0.000809 |
# |    value_loss         | 1.24e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -0.0118   |
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 10000     |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -0.376    |
# |    explained_variance | -0.161    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | -0.000429 |
# |    value_loss         | 1.81e-05  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.09597027151903603
# Cumulative Return: 9.597027151903603e-06
# Win Rate: 0.5
# Profit Factor: 1.1352875183384643
# Sharpe Ratio: 0.03643974529474427
# Sortino Ratio: 0.04738955436521411
# Maximum Drawdown: 0.6163210972831326
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 20.27395138460305
# Cumulative Return: 0.002027395138460305
# Win Rate: 0.6790852387364505
# Profit Factor: 7.0433330482301875
# Sharpe Ratio: 0.4842429424860053
# Sortino Ratio: 2.425780228704705
# Maximum Drawdown: 0.23175072091856397
