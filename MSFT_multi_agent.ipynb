# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'MSFT_TRAINING.csv'
    test_file = 'MSFT_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 920  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014197102 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -10.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00769    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012647901 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -2.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0283     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073450278 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.653       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.003        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00742     |
# |    value_loss           | 0.00287      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0075554587 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.466        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 0.00263      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 6            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0066131093 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0257      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00833     |
# |    value_loss           | 0.00412      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -1.37       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004998482 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.505      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -0.2         |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0059839236 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0175       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0232      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00931     |
# |    value_loss           | 0.00228      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007921923 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 0.00201     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -0.2         |
# | time/                   |              |
# |    fps                  | 798          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0077993963 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | -0.012       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0282      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00843     |
# |    value_loss           | 0.00353      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -0.2         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070448685 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | -0.126       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00204     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0097      |
# |    value_loss           | 0.00248      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.22        |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008090118 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | -0.131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00719     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00998    |
# |    value_loss           | 0.00185     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.22        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010425467 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | -0.199      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 0.00226     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.22        |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006974344 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -0.142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00342     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.22        |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 15          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007913608 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | -0.158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 16          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007479279 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 3.02         |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 17           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0070685577 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.015       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00614     |
# |    value_loss           | 0.00223      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009230591 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | -0.1        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 0.00317     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012046274 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | -0.0975     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00869    |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 5.33         |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 20           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0061445115 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.018       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00699     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.33        |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 21          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007410903 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00488    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.33        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 22          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009754185 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.0556      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000346   |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 5.33         |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 23           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0057532014 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0239       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00784     |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 7.76        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012137588 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00187     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 7.76        |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 25          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006155242 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00544    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.00358     |
# -----------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 9.075237251305225
# Cumulative Return: 0.0009075237251305225
# Win Rate: 0.6265560165975104
# Profit Factor: 2.897648148095576
# Sharpe Ratio: 0.3306457335444147
# Sortino Ratio: 0.6459289306132869
# Maximum Drawdown: 0.20777759762730774
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1226 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011256825 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -11.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0295      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00709    |
# |    value_loss           | 0.00912     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011235321 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -1.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 0.00444     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -3.11       |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010452669 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0247      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00434     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 0.00426     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -3.11       |
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008742391 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 0.00308     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -3.11       |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007839142 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00394     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -3.11        |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 7            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0077586262 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.461       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -0.765      |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007940587 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -0.765       |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0039749057 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00139     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | -0.765       |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 10           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0061563356 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | -0.408       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.02        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 0.00382      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | -0.765      |
# | time/                   |             |
# |    fps                  | 906         |
# |    iterations           | 11          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006611688 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0434      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00306     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.05e+03   |
# |    ep_rew_mean          | 1.3        |
# | time/                   |            |
# |    fps                  | 914        |
# |    iterations           | 12         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00631083 |
# |    clip_fraction        | 0.064      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.478      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0206    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00883   |
# |    value_loss           | 0.00204    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 1.3          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 13           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0071900096 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.96        |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0227      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 0.00306      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.3         |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 14          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006890447 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.0792      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 1.3          |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 15           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0049777864 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.078        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0339      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00807     |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.05e+03   |
# |    ep_rew_mean          | 3          |
# | time/                   |            |
# |    fps                  | 938        |
# |    iterations           | 16         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00859067 |
# |    clip_fraction        | 0.0793     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.973     |
# |    explained_variance   | 0.314      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0235    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00996   |
# |    value_loss           | 0.00145    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 3           |
# | time/                   |             |
# |    fps                  | 903         |
# |    iterations           | 17          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011588339 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.0183      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 3            |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 18           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0068735927 |
# |    clip_fraction        | 0.0918       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0216      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0081      |
# |    value_loss           | 0.00334      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 3            |
# | time/                   |              |
# |    fps                  | 906          |
# |    iterations           | 19           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0076936623 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0242      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00918     |
# |    value_loss           | 0.00214      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 909         |
# |    iterations           | 20          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009438816 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00917    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 21          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012250762 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6e-05       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 22          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009416042 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00384     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 23          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008065643 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.81        |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 24          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007591353 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00377     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.81        |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 25          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014822439 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00863    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 0.00439     |
# -----------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 11.815477542348162
# Cumulative Return: 0.0011815477542348163
# Win Rate: 0.6666666666666666
# Profit Factor: 4.764360283871997
# Sharpe Ratio: 0.4854109049577365
# Sortino Ratio: 1.1409935743248893
# Maximum Drawdown: 0.1306239526421571
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1384 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009838453 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -13.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006936676 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -1.55       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 0.0278       |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0067509315 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.238        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 0.00306      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 0.0278      |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006742497 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 0.0278       |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064091724 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.2         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0231      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00589     |
# |    value_loss           | 0.00393      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 0.0278      |
# | time/                   |             |
# ...
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 10           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0071068527 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.191       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0279      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00768     |
# |    value_loss           | 0.00423      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 0.83         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 11           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0068429615 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.0919      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0203      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 12          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008325048 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0705     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00691    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.05e+03   |
# |    ep_rew_mean          | 1.96       |
# | time/                   |            |
# |    fps                  | 747        |
# |    iterations           | 13         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00847468 |
# |    clip_fraction        | 0.0814     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.253     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.025     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0062    |
# |    value_loss           | 0.00247    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006995918 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | -0.144      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0194     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007221185 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | -0.259      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0276     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 4.36        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010370167 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | -0.333      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00484    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 4.36         |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 17           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0073165507 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.959       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 0.00239      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 4.36        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011579049 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | -0.0527     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 4.36        |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008277404 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.00216     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 6.44        |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006702084 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00881    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 6.44        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 21          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009001008 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0377     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 0.00291     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 6.44        |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 22          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007323831 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 6.44         |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 23           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0058179377 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0096      |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.49        |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 24          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009487076 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.49        |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 25          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010621602 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 0.00432     |
# -----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 7.692895293477704
# Cumulative Return: 0.0007692895293477704
# Win Rate: 0.6107491856677525
# Profit Factor: 2.908673788556854
# Sharpe Ratio: 0.298366552070225
# Sortino Ratio: 0.6013227600599598
# Maximum Drawdown: 0.18183085397191956
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 10.742914010786212
# Cumulative Return: 0.001074291401078621
# Win Rate: 0.6580771250425171
# Profit Factor: 4.5164458291705065
# Sharpe Ratio: 0.41801246338420694
# Sortino Ratio: 1.0427776142597975
# Maximum Drawdown: 0.1655119668316889
# --- Agent 1 Testing Metrics ---
# Total Profit: 23.84214233815146
# Cumulative Return: 0.002384214233815146
# Win Rate: 0.7569060773480663
# Profit Factor: 9.980678894283669
# Sharpe Ratio: 0.6103618292865464
# Sortino Ratio: 2.3905926564949347
# Maximum Drawdown: 0.10298789715212564
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 21.55795417815898
# Cumulative Return: 0.002155795417815898
# Win Rate: 0.6831683168316832
# Profit Factor: 6.124384472076316
# Sharpe Ratio: 0.47902340783062525
# Sortino Ratio: 1.576620673195984
# Maximum Drawdown: 0.17116549716514928
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 23.56102610860944
# Cumulative Return: 0.002356102610860944
# Win Rate: 0.7068493150684931
# Profit Factor: 7.292530094020669
# Sharpe Ratio: 0.4962467354387061
# Sortino Ratio: 1.4876400470535838
# Maximum Drawdown: 0.23180034892912182
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 21.096384145637785
# Cumulative Return: 0.0021096384145637783
# Win Rate: 0.6937716262975778
# Profit Factor: 6.609494983667396
# Sharpe Ratio: 0.534315179395351
# Sortino Ratio: 1.2119043588906768
# Maximum Drawdown: 0.3994417592934134
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 22.568156386926976
# Cumulative Return: 0.0022568156386926974
# Win Rate: 0.7126142592011511
# Profit Factor: 7.630377334352016
# Sharpe Ratio: 0.5348050871089012
# Sortino Ratio: 1.698221638734283
# Maximum Drawdown: 0.2232650574916749

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'MSFT_TRAINING.csv'
    test_file = 'MSFT_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05e+03 |
# |    ep_rew_mean      | -2.11    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 920      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 32192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000396 |
# |    n_updates        | 8022     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05e+03 |
# |    ep_rew_mean      | -0.249   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 956      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 32192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000301 |
# |    n_updates        | 8022     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05e+03 |
# |    ep_rew_mean      | -2.18    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 866      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 32192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.57e-05 |
# |    n_updates        | 8022     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05e+03 |
# |    ep_rew_mean      | -0.632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 998      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 32192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000413 |
# |    n_updates        | 8022     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.0479950383021088
# Cumulative Return: 0.00010479950383021088
# Win Rate: 0.5072536894759758
# Profit Factor: 1.2710590106881319
# Sharpe Ratio: 0.07360523843147337
# Sortino Ratio: 0.12502781046397038
# Maximum Drawdown: 0.6647736024192045
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.9193054366190012
# Cumulative Return: 9.193054366190012e-05
# Win Rate: 0.5186887203306696
# Profit Factor: 1.0698271767613245
# Sharpe Ratio: 0.022893169397720767
# Sortino Ratio: 0.0379254146825636
# Maximum Drawdown: 1.1974201483053208

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'MSFT_TRAINING.csv'
    test_file = 'MSFT_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=100000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 683      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -505     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0363  |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 746      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -355     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0424  |
# |    value_loss         | 0.00511  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 772      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -108     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0521   |
# |    value_loss         | 0.00458  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 749      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -195     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0915   |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -637     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0481  |
# |    value_loss         | 0.00382  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 773       |
# |    iterations         | 600       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -5.23e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.0106    |
# |    value_loss         | 0.000533  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 779       |
# |    iterations         | 700       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -1.43e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.00697   |
# |    value_loss         | 0.000753  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 782      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -415     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0186   |
# |    value_loss         | 0.000764 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 786      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -19      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0455  |
# |    value_loss         | 0.00231  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 1000      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.1      |
# |    explained_variance | -3.66e+06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.0148   |
# |    value_loss         | 0.000609  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 761      |
# |    iterations         | 1100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -73      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.000788 |
# |    value_loss         | 0.00017  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 739       |
# |    iterations         | 1200      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.977    |
# |    explained_variance | -9.44e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.00149   |
# |    value_loss         | 0.00023   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 709      |
# |    iterations         | 1300     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.898   |
# |    explained_variance | -7.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.00488  |
# |    value_loss         | 0.000129 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 696      |
# |    iterations         | 1400     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.803   |
# |    explained_variance | -118     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00253 |
# |    value_loss         | 5.75e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 687      |
# |    iterations         | 1500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.642   |
# |    explained_variance | -466     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.00359 |
# |    value_loss         | 0.000226 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 686       |
# |    iterations         | 1600      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.456    |
# |    explained_variance | -1.42e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.00288   |
# |    value_loss         | 0.00051   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 687       |
# |    iterations         | 1700      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.455    |
# |    explained_variance | -6.94e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.0041    |
# |    value_loss         | 2.53e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 692      |
# |    iterations         | 1800     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | -935     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.00452 |
# |    value_loss         | 0.000378 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 694      |
# |    iterations         | 1900     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | -4.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 9.12e-05 |
# |    value_loss         | 3.12e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 699       |
# |    iterations         | 2000      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.535    |
# |    explained_variance | -9.56e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.00118   |
# |    value_loss         | 7.02e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 704      |
# |    iterations         | 2100     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | -107     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.00336  |
# |    value_loss         | 4.33e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 706      |
# |    iterations         | 2200     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.64    |
# |    explained_variance | -147     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0018   |
# |    value_loss         | 1.04e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 710      |
# |    iterations         | 2300     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.882   |
# |    explained_variance | -33.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00474 |
# |    value_loss         | 3.8e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 711      |
# |    iterations         | 2400     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -4.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00408 |
# |    value_loss         | 1.94e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 702      |
# |    iterations         | 2500     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | -6.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00622  |
# |    value_loss         | 4.13e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 697      |
# |    iterations         | 2600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.777   |
# |    explained_variance | -70      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000934 |
# |    value_loss         | 8.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 701      |
# |    iterations         | 2700     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.76    |
# |    explained_variance | -300     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0089  |
# |    value_loss         | 7.43e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 703      |
# |    iterations         | 2800     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.879   |
# |    explained_variance | -75.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00283  |
# |    value_loss         | 1.78e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 707       |
# |    iterations         | 2900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.846    |
# |    explained_variance | -229      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.000347 |
# |    value_loss         | 1.06e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.691    |
# |    explained_variance | -687      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.000393 |
# |    value_loss         | 8.11e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 713       |
# |    iterations         | 3100      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.794    |
# |    explained_variance | -1.63e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -0.000965 |
# |    value_loss         | 4.56e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 717       |
# |    iterations         | 3200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.781    |
# |    explained_variance | -21.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -3.59e-05 |
# |    value_loss         | 4.2e-05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 718       |
# |    iterations         | 3300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.767    |
# |    explained_variance | -270      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -7.44e-05 |
# |    value_loss         | 3.06e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 716       |
# |    iterations         | 3400      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.73     |
# |    explained_variance | -1.44e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.00179  |
# |    value_loss         | 8.81e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 716       |
# |    iterations         | 3500      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.625    |
# |    explained_variance | -7.82     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.000212 |
# |    value_loss         | 1.94e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 713      |
# |    iterations         | 3600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | -98.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00211 |
# |    value_loss         | 5.25e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 715      |
# |    iterations         | 3700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.734   |
# |    explained_variance | -37.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00168  |
# |    value_loss         | 1.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 717      |
# |    iterations         | 3800     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.786   |
# |    explained_variance | -194     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.00134 |
# |    value_loss         | 7.22e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 719       |
# |    iterations         | 3900      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.787    |
# |    explained_variance | -58.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.000196 |
# |    value_loss         | 6.53e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 721      |
# |    iterations         | 4000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.653   |
# |    explained_variance | 0.829    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00158  |
# |    value_loss         | 5.49e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 4100     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.777   |
# |    explained_variance | -218     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.00203  |
# |    value_loss         | 8.96e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 4200     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.885   |
# |    explained_variance | -24      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.00274  |
# |    value_loss         | 9.42e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 727      |
# |    iterations         | 4300     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.408   |
# |    explained_variance | -4.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000606 |
# |    value_loss         | 2.93e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 729       |
# |    iterations         | 4400      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.43     |
# |    explained_variance | -15.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -0.000426 |
# |    value_loss         | 4.34e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 731      |
# |    iterations         | 4500     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.843   |
# |    explained_variance | -36.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.00119 |
# |    value_loss         | 4.57e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 733      |
# |    iterations         | 4600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | -56.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00073 |
# |    value_loss         | 6.53e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 735       |
# |    iterations         | 4700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.876    |
# |    explained_variance | -4.33e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 0.000702  |
# |    value_loss         | 3.48e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 736      |
# |    iterations         | 4800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.877   |
# |    explained_variance | -243     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.000188 |
# |    value_loss         | 5.65e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 738       |
# |    iterations         | 4900      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.531    |
# |    explained_variance | -1.86e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -0.000207 |
# |    value_loss         | 4.31e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 739      |
# |    iterations         | 5000     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.675   |
# |    explained_variance | -30.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.000838 |
# |    value_loss         | 7.01e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 741      |
# |    iterations         | 5100     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.368   |
# |    explained_variance | -41.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.00011  |
# |    value_loss         | 2.22e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 742      |
# |    iterations         | 5200     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | -7.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00205  |
# |    value_loss         | 7.04e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 744      |
# |    iterations         | 5300     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | -35.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.000984 |
# |    value_loss         | 2.14e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 745       |
# |    iterations         | 5400      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.29     |
# |    explained_variance | -110      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000119 |
# |    value_loss         | 3.54e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 746      |
# |    iterations         | 5500     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.279   |
# |    explained_variance | -115     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 5.55e-05 |
# |    value_loss         | 4.6e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 748      |
# |    iterations         | 5600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | -7.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.00467  |
# |    value_loss         | 4.4e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 749      |
# |    iterations         | 5700     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.767   |
# |    explained_variance | -53.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.000146 |
# |    value_loss         | 2.34e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 750      |
# |    iterations         | 5800     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.467   |
# |    explained_variance | -20.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.00318  |
# |    value_loss         | 1.67e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 751      |
# |    iterations         | 5900     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | -523     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -6.7e-05 |
# |    value_loss         | 4.58e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 752      |
# |    iterations         | 6000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | -4.85    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.00252  |
# |    value_loss         | 5.22e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 754       |
# |    iterations         | 6100      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.559    |
# |    explained_variance | -344      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0.000454 |
# |    value_loss         | 1.12e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 754      |
# |    iterations         | 6200     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.818   |
# |    explained_variance | -53.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.00253  |
# |    value_loss         | 4.9e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 755       |
# |    iterations         | 6300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.733    |
# |    explained_variance | -1.81e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -7.9e-05  |
# |    value_loss         | 1.27e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 756       |
# |    iterations         | 6400      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.724    |
# |    explained_variance | -101      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000687 |
# |    value_loss         | 1.29e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 6500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.751   |
# |    explained_variance | -1.5e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00186  |
# |    value_loss         | 9.87e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 6600     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.754   |
# |    explained_variance | -30.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00107 |
# |    value_loss         | 3e-06    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 758       |
# |    iterations         | 6700      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.771    |
# |    explained_variance | -1.03e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.000365 |
# |    value_loss         | 1.09e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 759      |
# |    iterations         | 6800     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.74    |
# |    explained_variance | -27      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 7.47e-05 |
# |    value_loss         | 4.46e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 760      |
# |    iterations         | 6900     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.792   |
# |    explained_variance | -5.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00121 |
# |    value_loss         | 4.07e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 761       |
# |    iterations         | 7000      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.82     |
# |    explained_variance | -1.82     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000277 |
# |    value_loss         | 2.7e-07   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 761      |
# |    iterations         | 7100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.879   |
# |    explained_variance | -11.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.00211 |
# |    value_loss         | 1.75e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 762      |
# |    iterations         | 7200     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.726   |
# |    explained_variance | -20.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.000622 |
# |    value_loss         | 4.31e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 7300     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.8     |
# |    explained_variance | -1.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.00324 |
# |    value_loss         | 2.57e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 7400     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | -8.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.000118 |
# |    value_loss         | 4.95e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 764      |
# |    iterations         | 7500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.924   |
# |    explained_variance | -75.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.00151  |
# |    value_loss         | 3.31e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 7600     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.969   |
# |    explained_variance | -83.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.00316  |
# |    value_loss         | 8.74e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 7700     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.84    |
# |    explained_variance | -131     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.000208 |
# |    value_loss         | 1.55e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 766      |
# |    iterations         | 7800     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.497   |
# |    explained_variance | -14.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.00677  |
# |    value_loss         | 1.8e-05  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# ...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 17800    |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.0436  |
# |    explained_variance | -17.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 1.23e-06 |
# |    value_loss         | 1.44e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 17900    |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.0365  |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 3.53e-06 |
# |    value_loss         | 1.13e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 983       |
# |    iterations         | 18000     |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -0.0368   |
# |    explained_variance | -86.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -4.07e-06 |
# |    value_loss         | 1.19e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 18100    |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.0481  |
# |    explained_variance | -5.07    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 4.54e-06 |
# |    value_loss         | 1.36e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 18200    |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.0348  |
# |    explained_variance | -0.228   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | 2.4e-06  |
# |    value_loss         | 3.39e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 18300    |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.0396  |
# |    explained_variance | -0.538   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | -9.3e-06 |
# |    value_loss         | 2.69e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 983      |
# |    iterations         | 18400    |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.219   |
# |    explained_variance | -77.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 0.000153 |
# |    value_loss         | 2.08e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 18500     |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.0394   |
# |    explained_variance | -9.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -9.92e-07 |
# |    value_loss         | 2.93e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 18600     |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -0.0453   |
# |    explained_variance | -32.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | -7.06e-07 |
# |    value_loss         | 4.38e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 984      |
# |    iterations         | 18700    |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.0542  |
# |    explained_variance | -42.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 2.97e-05 |
# |    value_loss         | 9.48e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 18800     |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -0.105    |
# |    explained_variance | -5.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -2.18e-05 |
# |    value_loss         | 9.09e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 984      |
# |    iterations         | 18900    |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.0233  |
# |    explained_variance | -5.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 2.41e-06 |
# |    value_loss         | 9.59e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 19000     |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.0194   |
# |    explained_variance | -4.4      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -2.29e-07 |
# |    value_loss         | 8.8e-08   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 984       |
# |    iterations         | 19100     |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.02     |
# |    explained_variance | -12.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -6.06e-06 |
# |    value_loss         | 5.53e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 985       |
# |    iterations         | 19200     |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.0134   |
# |    explained_variance | -8.13e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | 2.53e-06  |
# |    value_loss         | 2.9e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 985      |
# |    iterations         | 19300    |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.0138  |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 8.76e-07 |
# |    value_loss         | 3.96e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 985       |
# |    iterations         | 19400     |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -0.0137   |
# |    explained_variance | -72       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -1.26e-06 |
# |    value_loss         | 2.85e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 985      |
# |    iterations         | 19500    |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -0.015   |
# |    explained_variance | -28.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -3e-06   |
# |    value_loss         | 4.96e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 985      |
# |    iterations         | 19600    |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.0128  |
# |    explained_variance | -10.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 5.6e-07  |
# |    value_loss         | 4.96e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -8.05    |
# | time/                 |          |
# |    fps                | 985      |
# |    iterations         | 19700    |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -0.0209  |
# |    explained_variance | -4.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 1.62e-06 |
# |    value_loss         | 1.05e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 985       |
# |    iterations         | 19800     |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.0438   |
# |    explained_variance | -2.07     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -3.07e-07 |
# |    value_loss         | 3.93e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 985       |
# |    iterations         | 19900     |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -0.0237   |
# |    explained_variance | -0.731    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -1.68e-06 |
# |    value_loss         | 3.53e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -8.05     |
# | time/                 |           |
# |    fps                | 985       |
# |    iterations         | 20000     |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.032    |
# |    explained_variance | -0.449    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -3.72e-06 |
# |    value_loss         | 7.84e-07  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.9035725500402687
# Cumulative Return: 9.035725500402689e-05
# Win Rate: 0.5507681815354344
# Profit Factor: 7.446991459420145
# Sharpe Ratio: 0.6775215507859799
# Sortino Ratio: 4.787988808014525
# Maximum Drawdown: 0.2065573982847425
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0
# Cumulative Return: 0
# Win Rate: 0
# Profit Factor: 0
# Sharpe Ratio: 0
# Sortino Ratio: 0
# Maximum Drawdown: 0
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'MSFT_TRAINING.csv'
    test_file = 'MSFT_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2021 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014839342 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -11.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1225        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008718557 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -3.63       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0191      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 0.00667     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 1259        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008092601 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0045     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010459399 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00309     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 1298        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008367006 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00376    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00361    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 0.00312     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005422679 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0173      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008316549 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 1285        |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007287395 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00131    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 1282         |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0076007317 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00112     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00973     |
# |    value_loss           | 0.0039       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008404506 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.344      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 2.95        |
# | time/                   |             |
# |    fps                  | 1307        |
# |    iterations           | 12          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009036243 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 2.95        |
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006453396 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0949      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 2.95        |
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008987258 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0577      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00102    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00995    |
# |    value_loss           | 0.0037      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 2.95        |
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008242498 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0129      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 16          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009749554 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.05e+03   |
# |    ep_rew_mean          | 5.79       |
# | time/                   |            |
# |    fps                  | 1318       |
# |    iterations           | 17         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01018858 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.153      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0275    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00386   |
# |    value_loss           | 0.00274    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 18          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007470144 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | -0.0633     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 19          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008585671 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.06        |
# | time/                   |             |
# |    fps                  | 1327        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005396394 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.05e+03     |
# |    ep_rew_mean          | 8.06         |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 21           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0062535955 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00749     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 0.0033       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.06        |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008919465 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 0.00328     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 8.06        |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 23          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008096537 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 24          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012391927 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.05e+03    |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 1344        |
# |    iterations           | 25          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010631146 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 0.00351     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05e+03 |
# |    ep_rew_mean      | 0.849    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1253     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 32192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00018  |
# |    n_updates        | 8022     |
# ----------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1054     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.576   |
# |    explained_variance | -293     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0158  |
# |    value_loss         | 0.00165  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1045     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.366   |
# |    explained_variance | -333     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.00172  |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1038     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.357   |
# |    explained_variance | -223     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.108   |
# |    value_loss         | 0.00345  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1025      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.189    |
# |    explained_variance | -4.22e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -0.0251   |
# |    value_loss         | 0.00184   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1020     |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.142   |
# |    explained_variance | -30.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 2.63e-05 |
# |    value_loss         | 8.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1021     |
# |    iterations         | 600      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.183   |
# |    explained_variance | -67.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 6e-05    |
# |    value_loss         | 0.000126 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.472   |
# |    explained_variance | -3.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00735  |
# |    value_loss         | 0.000258 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1024      |
# |    iterations         | 800       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.668    |
# |    explained_variance | -1.76e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.0352   |
# |    value_loss         | 0.00205   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1025     |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -15.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0191   |
# |    value_loss         | 0.000631 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1025     |
# |    iterations         | 1000     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | -3.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.000761 |
# |    value_loss         | 5.91e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1025     |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.958   |
# |    explained_variance | -1.65    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0988  |
# |    value_loss         | 0.00747  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1026     |
# |    iterations         | 1200     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -16      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00269 |
# |    value_loss         | 3.47e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1026     |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | -9.6     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.00539 |
# |    value_loss         | 4.61e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1025     |
# |    iterations         | 1400     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | -1.6e+04 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0302  |
# |    value_loss         | 0.00121  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1027     |
# |    iterations         | 1500     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.849   |
# |    explained_variance | -510     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.00104 |
# |    value_loss         | 3.91e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1029      |
# |    iterations         | 1600      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.507    |
# |    explained_variance | -1.54e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.000532 |
# |    value_loss         | 1.01e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1024     |
# |    iterations         | 1700     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.439   |
# |    explained_variance | -22.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00096  |
# |    value_loss         | 9.55e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 1800     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.813   |
# |    explained_variance | -175     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0242   |
# |    value_loss         | 0.000541 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1018     |
# |    iterations         | 1900     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.642   |
# |    explained_variance | -23.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00279  |
# |    value_loss         | 4.39e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1015     |
# |    iterations         | 2000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.732   |
# |    explained_variance | -136     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00245  |
# |    value_loss         | 1.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1015     |
# |    iterations         | 2100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -7.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.00787  |
# |    value_loss         | 0.000243 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1016     |
# |    iterations         | 2200     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | -127     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 3.11e-05 |
# |    value_loss         | 7.78e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1017     |
# |    iterations         | 2300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.258   |
# |    explained_variance | -181     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00377 |
# |    value_loss         | 0.00401  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1018     |
# |    iterations         | 2400     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -70.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 4e-05    |
# |    value_loss         | 0.000179 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1019     |
# |    iterations         | 2500     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | -0.00675 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0105   |
# |    value_loss         | 0.000358 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1019     |
# |    iterations         | 2600     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.613   |
# |    explained_variance | -33.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0399   |
# |    value_loss         | 0.00162  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1020     |
# |    iterations         | 2700     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | -0.241   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0435  |
# |    value_loss         | 0.00509  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1021     |
# |    iterations         | 2800     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -0.037   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.00411 |
# |    value_loss         | 5.84e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 2900     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.701   |
# |    explained_variance | -0.235   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.00388 |
# |    value_loss         | 3.6e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 3000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 0.0532   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0132   |
# |    value_loss         | 0.000612 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1023     |
# |    iterations         | 3100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.437   |
# |    explained_variance | -0.0402  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00852 |
# |    value_loss         | 0.000132 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.135   |
# | time/                 |          |
# |    fps                | 1023     |
# |    iterations         | 3200     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | -3.59    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000665 |
# |    value_loss         | 2.01e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.00121 |
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 3300     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.0386  |
# |    explained_variance | -36.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 4.11e-06 |
# |    value_loss         | 5.19e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 3400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.0472   |
# |    explained_variance | -193      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -1.27e-05 |
# |    value_loss         | 2.81e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 3500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.0293   |
# |    explained_variance | -71.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -1.04e-07 |
# |    value_loss         | 2.67e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.00121 |
# | time/                 |          |
# |    fps                | 1022     |
# |    iterations         | 3600     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.0277  |
# |    explained_variance | -69.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.64e-07 |
# |    value_loss         | 1.6e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 3700      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.0566   |
# |    explained_variance | -234      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.000136 |
# |    value_loss         | 0.000272  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.00121 |
# | time/                 |          |
# |    fps                | 1023     |
# |    iterations         | 3800     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.126   |
# |    explained_variance | -154     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.000159 |
# |    value_loss         | 3.68e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 3900      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.0744   |
# |    explained_variance | -2.78e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 3.49e-05  |
# |    value_loss         | 8.12e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 4000      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.106    |
# |    explained_variance | -107      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.96e-05 |
# |    value_loss         | 8.45e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.00121 |
# | time/                 |          |
# |    fps                | 1024     |
# |    iterations         | 4100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | -762     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.000215 |
# |    value_loss         | 0.000242 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1024      |
# |    iterations         | 4200      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.603    |
# |    explained_variance | -1.24e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.0145   |
# |    value_loss         | 0.00703   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.00121  |
# | time/                 |           |
# |    fps                | 1023      |
# |    iterations         | 4300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.0593   |
# |    explained_variance | -3.47e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -1.27e-05 |
# |    value_loss         | 2.26e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.00121 |
# | time/                 |          |
# |    fps                | 1023     |
# |    iterations         | 4400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.018   |
# |    explained_variance | -8.37    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 2.73e-06 |
# |    value_loss         | 3.04e-06 |
# ...
# |    policy_loss        | 1.95e-05 |
# |    value_loss         | 4.25e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.14     |
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 7700      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.0543   |
# |    explained_variance | -168      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -1.38e-05 |
# |    value_loss         | 3.13e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.14     |
# | time/                 |           |
# |    fps                | 988       |
# |    iterations         | 7800      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -0.0514   |
# |    explained_variance | -3.68e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | 1.82e-06  |
# |    value_loss         | 7.26e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.14    |
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 7900     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.0346  |
# |    explained_variance | -70.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 1.03e-06 |
# |    value_loss         | 4.76e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.14     |
# | time/                 |           |
# |    fps                | 987       |
# |    iterations         | 8000      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.0202   |
# |    explained_variance | -9.33     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -7.99e-07 |
# |    value_loss         | 4.61e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 986      |
# |    iterations         | 8100     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.664   |
# |    explained_variance | -0.035   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.00611  |
# |    value_loss         | 0.000477 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 987      |
# |    iterations         | 8200     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.0533   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.0217   |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 987      |
# |    iterations         | 8300     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | -0.595   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | -0.00128 |
# |    value_loss         | 2e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 8400     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | 0.0421   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.0137   |
# |    value_loss         | 0.000953 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 8500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0.0547   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.00966  |
# |    value_loss         | 0.00155  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 989      |
# |    iterations         | 8600     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 0.00651  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.0962  |
# |    value_loss         | 0.0104   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | 0.0256    |
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8700      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.195    |
# |    explained_variance | -2.7      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000181 |
# |    value_loss         | 1.53e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | 0.0256    |
# | time/                 |           |
# |    fps                | 989       |
# |    iterations         | 8800      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.717    |
# |    explained_variance | 0.152     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.000448 |
# |    value_loss         | 5.06e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 990      |
# |    iterations         | 8900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.289   |
# |    explained_variance | -1.01    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 0.00137  |
# |    value_loss         | 0.000113 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 990      |
# |    iterations         | 9000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.391   |
# |    explained_variance | -0.601   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0168  |
# |    value_loss         | 0.00276  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 990      |
# |    iterations         | 9100     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -0.0433  |
# |    explained_variance | -11.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 7.82e-06 |
# |    value_loss         | 1.32e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 991      |
# |    iterations         | 9200     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.0984  |
# |    explained_variance | -34.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 1.23e-05 |
# |    value_loss         | 7.37e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | 0.0256    |
# | time/                 |           |
# |    fps                | 991       |
# |    iterations         | 9300      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -0.0141   |
# |    explained_variance | -109      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | -2.31e-07 |
# |    value_loss         | 1.67e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 992      |
# |    iterations         | 9400     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -0.00845 |
# |    explained_variance | 0.707    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 3.72e-06 |
# |    value_loss         | 1.51e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | 0.0256    |
# | time/                 |           |
# |    fps                | 992       |
# |    iterations         | 9500      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -0.0133   |
# |    explained_variance | -269      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | -8.16e-07 |
# |    value_loss         | 8.51e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | 0.0256   |
# | time/                 |          |
# |    fps                | 992      |
# |    iterations         | 9600     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.0122  |
# |    explained_variance | -2.94    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | -3.1e-07 |
# |    value_loss         | 1.12e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.125    |
# | time/                 |           |
# |    fps                | 993       |
# |    iterations         | 9700      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -0.54     |
# |    explained_variance | -0.191    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | -0.000845 |
# |    value_loss         | 3.09e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.05e+03  |
# |    ep_rew_mean        | -0.125    |
# | time/                 |           |
# |    fps                | 992       |
# |    iterations         | 9800      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -0.423    |
# |    explained_variance | -5.26     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -0.000473 |
# |    value_loss         | 4.94e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.125   |
# | time/                 |          |
# |    fps                | 992      |
# |    iterations         | 9900     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | -14.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | 7.61e-05 |
# |    value_loss         | 1.13e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.05e+03 |
# |    ep_rew_mean        | -0.125   |
# | time/                 |          |
# |    fps                | 993      |
# |    iterations         | 10000    |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.266   |
# |    explained_variance | 0.275    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | 0.000178 |
# |    value_loss         | 3.88e-06 |
# ------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.19336741460966936
# Cumulative Return: 1.933674146096693e-05
# Win Rate: 0.47637560918418304
# Profit Factor: 1.0689848857394182
# Sharpe Ratio: 0.01737020015528572
# Sortino Ratio: 0.030118588528974487
# Maximum Drawdown: 1.0399732137115012
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 14.104368984183962
# Cumulative Return: 0.001410436898418396
# Win Rate: 0.6340992754344142
# Profit Factor: 3.5641946133524858
# Sharpe Ratio: 0.3785905007190732
# Sortino Ratio: 1.0482376354984981
# Maximum Drawdown: 0.35894094453082176
