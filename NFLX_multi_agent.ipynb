# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NFLX_TRAINING.csv'
    test_file = 'NFLX_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1943 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1454         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054155514 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.809       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0308       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00619     |
# |    value_loss           | 0.0149       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1366       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00579786 |
# |    clip_fraction        | 0.0336     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.292      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.35e-05   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00884   |
# |    value_loss           | 0.0174     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007920922 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 0.00552     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008099712 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00455    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 1281         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0091953995 |
# |    clip_fraction        | 0.0894       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0165      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 0.0145       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 1257        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008530779 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00988     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009026346 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007442631 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.92       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00956     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 1067         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0077687255 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.411        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00193     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 0.0129       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 17         |
# | time/                   |            |
# |    fps                  | 1060       |
# |    iterations           | 11         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00888459 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.958     |
# |    explained_variance   | 0.0464     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0431    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.00584    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0071017863 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00249     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 1093        |
# |    iterations           | 13          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010362396 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008071614 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00458    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.00969     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 15          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010617472 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00328     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00762     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 16          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010717468 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 17          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006862704 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00257     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 18          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009593792 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00909    |
# |    value_loss           | 0.0082      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 1134        |
# |    iterations           | 19          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007266002 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000467    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 0.015       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 1142         |
# |    iterations           | 20           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0076134773 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00419     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00655     |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 36.4         |
# | time/                   |              |
# |    fps                  | 1145         |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0062266043 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 0.518        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00816      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 0.00968      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 36.4         |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0065460764 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.553        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0117      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00018     |
# |    value_loss           | 0.00993      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 36.4        |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 23          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015769567 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00333     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 36.4        |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 24          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007195997 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 40.7        |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 25          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007450641 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0158      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 0.00734     |
# -----------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 8.98816219051696
# Cumulative Return: 0.0008988162190516959
# Win Rate: 0.6632124352331606
# Profit Factor: 5.982421403582292
# Sharpe Ratio: 0.5082987105462757
# Sortino Ratio: 1.589829876044417
# Maximum Drawdown: 0.14870000331422073
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1758 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1445         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0102413595 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.482       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00123      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 0.0229       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1399        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007317123 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00622    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00922    |
# |    value_loss           | 0.0205      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 0.435       |
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005886797 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00632     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.00701     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 0.435       |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009967303 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0293      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.00857     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 0.435       |
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006482895 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00428    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 7.9          |
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0070443703 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0372      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 0.00863      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 7.9         |
# | time/                   |             |
# |    fps                  | 1301        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006985241 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 0.00684     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 7.9          |
# | time/                   |              |
# |    fps                  | 1301         |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0074919257 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.55         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0272      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 0.00811      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 7.9         |
# | time/                   |             |
# |    fps                  | 1293        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009460261 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0403     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012612903 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0431     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00702     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014789024 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 0.00833     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008546926 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.0111      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 24.8         |
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 14           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0092340475 |
# |    clip_fraction        | 0.0903       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00152     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.0118       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 24.8        |
# | time/                   |             |
# |    fps                  | 1285        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009624137 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 0.00836     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 24.8        |
# | time/                   |             |
# |    fps                  | 1277        |
# |    iterations           | 16          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011574472 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.0136      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 24.8        |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 17          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010200293 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.0125      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 31.4        |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009601524 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000438    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 0.00854     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 31.4        |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011805756 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00162     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 31.4        |
# | time/                   |             |
# |    fps                  | 1275        |
# |    iterations           | 20          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007623368 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00691    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 0.00997     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 1277        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008127501 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00761    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 37.4       |
# | time/                   |            |
# |    fps                  | 1272       |
# |    iterations           | 22         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01172906 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.807     |
# |    explained_variance   | 0.446      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0137    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.000176  |
# |    value_loss           | 0.00989    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 37.4         |
# | time/                   |              |
# |    fps                  | 1274         |
# |    iterations           | 23           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0085686445 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00267      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0064      |
# |    value_loss           | 0.0129       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 24          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007583664 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00612     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 0.0135      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 42           |
# | time/                   |              |
# |    fps                  | 1273         |
# |    iterations           | 25           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0060532847 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0143       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 0.00809      |
# ------------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 12.684715561463236
# Cumulative Return: 0.0012684715561463236
# Win Rate: 0.7606837606837606
# Profit Factor: 12.652270754354126
# Sharpe Ratio: 0.6185349475922497
# Sortino Ratio: 2.44628380743613
# Maximum Drawdown: 0.16387383922477494
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1858 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1518         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0073795198 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.66        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0284      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 0.0213       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1411         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0060866075 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00783      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00845     |
# |    value_loss           | 0.0214       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 6.87         |
# | time/                   |              |
# |    fps                  | 1387         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0064735836 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00681     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 0.00791      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 6.87        |
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009251381 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 6.87        |
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007986974 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0396     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 9.97        |
# | time/                   |             |
# |    fps                  | 1329        |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 5.45        |
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009011889 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0371     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00937     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 1305         |
# |    iterations           | 11           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0091085415 |
# |    clip_fraction        | 0.0791       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0351      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 0.00561      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 12          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009230455 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 0.00903     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 1299        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008416258 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00675    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00953     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009276381 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00835     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007626275 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.036       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 0.00714     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 21.2       |
# | time/                   |            |
# |    fps                  | 1297       |
# |    iterations           | 16         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00991847 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.893     |
# |    explained_variance   | 0.66       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0199    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0161    |
# |    value_loss           | 0.00981    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 1293        |
# |    iterations           | 17          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008322539 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00425     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007914892 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00267    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 0.00676     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012639664 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010448759 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 32.9       |
# | time/                   |            |
# |    fps                  | 1289       |
# |    iterations           | 21         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00813734 |
# |    clip_fraction        | 0.0951     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.793     |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0108    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00826   |
# |    value_loss           | 0.0106     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 32.9       |
# | time/                   |            |
# |    fps                  | 1291       |
# |    iterations           | 22         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00657902 |
# |    clip_fraction        | 0.0802     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.777     |
# |    explained_variance   | 0.607      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00315    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00169   |
# |    value_loss           | 0.00891    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 32.9       |
# | time/                   |            |
# |    fps                  | 1288       |
# |    iterations           | 23         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01199979 |
# |    clip_fraction        | 0.0978     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.774     |
# |    explained_variance   | 0.566      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00255   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00669   |
# |    value_loss           | 0.0122     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 24          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011911899 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0258     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 25          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011148626 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00216    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.00628     |
# -----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 11.414654131827774
# Cumulative Return: 0.0011414654131827774
# Win Rate: 0.7894736842105263
# Profit Factor: 19.612063584942426
# Sharpe Ratio: 0.7352639287432171
# Sortino Ratio: 3.969684725370118
# Maximum Drawdown: 0.11453644370796079
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 10.987743467620128
# Cumulative Return: 0.0010987743467620128
# Win Rate: 0.7562951720620628
# Profit Factor: 13.059216245359398
# Sharpe Ratio: 0.6461295178074812
# Sortino Ratio: 2.7144160775007418
# Maximum Drawdown: 0.1521876734710202
# --- Agent 1 Testing Metrics ---
# Total Profit: 22.91199580067223
# Cumulative Return: 0.002291199580067223
# Win Rate: 0.6370370370370371
# Profit Factor: 6.893924688963166
# Sharpe Ratio: 0.4060544843040344
# Sortino Ratio: 1.8384695436792704
# Maximum Drawdown: 0.22076525711250916
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 27.936598937369126
# Cumulative Return: 0.0027936598937369126
# Win Rate: 0.6888020833333334
# Profit Factor: 8.733727375653618
# Sharpe Ratio: 0.40873106969729067
# Sortino Ratio: 1.9693238192647828
# Maximum Drawdown: 0.1946820492268473
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 22.19055735726215
# Cumulative Return: 0.002219055735726215
# Win Rate: 0.6786324786324787
# Profit Factor: 5.681812010040585
# Sharpe Ratio: 0.38192923840164184
# Sortino Ratio: 1.3168392475159405
# Maximum Drawdown: 0.5929339364716668
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 23.137067388814103
# Cumulative Return: 0.00231370673888141
# Win Rate: 0.7280701754385965
# Profit Factor: 7.362747278196361
# Sharpe Ratio: 0.4349714192450858
# Sortino Ratio: 1.1936145810845091
# Maximum Drawdown: 0.5928980503796422
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 24.061771213588255
# Cumulative Return: 0.0024061771213588256
# Win Rate: 0.6840076561039179
# Profit Factor: 7.196046304834438
# Sharpe Ratio: 0.40878657030002563
# Sortino Ratio: 1.5772458298605931
# Maximum Drawdown: 0.40054750319957816

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NFLX_TRAINING.csv'
    test_file = 'NFLX_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14e+03 |
# |    ep_rew_mean      | 0.166    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1349     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000137 |
# |    n_updates        | 7118     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14e+03 |
# |    ep_rew_mean      | 7.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1339     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000276 |
# |    n_updates        | 7118     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14e+03 |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1340     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.87e-05 |
# |    n_updates        | 7118     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14e+03 |
# |    ep_rew_mean      | -5.06    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1346     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00079  |
# |    n_updates        | 7118     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.8183031853753278
# Cumulative Return: 0.00018183031853753276
# Win Rate: 0.526433798374555
# Profit Factor: 1.0688550975691946
# Sharpe Ratio: 0.01989522641777547
# Sortino Ratio: 0.029069576856416705
# Maximum Drawdown: 1.961319798879801
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 3.598843915779071
# Cumulative Return: 0.000359884391577907
# Win Rate: 0.5284872298624754
# Profit Factor: 1.3670577728542135
# Sharpe Ratio: 0.09939455409745386
# Sortino Ratio: 0.17879595459569964
# Maximum Drawdown: 0.8637818236120063

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NFLX_TRAINING.csv'
    test_file = 'NFLX_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=100000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | time/                 |           |
# |    fps                | 1036      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -2.88e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0292    |
# |    value_loss         | 0.00695   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 954      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -80.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0538   |
# |    value_loss         | 0.00332  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 949      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -41.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0284   |
# |    value_loss         | 0.00156  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 947      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -2.4e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0319   |
# |    value_loss         | 0.00208  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 941      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | -192     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.115    |
# |    value_loss         | 0.0067   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 941      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -738     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00499  |
# |    value_loss         | 0.0013   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -91.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00132  |
# |    value_loss         | 0.00183  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -136     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0294   |
# |    value_loss         | 0.00128  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 900       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -1.39e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.0134   |
# |    value_loss         | 0.000589  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 1000      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | -3.02e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.0129    |
# |    value_loss         | 0.000657  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -20.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0223  |
# |    value_loss         | 0.000724 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -503     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00392  |
# |    value_loss         | 0.000124 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -102     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.000153 |
# |    value_loss         | 0.000203 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 1400      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.891    |
# |    explained_variance | -1.92e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.0205   |
# |    value_loss         | 0.00146   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 1500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -628     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0211   |
# |    value_loss         | 0.000718 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 1600     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.979   |
# |    explained_variance | -29.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0225  |
# |    value_loss         | 0.000504 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 1700      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -1.06e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -0.0587   |
# |    value_loss         | 0.00247   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 1800     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -256     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0189   |
# |    value_loss         | 0.000243 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 1900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -613     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0117  |
# |    value_loss         | 0.00015  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 2000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.979   |
# |    explained_variance | -12.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00947 |
# |    value_loss         | 0.000113 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 2100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -19.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00492 |
# |    value_loss         | 3.97e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 2200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -34.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.00238 |
# |    value_loss         | 8.74e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 2300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | -32.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0176   |
# |    value_loss         | 0.000307 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 2400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.982    |
# |    explained_variance | -2.15e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.00203  |
# |    value_loss         | 1.18e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 2500     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.976   |
# |    explained_variance | -9.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00552  |
# |    value_loss         | 4.1e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 2600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -360     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00106  |
# |    value_loss         | 9.92e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 2700     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -138     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00485  |
# |    value_loss         | 2.97e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 2800      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.986    |
# |    explained_variance | -1.15e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.00263   |
# |    value_loss         | 6.15e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 2900     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.972   |
# |    explained_variance | -276     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.0156  |
# |    value_loss         | 0.000101 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 918      |
# |    iterations         | 3000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.964   |
# |    explained_variance | -21.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00158 |
# |    value_loss         | 6.85e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 919      |
# |    iterations         | 3100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -147     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.003   |
# |    value_loss         | 1.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 920      |
# |    iterations         | 3200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.884   |
# |    explained_variance | -7.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000183 |
# |    value_loss         | 3.15e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 3300     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -41.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000589 |
# |    value_loss         | 3.42e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 3400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.956   |
# |    explained_variance | -19.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00276  |
# |    value_loss         | 7.57e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 3500     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -23.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00606  |
# |    value_loss         | 4.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 3600     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -94.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00358  |
# |    value_loss         | 1.53e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 3700     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -258     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00169  |
# |    value_loss         | 3.09e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 3800     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.958   |
# |    explained_variance | -4.73    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00197  |
# |    value_loss         | 6.59e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 3900     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.999   |
# |    explained_variance | -35.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00218 |
# |    value_loss         | 1.97e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 4000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.754   |
# |    explained_variance | -20.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000567 |
# |    value_loss         | 5.4e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 923       |
# |    iterations         | 4100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.987    |
# |    explained_variance | -2.59e+06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.00031  |
# |    value_loss         | 4.57e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 4200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -275      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.000345 |
# |    value_loss         | 1.48e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 4300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -29.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000991 |
# |    value_loss         | 1.93e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 4400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.962   |
# |    explained_variance | -45      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.000294 |
# |    value_loss         | 4.99e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 4500      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.956    |
# |    explained_variance | -7.25     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.000178 |
# |    value_loss         | 1.57e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 4600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -160     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00165 |
# |    value_loss         | 4.55e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 4700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -75.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.000242 |
# |    value_loss         | 7.61e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 4800      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -5.81     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.000398 |
# |    value_loss         | 1.55e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 4900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -3.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00283 |
# |    value_loss         | 8.72e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 5000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.988   |
# |    explained_variance | -0.809   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.000185 |
# |    value_loss         | 6.62e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5100     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -3.88    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00168 |
# |    value_loss         | 2.4e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5200     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -6.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.00142 |
# |    value_loss         | 1.56e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.95    |
# |    explained_variance | -334     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.00562 |
# |    value_loss         | 2.92e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5400     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.675   |
# |    explained_variance | -53.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.000759 |
# |    value_loss         | 1.13e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | -93.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 5.24e-05 |
# |    value_loss         | 7.51e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.927   |
# |    explained_variance | -9.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00222 |
# |    value_loss         | 9.45e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 5700      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -51.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000799 |
# |    value_loss         | 1.61e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.999   |
# |    explained_variance | -12.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00187 |
# |    value_loss         | 4.07e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 5900     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -41.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.00299 |
# |    value_loss         | 8.2e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6000     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.96    |
# |    explained_variance | -16.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0043  |
# |    value_loss         | 4.43e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6100     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -61.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.00389  |
# |    value_loss         | 3.07e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6200     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -826     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.000885 |
# |    value_loss         | 1.08e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6300     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -5.39    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.00105 |
# |    value_loss         | 1.29e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 6400     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -93.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 4.39e-05 |
# |    value_loss         | 4.04e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -4.57    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00313  |
# |    value_loss         | 9.57e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6600     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -13.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.003   |
# |    value_loss         | 9.45e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6700     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.993   |
# |    explained_variance | -17.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.00306 |
# |    value_loss         | 4.62e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6800     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.61     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00198 |
# |    value_loss         | 2.78e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 6900     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.904   |
# |    explained_variance | -2.6e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.000916 |
# |    value_loss         | 7.58e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 926       |
# |    iterations         | 7000      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -3.76     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000193 |
# |    value_loss         | 3.15e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 7100     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -42.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.00095 |
# |    value_loss         | 1.98e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 926       |
# |    iterations         | 7200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.925    |
# |    explained_variance | -75.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0.000472 |
# |    value_loss         | 5.92e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 926       |
# |    iterations         | 7300      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -1.26e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -0.00157  |
# |    value_loss         | 5.45e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 926       |
# |    iterations         | 7400      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.91     |
# |    explained_variance | -70.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -0.000434 |
# |    value_loss         | 4.59e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 927       |
# |    iterations         | 7500      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -0.972    |
# |    explained_variance | -654      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0.000357 |
# |    value_loss         | 1.6e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 7600     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -12.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.00177  |
# |    value_loss         | 2.8e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 7700      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -2.85     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.000602 |
# |    value_loss         | 5.38e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 7800     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | -154     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.00055  |
# |    value_loss         | 2.25e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# ...
# |    n_updates          | 17599    |
# |    policy_loss        | 1.37e-06 |
# |    value_loss         | 6.35e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 721      |
# |    iterations         | 17700    |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 88500    |
# | train/                |          |
# |    entropy_loss       | -0.00542 |
# |    explained_variance | -9.57    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | 1.66e-06 |
# |    value_loss         | 8.31e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 721      |
# |    iterations         | 17800    |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.00619 |
# |    explained_variance | -0.734   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 3.46e-07 |
# |    value_loss         | 2.63e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 722      |
# |    iterations         | 17900    |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.00463 |
# |    explained_variance | -9.62    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | -9.5e-08 |
# |    value_loss         | 1.02e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 722      |
# |    iterations         | 18000    |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.00429 |
# |    explained_variance | -344     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 6.6e-08  |
# |    value_loss         | 7.36e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 722      |
# |    iterations         | 18100    |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.00482 |
# |    explained_variance | -44.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 1.71e-06 |
# |    value_loss         | 1.45e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 722       |
# |    iterations         | 18200     |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.00467  |
# |    explained_variance | -6.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -2.22e-07 |
# |    value_loss         | 3.68e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 723       |
# |    iterations         | 18300     |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.00475  |
# |    explained_variance | -1.74     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -3.28e-07 |
# |    value_loss         | 4.66e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 18400    |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.00544 |
# |    explained_variance | -3.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 1.69e-06 |
# |    value_loss         | 1.23e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 18500    |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -0.00399 |
# |    explained_variance | -8.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 1.4e-07  |
# |    value_loss         | 2.47e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 18600    |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.00515 |
# |    explained_variance | -1.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 4.85e-07 |
# |    value_loss         | 2.9e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 18700    |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.00435 |
# |    explained_variance | -135     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 2.44e-06 |
# |    value_loss         | 2.75e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 18800    |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.00319 |
# |    explained_variance | -27.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 3.28e-07 |
# |    value_loss         | 2.14e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 724       |
# |    iterations         | 18900     |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.0037   |
# |    explained_variance | -6.73     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -2.03e-09 |
# |    value_loss         | 3.31e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 724       |
# |    iterations         | 19000     |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.00405  |
# |    explained_variance | -75       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -2.65e-07 |
# |    value_loss         | 5.87e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 19100    |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.00518 |
# |    explained_variance | -21      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 3.82e-07 |
# |    value_loss         | 7.12e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 19200    |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.00743 |
# |    explained_variance | -4.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 1.06e-06 |
# |    value_loss         | 1.87e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 725       |
# |    iterations         | 19300     |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.00899  |
# |    explained_variance | -96.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | -9.53e-08 |
# |    value_loss         | 1.27e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 19400    |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.0112  |
# |    explained_variance | -17.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 1.7e-06  |
# |    value_loss         | 3.17e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 726       |
# |    iterations         | 19500     |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.0301   |
# |    explained_variance | -7.08     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -5.44e-07 |
# |    value_loss         | 2.33e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 726      |
# |    iterations         | 19600    |
# |    time_elapsed       | 134      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.0287  |
# |    explained_variance | -2       |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 9.31e-07 |
# |    value_loss         | 1.18e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 726       |
# |    iterations         | 19700     |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.0201   |
# |    explained_variance | -25.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -9.29e-07 |
# |    value_loss         | 1.23e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -7.14     |
# | time/                 |           |
# |    fps                | 726       |
# |    iterations         | 19800     |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.0219   |
# |    explained_variance | -41.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -4.13e-07 |
# |    value_loss         | 3.36e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 727      |
# |    iterations         | 19900    |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.0151  |
# |    explained_variance | -319     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 8.42e-07 |
# |    value_loss         | 5.33e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -7.14    |
# | time/                 |          |
# |    fps                | 727      |
# |    iterations         | 20000    |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.0152  |
# |    explained_variance | -70.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 5.02e-07 |
# |    value_loss         | 1.12e-07 |
# ------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 2.150602693193966
# Cumulative Return: 0.00021506026931939655
# Win Rate: 0.6046842839850937
# Profit Factor: 2.791647937628012
# Sharpe Ratio: 0.4276166977708063
# Sortino Ratio: 1.105336674012756
# Maximum Drawdown: 0.7159051913219505
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 3.310444204150098
# Cumulative Return: 0.0003310444204150099
# Win Rate: 0.4954630659767672
# Profit Factor: 3.3672714156469326
# Sharpe Ratio: 0.4958059699194185
# Sortino Ratio: 2.321331515344581
# Maximum Drawdown: 1.3378212788082011

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NFLX_TRAINING.csv'
    test_file = 'NFLX_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1443 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1116        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010230035 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -7.41       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0274     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 0.0214      |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1037      |
# |    iterations           | 3         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0070756 |
# |    clip_fraction        | 0.0583    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.09     |
# |    explained_variance   | 0.221     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0138   |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0123   |
# |    value_loss           | 0.0166    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | -3.21        |
# | time/                   |              |
# |    fps                  | 971          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0096883075 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.43         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 0.00827      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | -3.21        |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0044483375 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0925       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0318      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00716     |
# |    value_loss           | 0.0071       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | -3.21        |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071737776 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.08         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0262      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.016       |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 3.11        |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007772221 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0138      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00957     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 3.11        |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008591764 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0755      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00646     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 3.11        |
# | time/                   |             |
# |    fps                  | 876         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011399044 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | -0.371      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00963     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00882     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 3.11        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009768081 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.011       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0076799933 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0244      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00944     |
# |    value_loss           | 0.00774      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010566272 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00203    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 13           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0083526205 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0305      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 0.0106       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010204675 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00092     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00925     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 21.8         |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 15           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0120764095 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00652      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 0.00617      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 16          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008638449 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00328     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007627234 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00284    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 28.4         |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 18           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0063530616 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0226      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.007       |
# |    value_loss           | 0.00677      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 28.4        |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 19          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008891133 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00695    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 28.4        |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009784246 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0245     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00987     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 34.1         |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 21           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0067515243 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0436      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00802     |
# |    value_loss           | 0.00852      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010549574 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00387    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.00896     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.14e+03   |
# |    ep_rew_mean          | 34.1       |
# | time/                   |            |
# |    fps                  | 863        |
# |    iterations           | 23         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00905312 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.779     |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0138    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00492   |
# |    value_loss           | 0.0135     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009089898 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00697    |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 39          |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 25          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009502252 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00373    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 0.00705     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.14e+03 |
# |    ep_rew_mean      | 5.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1004     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000428 |
# |    n_updates        | 7118     |
# ----------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 773      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -15.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.00565 |
# |    value_loss         | 0.000205 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 788      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -52.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.166   |
# |    value_loss         | 0.0193   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -1.71    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00255 |
# |    value_loss         | 0.000362 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -27.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.415   |
# |    value_loss         | 0.154    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 771      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -5.44    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.108    |
# |    value_loss         | 0.016    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 775      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | -68.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0193   |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 774      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -0.928   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00671  |
# |    value_loss         | 0.000983 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 760      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -5.94    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0271  |
# |    value_loss         | 0.00863  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 717      |
# |    iterations         | 900      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -1.34    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0564  |
# |    value_loss         | 0.00202  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 698      |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.843   |
# |    explained_variance | -5.05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0824   |
# |    value_loss         | 0.00364  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 1100      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.876    |
# |    explained_variance | -8.16e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.00278   |
# |    value_loss         | 0.00011   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 708      |
# |    iterations         | 1200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.518   |
# |    explained_variance | -1.62    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00817  |
# |    value_loss         | 0.000134 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 700      |
# |    iterations         | 1300     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | -0.319   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.00457  |
# |    value_loss         | 7.09e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 696      |
# |    iterations         | 1400     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | -5.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00195 |
# |    value_loss         | 1.39e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -2.1      |
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 1500      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.854    |
# |    explained_variance | -4.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.000639 |
# |    value_loss         | 4.01e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 708      |
# |    iterations         | 1600     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | -0.00517 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.416    |
# |    value_loss         | 0.142    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 713      |
# |    iterations         | 1700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -7.9     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00735 |
# |    value_loss         | 6.38e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 718      |
# |    iterations         | 1800     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -152     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.0339   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -2.1      |
# | time/                 |           |
# |    fps                | 718       |
# |    iterations         | 1900      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.995    |
# |    explained_variance | -1.55e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -0.000987 |
# |    value_loss         | 0.000114  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 717      |
# |    iterations         | 2000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -1.51    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.144    |
# |    value_loss         | 0.0161   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -2.1      |
# | time/                 |           |
# |    fps                | 720       |
# |    iterations         | 2100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.835    |
# |    explained_variance | -9.55e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.0479   |
# |    value_loss         | 0.00319   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 2200     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -140     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.023   |
# |    value_loss         | 0.000956 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 721      |
# |    iterations         | 2300     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -2.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0346  |
# |    value_loss         | 0.00191  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 2400     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -3.56    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0478  |
# |    value_loss         | 0.00293  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 2500     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.89    |
# |    explained_variance | -1.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.053    |
# |    value_loss         | 0.00757  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 726      |
# |    iterations         | 2600     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.891   |
# |    explained_variance | -7.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00418  |
# |    value_loss         | 9.9e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | -2.1     |
# | time/                 |          |
# |    fps                | 728      |
# |    iterations         | 2700     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | -0.455   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00728  |
# |    value_loss         | 9.59e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | -2.1      |
# | time/                 |           |
# |    fps                | 731       |
# |    iterations         | 2800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.584    |
# |    explained_variance | -1.52e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -0.00024  |
# |    value_loss         | 2.23e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 733      |
# |    iterations         | 2900     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.254   |
# |    explained_variance | -81.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000191 |
# |    value_loss         | 2.36e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 0.174     |
# | time/                 |           |
# |    fps                | 733       |
# |    iterations         | 3000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.377    |
# |    explained_variance | -2.63     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -5.37e-05 |
# |    value_loss         | 1.69e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 735      |
# |    iterations         | 3100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.897   |
# |    explained_variance | -0.654   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0248  |
# |    value_loss         | 0.00129  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 737      |
# |    iterations         | 3200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | -0.107   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0101  |
# |    value_loss         | 0.000305 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 739      |
# |    iterations         | 3300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -4.44    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0123   |
# |    value_loss         | 0.000387 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 737      |
# |    iterations         | 3400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.883   |
# |    explained_variance | 0.00703  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0589   |
# |    value_loss         | 0.00276  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 729      |
# |    iterations         | 3500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.315    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0669   |
# |    value_loss         | 0.00608  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 723      |
# |    iterations         | 3600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.504    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0308   |
# |    value_loss         | 0.00094  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 710      |
# |    iterations         | 3700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.972   |
# |    explained_variance | 0.271    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0216   |
# |    value_loss         | 0.000517 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 690      |
# |    iterations         | 3800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.225    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00316  |
# |    value_loss         | 0.000157 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 681      |
# |    iterations         | 3900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -3.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0155  |
# |    value_loss         | 0.000233 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 4000     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -0.759   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0134  |
# |    value_loss         | 0.000364 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 4100     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.144    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.00771  |
# |    value_loss         | 6.43e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 0.174    |
# | time/                 |          |
# |    fps                | 666      |
# |    iterations         | 4200     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.867   |
# |    explained_variance | -0.317   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00246 |
# |    value_loss         | 9.28e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.23     |
# | time/                 |          |
# |    fps                | 662      |
# |    iterations         | 4300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.787   |
# |    explained_variance | -0.648   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000118 |
# |    value_loss         | 5.02e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.23     |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 4400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 22000    |
# ...
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.00277 |
# |    value_loss         | 5.64e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 789      |
# |    iterations         | 7700     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.564   |
# |    explained_variance | -0.00949 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -0.00515 |
# |    value_loss         | 0.00023  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 789      |
# |    iterations         | 7800     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.711   |
# |    explained_variance | -914     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.0423  |
# |    value_loss         | 0.00241  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 789      |
# |    iterations         | 7900     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.511   |
# |    explained_variance | -48.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | -0.00971 |
# |    value_loss         | 0.000489 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 2.77      |
# | time/                 |           |
# |    fps                | 790       |
# |    iterations         | 8000      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.302    |
# |    explained_variance | -0.434    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -0.000177 |
# |    value_loss         | 6.07e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 8100     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | -497     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.153    |
# |    value_loss         | 0.0296   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 2.77      |
# | time/                 |           |
# |    fps                | 790       |
# |    iterations         | 8200      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -2.39e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -0.0224   |
# |    value_loss         | 0.00153   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 8300     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.259   |
# |    explained_variance | -0.643   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.000223 |
# |    value_loss         | 1.08e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 2.77     |
# | time/                 |          |
# |    fps                | 790      |
# |    iterations         | 8400     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.0945  |
# |    explained_variance | -19.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 4.85e-06 |
# |    value_loss         | 7.97e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 2.77      |
# | time/                 |           |
# |    fps                | 790       |
# |    iterations         | 8500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -0.088    |
# |    explained_variance | -250      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -9.42e-08 |
# |    value_loss         | 4.95e-10  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 8600     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.548   |
# |    explained_variance | -0.0208  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.0181  |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 8700     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | -2.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | -0.0679  |
# |    value_loss         | 0.0164   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 8800     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.64    |
# |    explained_variance | -0.593   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 0.0108   |
# |    value_loss         | 0.00106  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 8900     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0.27     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 0.0114   |
# |    value_loss         | 0.000381 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 9000     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | -0.0694  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0218  |
# |    value_loss         | 0.00586  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9100     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -0.664   |
# |    explained_variance | -8.82    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | -0.00187 |
# |    value_loss         | 2.3e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.638   |
# |    explained_variance | 0.108    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | -0.00204 |
# |    value_loss         | 0.000246 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9300     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.0473  |
# |    explained_variance | -0.239   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | -6.5e-05 |
# |    value_loss         | 8.1e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9400     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -0.0216  |
# |    explained_variance | -50.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 7.51e-07 |
# |    value_loss         | 9.59e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 3.31      |
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 9500      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -0.0307   |
# |    explained_variance | -5.76     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | -6.88e-06 |
# |    value_loss         | 3.18e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9600     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.948   |
# |    explained_variance | -2.34    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | -0.00316 |
# |    value_loss         | 0.000187 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.14e+03 |
# |    ep_rew_mean        | 3.31     |
# | time/                 |          |
# |    fps                | 792      |
# |    iterations         | 9700     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -0.569   |
# |    explained_variance | -1.2e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | -0.00654 |
# |    value_loss         | 0.00142  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 3.31      |
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 9800      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -0.0211   |
# |    explained_variance | -4.57e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -7.65e-08 |
# |    value_loss         | 2.51e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 3.31      |
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 9900      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -0.0212   |
# |    explained_variance | -29.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | -5.97e-08 |
# |    value_loss         | 7.14e-10  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.14e+03  |
# |    ep_rew_mean        | 3.31      |
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 10000     |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -0.0198   |
# |    explained_variance | -19.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | -3.88e-07 |
# |    value_loss         | 2.14e-08  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 7.907532942393601
# Cumulative Return: 0.00079075329423936
# Win Rate: 0.5728702581013124
# Profit Factor: 1.9195554051557744
# Sharpe Ratio: 0.1583689278847564
# Sortino Ratio: 0.36966838113198097
# Maximum Drawdown: 0.8199328807420527
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 19.41280259630613
# Cumulative Return: 0.0019412802596306129
# Win Rate: 0.6366429870223571
# Profit Factor: 4.301802843089562
# Sharpe Ratio: 0.3095345394423888
# Sortino Ratio: 1.1942870877472944
# Maximum Drawdown: 0.8104955056071071
