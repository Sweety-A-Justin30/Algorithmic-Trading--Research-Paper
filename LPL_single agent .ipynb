# %%
#ppo algorithm single agent
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.log = []  # Log for detailed reporting
        self.scaler = scaler  # Store the scaler for inverse scaling

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        self.log = []  # Reset log

        # Log initial holdings
        self.log.append(f"Agent starts with 0 holdings (neutral position), Initial Balance: {self.balance}")
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        return obs

    def inverse_scale_price(self, price):
        # Inverse transform the scaled price to get the original value (considering the 'close' column)
        inverse_scaled = self.scaler.inverse_transform([[0, 0, 0, price, 0]])[0][3]
        return inverse_scaled

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        original_price = self.inverse_scale_price(current_price)  # Get original (inverse-scaled) price

        # If agent buys
        if action == 1:
            if self.position == 0:  # Only buy if neutral
                self.position = 1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent buys at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Long")
            elif self.position == -1:  # Close short position
                reward = self.entry_price - current_price  # Scaled reward
                original_reward = self.inverse_scale_price(self.entry_price) - original_price
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes short at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        # If agent sells
        elif action == 2:
            if self.position == 0:  # Only sell if neutral
                self.position = -1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent sells (short) at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Short")
            elif self.position == 1:  # Close long position
                reward = current_price - self.entry_price  # Scaled reward
                original_reward = original_price - self.inverse_scale_price(self.entry_price)
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes long at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

    def generate_report(self):
        print("\n--- Agent Report ---")
        for log in self.log:
            print(log)
        print(f"Final Balance: {self.balance}")
        print(f"Total Profit: {self.balance - self.initial_balance}")
        print(f"Number of Holdings (Long): {1 if self.position == 1 else 0}, Short: {1 if self.position == -1 else 0}")
        print("-" * 40)

# Function to calculate additional metrics
def calculate_metrics(trades, initial_balance, final_balance):
    # Total Profit
    total_profit = final_balance - initial_balance

    # Cumulative Return
    cumulative_return = (final_balance - initial_balance) / initial_balance

    # Win Rate
    positive_trades = [trade for trade in trades if trade > 0]
    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Profit Factor
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf

    # Sharpe Ratio
    returns = np.array(trades)
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    sharpe_ratio = mean_return / std_return if std_return != 0 else 0

    # Sortino Ratio (using only downside standard deviation)
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = mean_return / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    balance_series = np.cumsum([initial_balance] + trades)  # Series of balance over time
    peak_balance = np.maximum.accumulate(balance_series)
    drawdowns = (peak_balance - balance_series) / peak_balance
    max_drawdown = np.max(drawdowns) if drawdowns.size > 0 else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Train and evaluate the model with all metrics
def train_and_evaluate():
    # Load and normalize the data
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Create the environment using the training data
    env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)

    # Initialize the PPO model and train
    model = PPO("MlpPolicy", env_train, verbose=1)
    model.learn(total_timesteps=100000)

    # Test the model on the training data
    obs, _ = env_train.reset()
    done = False
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_train.step(action)

    # Generate report for the training session
    env_train.generate_report()

    # Calculate and display metrics for the training period
    training_metrics = calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance)
    print("\n--- Training Metrics ---")
    for metric, value in training_metrics.items():
        print(f"{metric}: {value}")

    # Test the model on the testing data
    env_test = SingleAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_test.step(action)

    # Generate report for the testing session
    env_test.generate_report()

    # Calculate and display metrics for the testing period
    testing_metrics = calculate_metrics(env_test.trades, env_test.initial_balance, env_test.balance)
    print("\n--- Testing Metrics ---")
    for metric, value in testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1647 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009475296 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.93       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00911     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 0.0158      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | -0.605       |
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046062293 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00776     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00681     |
# |    value_loss           | 0.0158       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | -0.605      |
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009260123 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0404     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 0.828       |
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009827054 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 0.828        |
# | time/                   |              |
# |    fps                  | 1238         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0075495047 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0293      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.00643      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.62        |
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011912257 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0304     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 0.00804     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.62        |
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007955194 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.047      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00584    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.00764     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 3.62        |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007391572 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0484     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00336    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 0.00604     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.12        |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009055043 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.0662      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.0087      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 7.12        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008226104 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.0261      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 0.00546     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0066246865 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00499     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00915     |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 1126        |
# |    iterations           | 13          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009556044 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.00858     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 13.2       |
# | time/                   |            |
# |    fps                  | 1126       |
# |    iterations           | 14         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01006434 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.899     |
# |    explained_variance   | 0.395      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0272    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.00798    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 1127         |
# |    iterations           | 15           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0058968817 |
# |    clip_fraction        | 0.0924       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00199     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00748     |
# |    value_loss           | 0.0088       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 1137        |
# |    iterations           | 16          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009470768 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0194     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009520125 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.00863     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 1151        |
# |    iterations           | 18          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026970368 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 0.00804     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 19          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008758964 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00791    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00842     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 20          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018726375 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.00875     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.78e+03   |
# |    ep_rew_mean          | 19         |
# | time/                   |            |
# |    fps                  | 1147       |
# |    iterations           | 21         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01425243 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.803     |
# |    explained_variance   | 0.628      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0703     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00761   |
# |    value_loss           | 0.00866    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 1153         |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0065078484 |
# |    clip_fraction        | 0.0958       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0244      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00702     |
# |    value_loss           | 0.00911      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 23          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008897498 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 0.00845     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 24          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011405788 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 0.00882     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.78e+03     |
# |    ep_rew_mean          | 21.1         |
# | time/                   |              |
# |    fps                  | 1162         |
# |    iterations           | 25           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0108839255 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.542        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0171       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00754     |
# |    value_loss           | 0.00929      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 26          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009889657 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0349     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 0.00982     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 27          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006161867 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0174      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 0.00889     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 28          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011712952 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | -0.115      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0404     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00899    |
# |    value_loss           | 0.00697     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 29          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010363362 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 0.00871     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 30          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010033671 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0225      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000238   |
# |    value_loss           | 0.00795     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 31          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.016244246 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0142     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00271    |
# |    value_loss           | 0.00768     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 32          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011029489 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00759     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 0.00997     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 33          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012839996 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000812    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 0.0083      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 1184        |
# |    iterations           | 34          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016661648 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0339      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 0.00991     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 1187        |
# |    iterations           | 35          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013714211 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00564    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 0.00739     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 36          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008029057 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00998     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 37          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009406635 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00973    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 0.00736     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 38          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008521704 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00771    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 0.0079      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 39          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012897672 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 30.6        |
# | time/                   |             |
# |    fps                  | 1190        |
# |    iterations           | 40          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018724192 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 0.0095      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 30.6        |
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 41          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018045606 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 0.00958     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 42          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.027166732 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0341     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 0.00781     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 1177        |
# |    iterations           | 43          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010146383 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00725     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 44          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015859107 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0076     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.000331    |
# |    value_loss           | 0.00921     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 32.4        |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 45          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009653807 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 0.00995     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 32.4        |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 46          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011411659 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00492    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 33.2        |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 47          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011420738 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00277    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0067     |
# |    value_loss           | 0.00956     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 33.2        |
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 48          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012847669 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 0.00911     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.78e+03    |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 49          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008958599 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00667    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 0.00732     |
# -----------------------------------------
#
# --- Agent Report ---
# Agent starts with 0 holdings (neutral position), Initial Balance: 10000
# Agent buys at 7.07, Current Balance: 10000, Holdings: 1 Long
# Agent closes long at 7.075, profit: 0.004999999999999893, Current Balance: 10000.005, Holdings: 0
# Agent buys at 7.1, Current Balance: 10000.005, Holdings: 1 Long
# Agent closes long at 7.12, profit: 0.020000000000000462, Current Balance: 10000.025, Holdings: 0
# Agent sells (short) at 7.14, Current Balance: 10000.025, Holdings: 1 Short
# Agent closes short at 6.83, profit: 0.3099999999999996, Current Balance: 10000.335, Holdings: 0
# Agent buys at 6.855, Current Balance: 10000.335, Holdings: 1 Long
# Agent closes long at 6.98, profit: 0.125, Current Balance: 10000.46, Holdings: 0
# Agent sells (short) at 6.97, Current Balance: 10000.46, Holdings: 1 Short
# Agent closes short at 6.98, profit: -0.010000000000000675, Current Balance: 10000.449999999999, Holdings: 0
# Agent sells (short) at 6.98, Current Balance: 10000.449999999999, Holdings: 1 Short
# Agent closes short at 6.9, profit: 0.08000000000000007, Current Balance: 10000.529999999999, Holdings: 0
# Agent sells (short) at 6.96, Current Balance: 10000.529999999999, Holdings: 1 Short
# Agent closes short at 6.81, profit: 0
# Agent closes long at 6.55, profit: 0.03000000000000025, Current Balance: 10001.53, Holdings: 0
# Agent sells (short) at 6.57, Current Balance: 10001.53, Holdings: 1 Short
# Agent closes short at 6.4243, profit: 0.1457000000000006, Current Balance: 10001.6757, Holdings: 0
# Agent buys at 6.43, Current Balance: 10001.6757, Holdings: 1 Long
# Agent closes long at 6.45, profit: 0.020000000000000462, Current Balance: 10001.6957, Holdings: 0
# Agent buys at 6.45, Current Balance: 10001.6957, Holdings: 1 Long
# Agent closes long at 6.425, profit: -0.025000000000000355, Current Balance: 10001.6707, Holdings: 0
# Agent sells (short) at 6.42, Current Balance: 10001.6707, Holdings: 1 Short
# Agent closes short at 6.19, profit: 0.22999999999999954, Current Balance: 10001.9007, Holdings: 0
# Agent sells (short) at 6.25, Current Balance: 10001.9007, Holdings: 1 Short
# ...
# Agent sells (short) at 4.87, Current Balance: 10031.383800000001, Holdings: 1 Short
# Agent closes short at 4.789999999999999, profit: 0.08000000000000096, Current Balance: 10031.463800000001, Holdings: 0
# Agent sells (short) at 4.7499, Current Balance: 10031.463800000001, Holdings: 1 Short
# Agent closes short at 4.715, profit: 0.034900000000000375, Current Balance: 10031.498700000002, Holdings: 0
# Agent buys at 4.73, Current Balance: 10031.498700000002, Holdings: 1 Long
# Agent closes long at 4.72, profit: -0.010000000000000675, Current Balance: 10031.488700000002, Holdings: 0
# Agent sells (short) at 4.71, Current Balance: 10031.488700000002, Holdings: 1 Short
# Agent closes short at 4.725, profit: -0.01499999999999968, Current Balance: 10031.473700000002, Holdings: 0
# Agent buys at 4.75, Current Balance: 10031.473700000002, Holdings: 1 Long
# Agent closes long at 4.74, profit: -0.009999999999999787, Current Balance: 10031.463700000002, Holdings: 0
# Agent sells (short) at 4.96, Current Balance: 10031.463700000002, Holdings: 1 Short
# Agent closes short at 4.605, profit: 0.35499999999999954, Current Balance: 10031.818700000002, Holdings: 0
# Agent buys at 4.635, Current Balance: 10031.818700000002, Holdings: 1 Long
# Agent closes long at 4.745, profit: 0.11000000000000032, Current Balance: 10031.928700000002, Holdings: 0
# Agent sells (short) at 4.785, Current Balance: 10031.928700000002, Holdings: 1 Short
# Agent closes short at 4.605, profit: 0.17999999999999972, Current Balance: 10032.108700000003, Holdings: 0
# Agent sells (short) at 4.605, Current Balance: 10032.108700000003, Holdings: 1 Short
# Agent closes short at 4.62, profit: -0.01499999999999968, Current Balance: 10032.093700000003, Holdings: 0
# Agent buys at 4.595, Current Balance: 10032.093700000003, Holdings: 1 Long
# Agent closes long at 4.9, profit: 0.3050000000000006, Current Balance: 10032.398700000003, Holdings: 0
# Agent buys at 4.97, Current Balance: 10032.398700000003, Holdings: 1 Long
# Agent closes long at 5.065, profit: 0.09500000000000064, Current Balance: 10032.493700000003, Holdings: 0
# Agent buys at 5.085, Current Balance: 10032.493700000003, Holdings: 1 Long
# Agent closes long at 5.065, profit: -0.019999999999999574, Current Balance: 10032.473700000002, Holdings: 0
# Agent buys at 5.05, Current Balance: 10032.473700000002, Holdings: 1 Long
# Agent closes long at 5.14, profit: 0.08999999999999986, Current Balance: 10032.563700000002, Holdings: 0
# Agent buys at 5.115, Current Balance: 10032.563700000002, Holdings: 1 Long
# Agent closes long at 5.085, profit: -0.03000000000000025, Current Balance: 10032.533700000002, Holdings: 0
# Agent sells (short) at 5.105, Current Balance: 10032.533700000002, Holdings: 1 Short
# Agent closes short at 4.875, profit: 0.23000000000000043, Current Balance: 10032.763700000001, Holdings: 0
# Agent buys at 4.87, Current Balance: 10032.763700000001, Holdings: 1 Long
# Agent closes long at 5.02, profit: 0.14999999999999947, Current Balance: 10032.913700000001, Holdings: 0
# Agent buys at 5.06, Current Balance: 10032.913700000001, Holdings: 1 Long
# Agent closes long at 5.02, profit: -0.040000000000000036, Current Balance: 10032.8737, Holdings: 0
# Agent buys at 5.095, Current Balance: 10032.8737, Holdings: 1 Long
# Agent closes long at 5.155, profit: 0.0600000000000005, Current Balance: 10032.9337, Holdings: 0
# Agent sells (short) at 5.165, Current Balance: 10032.9337, Holdings: 1 Short
# Agent closes short at 5.05, profit: 0.11500000000000021, Current Balance: 10033.0487, Holdings: 0
# Agent buys at 5.045, Current Balance: 10033.0487, Holdings: 1 Long
# Agent closes long at 5.085, profit: 0.040000000000000036, Current Balance: 10033.0887, Holdings: 0
# Agent sells (short) at 5.085, Current Balance: 10033.0887, Holdings: 1 Short
# Agent closes short at 4.89, profit: 0.19500000000000028, Current Balance: 10033.2837, Holdings: 0
# Agent sells (short) at 4.89, Current Balance: 10033.2837, Holdings: 1 Short
# Agent closes short at 4.71, profit: 0.17999999999999972, Current Balance: 10033.4637, Holdings: 0
# Agent sells (short) at 4.71, Current Balance: 10033.4637, Holdings: 1 Short
# Agent closes short at 4.705, profit: 0.004999999999999893, Current Balance: 10033.4687, Holdings: 0
# Agent sells (short) at 4.715, Current Balance: 10033.4687, Holdings: 1 Short
# Agent closes short at 4.7, profit: 0.01499999999999968, Current Balance: 10033.483699999999, Holdings: 0
# Agent sells (short) at 4.71, Current Balance: 10033.483699999999, Holdings: 1 Short
# Agent closes short at 4.47, profit: 0.2400000000000002, Current Balance: 10033.723699999999, Holdings: 0
# Agent buys at 4.42, Current Balance: 10033.723699999999, Holdings: 1 Long
# Agent closes long at 4.44, profit: 0.020000000000000462, Current Balance: 10033.743699999999, Holdings: 0
# Agent buys at 4.415, Current Balance: 10033.743699999999, Holdings: 1 Long
# Agent closes long at 4.45, profit: 0.03500000000000014, Current Balance: 10033.778699999999, Holdings: 0
# Agent sells (short) at 4.41, Current Balance: 10033.778699999999, Holdings: 1 Short
# Agent closes short at 4.405, profit: 0.004999999999999893, Current Balance: 10033.783699999998, Holdings: 0
# Agent buys at 4.41, Current Balance: 10033.783699999998, Holdings: 1 Long
# Agent closes long at 4.595, profit: 0.1849999999999996, Current Balance: 10033.968699999998, Holdings: 0
# Agent buys at 4.595, Current Balance: 10033.968699999998, Holdings: 1 Long
# Agent closes long at 4.635, profit: 0.040000000000000036, Current Balance: 10034.008699999998, Holdings: 0
# Agent buys at 4.64, Current Balance: 10034.008699999998, Holdings: 1 Long
# Agent buys at 4.97, Current Balance: 10038.833099999994, Holdings: 1 Long
# Agent closes long at 4.965, profit: -0.004999999999999893, Current Balance: 10038.828099999995, Holdings: 0
# Agent sells (short) at 4.955, Current Balance: 10038.828099999995, Holdings: 1 Short
# Agent closes short at 4.96, profit: -0.004999999999999893, Current Balance: 10038.823099999996, Holdings: 0
# Final Balance: 10038.823099999996
# Total Profit: 38.823099999995975
# Number of Holdings (Long): 0, Short: 0
# ----------------------------------------
#
# --- Testing Metrics ---
# Total Profit: 38.823099999995975
# Cumulative Return: 0.0038823099999995975
# Win Rate: 0.7511961722488039
# Profit Factor: 15.631453983568285
# Sharpe Ratio: 0.6676475758344864
# Sortino Ratio: 4.749454535761101
# Maximum Drawdown: 1.899151554048322e-05

# %%
#dqn algorithm single agent
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.log = []  # Log for detailed reporting
        self.scaler = scaler  # Store the scaler for inverse scaling

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        self.log = []  # Reset log

        # Log initial holdings
        self.log.append(f"Agent starts with 0 holdings (neutral position), Initial Balance: {self.balance}")
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        return obs

    def inverse_scale_price(self, price):
        # Inverse transform the scaled price to get the original value (considering the 'close' column)
        inverse_scaled = self.scaler.inverse_transform([[0, 0, 0, price, 0]])[0][3]
        return inverse_scaled

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        original_price = self.inverse_scale_price(current_price)  # Get original (inverse-scaled) price

        # If agent buys
        if action == 1:
            if self.position == 0:  # Only buy if neutral
                self.position = 1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent buys at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Long")
            elif self.position == -1:  # Close short position
                reward = self.entry_price - current_price  # Scaled reward
                original_reward = self.inverse_scale_price(self.entry_price) - original_price
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes short at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        # If agent sells
        elif action == 2:
            if self.position == 0:  # Only sell if neutral
                self.position = -1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent sells (short) at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Short")
            elif self.position == 1:  # Close long position
                reward = current_price - self.entry_price  # Scaled reward
                original_reward = original_price - self.inverse_scale_price(self.entry_price)
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes long at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

    def generate_report(self):
        print("\n--- Agent Report ---")
        for log in self.log:
            print(log)
        print(f"Final Balance: {self.balance}")
        print(f"Total Profit: {self.balance - self.initial_balance}")
        print(f"Number of Holdings (Long): {1 if self.position == 1 else 0}, Short: {1 if self.position == -1 else 0}")
        print("-" * 40)

# Function to calculate additional metrics
def calculate_metrics(trades, initial_balance, final_balance):
    # Total Profit
    total_profit = final_balance - initial_balance

    # Cumulative Return
    cumulative_return = (final_balance - initial_balance) / initial_balance

    # Win Rate
    positive_trades = [trade for trade in trades if trade > 0]
    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Profit Factor
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf

    # Sharpe Ratio
    returns = np.array(trades)
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    sharpe_ratio = mean_return / std_return if std_return != 0 else 0

    # Sortino Ratio (using only downside standard deviation)
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = mean_return / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    balance_series = np.cumsum([initial_balance] + trades)  # Series of balance over time
    peak_balance = np.maximum.accumulate(balance_series)
    drawdowns = (peak_balance - balance_series) / peak_balance
    max_drawdown = np.max(drawdowns) if drawdowns.size > 0 else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Train and evaluate the model with all metrics
def train_and_evaluate():
    # Load and normalize the data
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Create the environment using the training data
    env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)

    # Initialize the DQN model and train
    model = DQN("MlpPolicy", env_train, verbose=1)
    model.learn(total_timesteps=100000)

    # Test the model on the training data
    obs, _ = env_train.reset()
    done = False
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_train.step(action)

    # Generate report for the training session
    env_train.generate_report()

    # Calculate and display metrics for the training period
    training_metrics = calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance)
    print("\n--- Training Metrics ---")
    for metric, value in training_metrics.items():
        print(f"{metric}: {value}")

    # Test the model on the testing data
    env_test = SingleAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_test.step(action)

    # Generate report for the testing session
    env_test.generate_report()

    # Calculate and display metrics for the testing period
    testing_metrics = calculate_metrics(env_test.trades, env_test.initial_balance, env_test.balance)
    print("\n--- Testing Metrics ---")
    for metric, value in testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 2.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 917      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000156 |
# |    n_updates        | 4752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 3.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1037     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 38224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.66e-05 |
# |    n_updates        | 9530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 3.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1091     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 57336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000724 |
# |    n_updates        | 14308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 3.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1124     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 76448    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.84e-05 |
# |    n_updates        | 19086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78e+03 |
# |    ep_rew_mean      | 2.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1138     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 95560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 23864    |
# ----------------------------------
#
# --- Agent Report ---
# Agent starts with 0 holdings (neutral position), Initial Balance: 10000
# Agent sells (short) at 7.07, Current Balance: 10000, Holdings: 1 Short
# Agent closes short at 6.9775, profit: 0.09250000000000025, Current Balance: 10000.0925, Holdings: 0
# Agent sells (short) at 6.98, Current Balance: 10000.0925, Holdings: 1 Short
# Agent closes short at 6.9, profit: 0.08000000000000007, Current Balance: 10000.1725, Holdings: 0
# Agent sells (short) at 6.96, Current Balance: 10000.1725, Holdings: 1 Short
# Agent closes short at 6.87, profit: 0.08999999999999986, Current Balance: 10000.2625, Holdings: 0
# Agent buys at 6.85, Current Balance: 10000.2625, Holdings: 1 Long
# Agent closes long at 6.81, profit: -0.040000000000000036, Current Balance: 10000.2225, Holdings: 0
# Agent sells (short) at 6.79, Current Balance: 10000.2225, Holdings: 1 Short
# Agent closes short at 6.8, profit: -0.009999999999999787, Current Balance: 10000.2125, Holdings: 0
# Agent sells (short) at 6.8, Current Balance: 10000.2125, Holdings: 1 Short
# Agent closes short at 6.85, profit: -0.04999999999999982, Current Balance: 10000.1625, Holdings: 0
# Agent sells (short) at 6.86, Current Balance: 10000.1625, Holdings: 1 Short
# Agent closes short at 6.79, profit: 0.07000000000000028, Current Balance: 10000.2325, Holdings: 0
# Agent buys at 6.76, Current Balance: 10000.2325, Holdings: 1 Long
# Agent closes long at 6.68, profit: -0.08000000000000007, Current Balance: 10000.1525, Holdings: 0
# Agent sells (short) at 6.655, Current Balance: 10000.1525, Holdings: 1 Short
# Agent closes short at 6.8, profit: -0.14499999999999957, Current Balance: 10000.0075, Holdings: 0
# Agent sells (short) at 6.81, Current Balance: 10000.0075, Holdings: 1 Short
# Agent closes short at 6.7, profit: 0.10999999999999943, Current Balance: 10000.1175, Holdings: 0
# Agent buys at 6.695, Current Balance: 10000.1175, Holdings: 1 Long
# Agent closes long at 6.69, profit: -0.004999999999999893, Current Balance: 10000.112500000001, Holdings: 0
# Agent sells (short) at 6.7, Current Balance: 10000.112500000001, Holdings: 1 Short
# Agent closes short at 6.825, profit: -0.125, Current Balance: 9999.987500000001, Holdings: 0
# Agent sells (short) at 6.82, Current Balance: 9999.987500000001, Holdings: 1 Short
# Agent closes short at 6.83, profit: -0.009999999999999787, Current Balance: 9999.9775, Holdings: 0
# Agent sells (short) at 6.6598, Current Balance: 9999.9775, Holdings: 1 Short
# Agent closes short at 6.57, profit: 0.08979999999999944, Current Balance: 10000.0673, Holdings: 0
# Agent buys at 6.56, Current Balance: 10000.0673, Holdings: 1 Long
# Agent closes long at 6.57, profit: 0.010000000000000675, Current Balance: 10000.0773, Holdings: 0
# Agent sells (short) at 6.53, Current Balance: 10000.0773, Holdings: 1 Short
# Agent closes short at 6.52, profit: 0.010000000000000675, Current Balance: 10000.087300000001, Holdings: 0
# Agent sells (short) at 6.53, Current Balance: 10000.087300000001, Holdings: 1 Short
# Agent closes short at 6.48, profit: 0.04999999999999982, Current Balance: 10000.1373, Holdings: 0
# Agent sells (short) at 6.48, Current Balance: 10000.1373, Holdings: 1 Short
# Agent closes short at 6.42, profit: 0.0600000000000005, Current Balance: 10000.1973, Holdings: 0
# Agent sells (short) at 6.44, Current Balance: 10000.1973, Holdings: 1 Short
# Agent closes short at 6.45, profit: -0.009999999999999787, Current Balance: 10000.1873, Holdings: 0
# Agent buys at 6.43, Current Balance: 10000.1873, Holdings: 1 Long
# Agent closes long at 6.425, profit: -0.004999999999999893, Current Balance: 10000.1823, Holdings: 0
# Agent sells (short) at 6.42, Current Balance: 10000.1823, Holdings: 1 Short
# Agent closes short at 6.43, profit: -0.009999999999999787, Current Balance: 10000.1723, Holdings: 0
# Agent sells (short) at 6.19, Current Balance: 10000.1723, Holdings: 1 Short
# Agent closes short at 6.28, profit: -0.08999999999999986, Current Balance: 10000.0823, Holdings: 0
# Agent sells (short) at 6.25, Current Balance: 10000.0823, Holdings: 1 Short
# Agent closes short at 6.235, profit: 0.01499999999999968, Current Balance: 10000.0973, Holdings: 0
# Agent sells (short) at 6.255, Current Balance: 10000.0973, Holdings: 1 Short
# Agent closes short at 6.26, profit: -0.004999999999999893, Current Balance: 10000.0923, Holdings: 0
# Agent sells (short) at 6.255, Current Balance: 10000.0923, Holdings: 1 Short
# Agent closes short at 6.21, profit: 0.04499999999999993, Current Balance: 10000.1373, Holdings: 0
# Agent sells (short) at 6.155, Current Balance: 10000.1373, Holdings: 1 Short
# Agent closes short at 6.4, profit: -0.2450000000000001, Current Balance: 9999.8923, Holdings: 0
# Agent sells (short) at 6.37, Current Balance: 9999.8923, Holdings: 1 Short
# Agent closes short at 6.22, profit: 0.15000000000000036, Current Balance: 10000.0423, Holdings: 0
# Agent sells (short) at 4.1, Current Balance: 10002.559500000003, Holdings: 1 Short
# Agent closes short at 4.15, profit: -0.05000000000000071, Current Balance: 10002.509500000004, Holdings: 0
# Agent sells (short) at 4.15, Current Balance: 10002.509500000004, Holdings: 1 Short
# Agent closes short at 4.18, profit: -0.02999999999999936, Current Balance: 10002.479500000003, Holdings: 0
# Agent buys at 4.16, Current Balance: 10002.479500000003, Holdings: 1 Long
# Agent closes long at 4.1, profit: -0.0600000000000005, Current Balance: 10002.419500000004, Holdings: 0
# Agent buys at 4.08, Current Balance: 10002.419500000004, Holdings: 1 Long
# Agent closes long at 4.09, profit: 0.009999999999999787, Current Balance: 10002.429500000004, Holdings: 0
# Agent sells (short) at 4.11, Current Balance: 10002.429500000004, Holdings: 1 Short
# Agent closes short at 4.5901, profit: -0.4800999999999993, Current Balance: 10001.949400000003, Holdings: 0
# Agent sells (short) at 4.615, Current Balance: 10001.949400000003, Holdings: 1 Short
# Agent closes short at 4.59, profit: 0.025000000000000355, Current Balance: 10001.974400000003, Holdings: 0
# Agent sells (short) at 4.59, Current Balance: 10001.974400000003, Holdings: 1 Short
# Agent closes short at 5.01, profit: -0.41999999999999993, Current Balance: 10001.554400000003, Holdings: 0
# Agent sells (short) at 5.01, Current Balance: 10001.554400000003, Holdings: 1 Short
# Agent closes short at 4.87, profit: 0.13999999999999968, Current Balance: 10001.694400000002, Holdings: 0
# Agent sells (short) at 4.87, Current Balance: 10001.694400000002, Holdings: 1 Short
# Agent closes short at 5.14, profit: -0.2699999999999996, Current Balance: 10001.424400000002, Holdings: 0
# Agent sells (short) at 5.175, Current Balance: 10001.424400000002, Holdings: 1 Short
# Agent closes short at 5.24, profit: -0.06500000000000039, Current Balance: 10001.359400000001, Holdings: 0
# Agent sells (short) at 5.38, Current Balance: 10001.359400000001, Holdings: 1 Short
# Agent closes short at 5.02, profit: 0.3600000000000003, Current Balance: 10001.719400000002, Holdings: 0
# Agent sells (short) at 4.95, Current Balance: 10001.719400000002, Holdings: 1 Short
# Agent closes short at 5.0, profit: -0.04999999999999982, Current Balance: 10001.669400000002, Holdings: 0
# Agent buys at 4.96, Current Balance: 10001.669400000002, Holdings: 1 Long
# Agent closes long at 4.96, profit: 0.0, Current Balance: 10001.669400000002, Holdings: 0
# Agent sells (short) at 4.9, Current Balance: 10001.669400000002, Holdings: 1 Short
# Agent closes short at 4.94, profit: -0.040000000000000036, Current Balance: 10001.629400000002, Holdings: 0
# Agent buys at 4.97, Current Balance: 10001.629400000002, Holdings: 1 Long
# Agent closes long at 5.005, profit: 0.03500000000000014, Current Balance: 10001.664400000001, Holdings: 0
# Agent buys at 4.975, Current Balance: 10001.664400000001, Holdings: 1 Long
# Agent closes long at 4.98, profit: 0.005000000000000782, Current Balance: 10001.6694, Holdings: 0
# Agent sells (short) at 4.98, Current Balance: 10001.6694, Holdings: 1 Short
# Agent closes short at 4.685, profit: 0.2950000000000008, Current Balance: 10001.9644, Holdings: 0
# Agent sells (short) at 4.74, Current Balance: 10001.9644, Holdings: 1 Short
# Agent sells (short) at 5.36, Current Balance: 10001.464400000003, Holdings: 1 Short
# Agent closes short at 5.33, profit: 0.03000000000000025, Current Balance: 10001.494400000003, Holdings: 0
# Agent sells (short) at 5.33, Current Balance: 10001.494400000003, Holdings: 1 Short
# Agent closes short at 5.145, profit: 0.1850000000000005, Current Balance: 10001.679400000003, Holdings: 0
# Agent sells (short) at 5.11, Current Balance: 10001.679400000003, Holdings: 1 Short
# Agent closes short at 5.0, profit: 0.11000000000000032, Current Balance: 10001.789400000003, Holdings: 0
# Agent sells (short) at 5.175, Current Balance: 10001.789400000003, Holdings: 1 Short
# Agent closes short at 5.6, profit: -0.4249999999999998, Current Balance: 10001.364400000004, Holdings: 0
# Agent sells (short) at 5.62, Current Balance: 10001.364400000004, Holdings: 1 Short
# Agent closes short at 5.5, profit: 0.1200000000000001, Current Balance: 10001.484400000005, Holdings: 0
# Agent sells (short) at 5.49, Current Balance: 10001.484400000005, Holdings: 1 Short
# Agent closes short at 5.56, profit: -0.0699999999999994, Current Balance: 10001.414400000005, Holdings: 0
# Agent sells (short) at 5.57, Current Balance: 10001.414400000005, Holdings: 1 Short
# Agent closes short at 5.51, profit: 0.0600000000000005, Current Balance: 10001.474400000005, Holdings: 0
# Agent sells (short) at 5.5, Current Balance: 10001.474400000005, Holdings: 1 Short
# Agent closes short at 5.33, profit: 0.16999999999999993, Current Balance: 10001.644400000005, Holdings: 0
# Agent sells (short) at 5.34, Current Balance: 10001.644400000005, Holdings: 1 Short
# Agent closes short at 5.58, profit: -0.2400000000000002, Current Balance: 10001.404400000005, Holdings: 0
# Agent buys at 5.58, Current Balance: 10001.404400000005, Holdings: 1 Long
# Agent closes long at 5.5901, profit: 0.010099999999999554, Current Balance: 10001.414500000004, Holdings: 0
# Agent buys at 6.0, Current Balance: 10001.414500000004, Holdings: 1 Long
# Agent closes long at 6.2, profit: 0.20000000000000018, Current Balance: 10001.614500000005, Holdings: 0
# Agent buys at 6.21, Current Balance: 10001.614500000005, Holdings: 1 Long
# Agent closes long at 6.08, profit: -0.1299999999999999, Current Balance: 10001.484500000006, Holdings: 0
# Agent sells (short) at 6.28, Current Balance: 10001.484500000006, Holdings: 1 Short
# Agent closes short at 6.295, profit: -0.01499999999999968, Current Balance: 10001.469500000007, Holdings: 0
# Agent sells (short) at 6.3, Current Balance: 10001.469500000007, Holdings: 1 Short
# Agent closes short at 6.31, profit: -0.009999999999999787, Current Balance: 10001.459500000006, Holdings: 0
# Agent sells (short) at 6.4, Current Balance: 10001.459500000006, Holdings: 1 Short
# Agent closes short at 6.46, profit: -0.05999999999999961, Current Balance: 10001.399500000007, Holdings: 0
# Agent sells (short) at 6.5, Current Balance: 10001.399500000007, Holdings: 1 Short
# Agent closes short at 6.5558, profit: -0.05579999999999963, Current Balance: 10001.343700000007, Holdings: 0
# Agent buys at 6.565, Current Balance: 10001.343700000007, Holdings: 1 Long
# Agent closes long at 6.57, profit: 0.004999999999999893, Current Balance: 10001.348700000006, Holdings: 0
# Agent sells (short) at 6.58, Current Balance: 10001.348700000006, Holdings: 1 Short
# Agent closes short at 6.32, profit: 0.2599999999999998, Current Balance: 10001.608700000006, Holdings: 0
# Agent buys at 6.32, Current Balance: 10001.608700000006, Holdings: 1 Long
# Agent closes long at 6.31, profit: -0.010000000000000675, Current Balance: 10001.598700000006, Holdings: 0
# Agent sells (short) at 6.32, Current Balance: 10001.598700000006, Holdings: 1 Short
# Agent closes short at 6.305, profit: 0.015000000000000568, Current Balance: 10001.613700000005, Holdings: 0
# Agent buys at 6.35, Current Balance: 10001.613700000005, Holdings: 1 Long
# Agent closes long at 6.35, profit: 0.0, Current Balance: 10001.613700000005, Holdings: 0
# Agent sells (short) at 6.12, Current Balance: 10001.613700000005, Holdings: 1 Short
# Agent closes short at 6.12, profit: 0.0, Current Balance: 10001.613700000005, Holdings: 0
# Agent sells (short) at 6.1, Current Balance: 10001.613700000005, Holdings: 1 Short
# Agent closes short at 6.29, profit: -0.1900000000000004, Current Balance: 10001.423700000005, Holdings: 0
# Agent sells (short) at 6.245, Current Balance: 10001.423700000005, Holdings: 1 Short
# Agent closes short at 6.32, profit: -0.07500000000000018, Current Balance: 10001.348700000004, Holdings: 0
# Agent buys at 6.32, Current Balance: 10001.348700000004, Holdings: 1 Long
# Agent closes long at 6.32, profit: 0.0, Current Balance: 10001.348700000004, Holdings: 0
# Agent buys at 6.32, Current Balance: 10001.348700000004, Holdings: 1 Long
# Agent closes long at 6.31, profit: -0.010000000000000675, Current Balance: 10001.338700000004, Holdings: 0
# Agent sells (short) at 6.38, Current Balance: 10001.338700000004, Holdings: 1 Short
# Agent closes short at 6.39, profit: -0.009999999999999787, Current Balance: 10001.328700000004, Holdings: 0
# Agent sells (short) at 6.39, Current Balance: 10001.328700000004, Holdings: 1 Short
# Agent closes short at 6.245, profit: 0.14499999999999957, Current Balance: 10001.473700000004, Holdings: 0
# Agent buys at 6.24, Current Balance: 10001.473700000004, Holdings: 1 Long
# Agent closes long at 6.45, profit: 0.20999999999999996, Current Balance: 10001.683700000003, Holdings: 0
# Agent sells (short) at 6.685, Current Balance: 10001.683700000003, Holdings: 1 Short
# Agent closes short at 6.815, profit: -0.13000000000000078, Current Balance: 10001.553700000004, Holdings: 0
# Agent sells (short) at 6.82, Current Balance: 10001.553700000004, Holdings: 1 Short
# Agent closes short at 6.81, profit: 0.010000000000000675, Current Balance: 10001.563700000004, Holdings: 0
# Agent buys at 6.81, Current Balance: 10001.563700000004, Holdings: 1 Long
# Agent closes long at 6.94, profit: 0.13000000000000078, Current Balance: 10001.693700000003, Holdings: 0
# Agent sells (short) at 6.94, Current Balance: 10001.693700000003, Holdings: 1 Short
# Agent closes short at 6.9, profit: 0.040000000000000036, Current Balance: 10001.733700000004, Holdings: 0
# Agent buys at 6.87, Current Balance: 10001.733700000004, Holdings: 1 Long
# Agent closes long at 6.86, profit: -0.009999999999999787, Current Balance: 10001.723700000004, Holdings: 0
# Agent sells (short) at 6.86, Current Balance: 10001.723700000004, Holdings: 1 Short
# Agent closes short at 6.76, profit: 0.10000000000000053, Current Balance: 10001.823700000004, Holdings: 0
# Agent buys at 7.0, Current Balance: 10001.823700000004, Holdings: 1 Long
# Agent closes long at 7.0, profit: 0.0, Current Balance: 10001.823700000004, Holdings: 0
# Agent sells (short) at 7.05, Current Balance: 10001.823700000004, Holdings: 1 Short
# Agent closes short at 7.04, profit: 0.009999999999999787, Current Balance: 10001.833700000005, Holdings: 0
# Agent buys at 7.05, Current Balance: 10001.833700000005, Holdings: 1 Long
# Agent closes long at 7.03, profit: -0.019999999999999574, Current Balance: 10001.813700000004, Holdings: 0
# Agent sells (short) at 7.07, Current Balance: 10001.813700000004, Holdings: 1 Short
# Agent closes short at 7.09, profit: -0.019999999999999574, Current Balance: 10001.793700000004, Holdings: 0
# Agent buys at 7.09, Current Balance: 10001.793700000004, Holdings: 1 Long
# Agent closes long at 7.1, profit: 0.009999999999999787, Current Balance: 10001.803700000004, Holdings: 0
# Agent sells (short) at 7.11, Current Balance: 10001.803700000004, Holdings: 1 Short
# Agent closes short at 7.08, profit: 0.03000000000000025, Current Balance: 10001.833700000005, Holdings: 0
# Agent sells (short) at 6.97, Current Balance: 10001.833700000005, Holdings: 1 Short
# Agent closes short at 6.91, profit: 0.05999999999999961, Current Balance: 10001.893700000004, Holdings: 0
# Agent buys at 6.9, Current Balance: 10001.893700000004, Holdings: 1 Long
# Agent closes long at 7.0, profit: 0.09999999999999964, Current Balance: 10001.993700000005, Holdings: 0
# Agent sells (short) at 6.95, Current Balance: 10001.993700000005, Holdings: 1 Short
# Agent closes short at 6.95, profit: 0.0, Current Balance: 10001.993700000005, Holdings: 0
# Agent sells (short) at 6.95, Current Balance: 10001.993700000005, Holdings: 1 Short
# Agent closes short at 6.85, profit: 0.10000000000000053, Current Balance: 10002.093700000005, Holdings: 0
# Agent sells (short) at 6.87, Current Balance: 10002.093700000005, Holdings: 1 Short
# Agent closes short at 6.7, profit: 0.16999999999999993, Current Balance: 10002.263700000005, Holdings: 0
# Agent sells (short) at 6.8, Current Balance: 10002.263700000005, Holdings: 1 Short
# Agent closes short at 6.85, profit: -0.04999999999999982, Current Balance: 10002.213700000006, Holdings: 0
# Agent sells (short) at 6.94, Current Balance: 10002.213700000006, Holdings: 1 Short
# Agent closes short at 6.805, profit: 0.13500000000000068, Current Balance: 10002.348700000006, Holdings: 0
# Agent sells (short) at 6.85, Current Balance: 10002.348700000006, Holdings: 1 Short
# Agent closes short at 6.64, profit: 0.20999999999999996, Current Balance: 10002.558700000005, Holdings: 0
# Agent sells (short) at 6.94, Current Balance: 10002.558700000005, Holdings: 1 Short
# Agent closes short at 6.37, profit: 0.5700000000000003, Current Balance: 10003.128700000005, Holdings: 0
# Agent buys at 6.42, Current Balance: 10003.128700000005, Holdings: 1 Long
# Agent closes long at 6.435, profit: 0.01499999999999968, Current Balance: 10003.143700000004, Holdings: 0
# Agent sells (short) at 6.41, Current Balance: 10003.143700000004, Holdings: 1 Short
# Agent closes short at 6.41, profit: 0.0, Current Balance: 10003.143700000004, Holdings: 0
# Agent buys at 6.41, Current Balance: 10003.143700000004, Holdings: 1 Long
# Agent sells (short) at 5.685, Current Balance: 10003.129499999992, Holdings: 1 Short
# Agent closes short at 5.449999999999999, profit: 0.23500000000000032, Current Balance: 10003.364499999992, Holdings: 0
# Agent sells (short) at 5.445, Current Balance: 10003.364499999992, Holdings: 1 Short
# Agent closes short at 5.37, profit: 0.07500000000000018, Current Balance: 10003.439499999993, Holdings: 0
# Agent sells (short) at 5.38, Current Balance: 10003.439499999993, Holdings: 1 Short
# Agent closes short at 5.36, profit: 0.019999999999999574, Current Balance: 10003.459499999994, Holdings: 0
# Agent sells (short) at 5.36, Current Balance: 10003.459499999994, Holdings: 1 Short
# Agent closes short at 5.190000000000001, profit: 0.16999999999999904, Current Balance: 10003.629499999994, Holdings: 0
# Agent sells (short) at 5.11, Current Balance: 10003.629499999994, Holdings: 1 Short
# Agent closes short at 5.08, profit: 0.03000000000000025, Current Balance: 10003.659499999994, Holdings: 0
# Agent sells (short) at 5.05, Current Balance: 10003.659499999994, Holdings: 1 Short
# Final Balance: 10003.659499999994
# Total Profit: 3.6594999999942956
# Number of Holdings (Long): 0, Short: 1
# ----------------------------------------
#
# --- Testing Metrics ---
# Total Profit: 3.6594999999942956
# Cumulative Return: 0.0003659499999994296
# Win Rate: 0.49
# Profit Factor: 1.334036183069535
# Sharpe Ratio: 0.09263728032012003
# Sortino Ratio: 0.1559274489574269
# Maximum Drawdown: 0.00017864586732450316

# %%
#a2c algorithm single agent
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.log = []  # Log for detailed reporting
        self.scaler = scaler  # Store the scaler for inverse scaling

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        self.log = []  # Reset log

        # Log initial holdings
        self.log.append(f"Agent starts with 0 holdings (neutral position), Initial Balance: {self.balance}")
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        return obs

    def inverse_scale_price(self, price):
        # Inverse transform the scaled price to get the original value (considering the 'close' column)
        inverse_scaled = self.scaler.inverse_transform([[0, 0, 0, price, 0]])[0][3]
        return inverse_scaled

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        original_price = self.inverse_scale_price(current_price)  # Get original (inverse-scaled) price

        # If agent buys
        if action == 1:
            if self.position == 0:  # Only buy if neutral
                self.position = 1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent buys at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Long")
            elif self.position == -1:  # Close short position
                reward = self.entry_price - current_price  # Scaled reward
                original_reward = self.inverse_scale_price(self.entry_price) - original_price
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes short at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        # If agent sells
        elif action == 2:
            if self.position == 0:  # Only sell if neutral
                self.position = -1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent sells (short) at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Short")
            elif self.position == 1:  # Close long position
                reward = current_price - self.entry_price  # Scaled reward
                original_reward = original_price - self.inverse_scale_price(self.entry_price)
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes long at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

    def generate_report(self):
        print("\n--- Agent Report ---")
        for log in self.log:
            print(log)
        print(f"Final Balance: {self.balance}")
        print(f"Total Profit: {self.balance - self.initial_balance}")
        print(f"Number of Holdings (Long): {1 if self.position == 1 else 0}, Short: {1 if self.position == -1 else 0}")
        print("-" * 40)

# Function to calculate additional metrics
def calculate_metrics(trades, initial_balance, final_balance):
    # Total Profit
    total_profit = final_balance - initial_balance

    # Cumulative Return
    cumulative_return = (final_balance - initial_balance) / initial_balance

    # Win Rate
    positive_trades = [trade for trade in trades if trade > 0]
    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Profit Factor
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf

    # Sharpe Ratio
    returns = np.array(trades)
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    sharpe_ratio = mean_return / std_return if std_return != 0 else 0

    # Sortino Ratio (using only downside standard deviation)
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = mean_return / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    balance_series = np.cumsum([initial_balance] + trades)  # Series of balance over time
    peak_balance = np.maximum.accumulate(balance_series)
    drawdowns = (peak_balance - balance_series) / peak_balance
    max_drawdown = np.max(drawdowns) if drawdowns.size > 0 else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Train and evaluate the model with action logging for debugging
def train_and_evaluate():
    # Load and normalize the data
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Create the environment using the training data
    env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)

    # Initialize the A2C model and train with more timesteps
    model = A2C("MlpPolicy", env_train, verbose=1)
    model.learn(total_timesteps=500000)  # Increased timesteps

    # Testing on the training data with action logging
    obs, _ = env_train.reset()
    done = False
    print("\n--- Training Session ---")
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_train.step(action)
        # Log each action and reward for debugging
        print(f"Step: {env_train.current_step}, Action: {action}, Reward: {reward}")

    # Generate report and metrics for the training session
    env_train.generate_report()
    training_metrics = calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance)
    print("\n--- Training Metrics ---")
    for metric, value in training_metrics.items():
        print(f"{metric}: {value}")

    # Testing on the testing data with action logging
    env_test = SingleAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    print("\n--- Testing Session ---")
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env_test.step(action)
        # Log each action and reward for debugging
        print(f"Step: {env_test.current_step}, Action: {action}, Reward: {reward}")

    # Generate report and metrics for the testing session
    env_test.generate_report()
    testing_metrics = calculate_metrics(env_test.trades, env_test.initial_balance, env_test.balance)
    print("\n--- Testing Metrics ---")
    for metric, value in testing_metrics.items():
        print(f"{metric}: {value}")



# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -18.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0413  |
# |    value_loss         | 0.00555  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 914      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -456     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0644  |
# |    value_loss         | 0.00797  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 898      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -70.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0465  |
# |    value_loss         | 0.00323  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -35.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00451  |
# |    value_loss         | 0.000144 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 729      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.18     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0903  |
# |    value_loss         | 0.0138   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 669      |
# |    iterations         | 600      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -35.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00594  |
# |    value_loss         | 0.000306 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 655      |
# |    iterations         | 700      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.137   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0898   |
# |    value_loss         | 0.00933  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 668      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -87.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.107   |
# |    value_loss         | 0.0161   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 691      |
# |    iterations         | 900      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.887   |
# |    explained_variance | -0.599   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.139   |
# |    value_loss         | 0.0122   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 710      |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -28.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00511  |
# |    value_loss         | 8.38e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 696      |
# |    iterations         | 1100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.79    |
# |    explained_variance | -4.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.00613  |
# |    value_loss         | 6.6e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 700      |
# |    iterations         | 1200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.843   |
# |    explained_variance | -1.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00587 |
# |    value_loss         | 3.6e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 698      |
# |    iterations         | 1300     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.771   |
# |    explained_variance | -0.104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0408   |
# |    value_loss         | 0.00519  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 713      |
# |    iterations         | 1400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.546   |
# |    explained_variance | -267     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.000827 |
# |    value_loss         | 0.000538 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 1500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | -36.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.000337 |
# |    value_loss         | 2.41e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.241    |
# | time/                 |           |
# |    fps                | 725       |
# |    iterations         | 1600      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.837    |
# |    explained_variance | -1.36e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0663   |
# |    value_loss         | 0.00782   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 730      |
# |    iterations         | 1700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.305   |
# |    explained_variance | -11.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -9.6e-05 |
# |    value_loss         | 8.65e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 740      |
# |    iterations         | 1800     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -9.4     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0596   |
# |    value_loss         | 0.00567  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.241   |
# | time/                 |          |
# |    fps                | 749      |
# |    iterations         | 1900     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.751   |
# |    explained_variance | 0.323    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.0148   |
# |    value_loss         | 0.000169 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 2000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.766   |
# |    explained_variance | -0.725   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00493  |
# |    value_loss         | 0.000207 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 0.309     |
# | time/                 |           |
# |    fps                | 766       |
# |    iterations         | 2100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.934    |
# |    explained_variance | -1.74e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.0665   |
# |    value_loss         | 0.00479   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 774      |
# |    iterations         | 2200     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -0.132   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.00887 |
# |    value_loss         | 7.29e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 781      |
# |    iterations         | 2300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.0243   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0492  |
# |    value_loss         | 0.00327  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 787      |
# |    iterations         | 2400     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.696   |
# |    explained_variance | -195     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0244   |
# |    value_loss         | 0.000926 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 794      |
# |    iterations         | 2500     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.743   |
# |    explained_variance | -24.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00529  |
# |    value_loss         | 5.31e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | 0.309     |
# | time/                 |           |
# |    fps                | 800       |
# |    iterations         | 2600      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.589    |
# |    explained_variance | -0.36     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.000267 |
# |    value_loss         | 2.77e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 2700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.865   |
# |    explained_variance | 0.00969  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0104  |
# |    value_loss         | 0.00188  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | 0.309    |
# | time/                 |          |
# |    fps                | 811      |
# |    iterations         | 2800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.87    |
# |    explained_variance | -37.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00252  |
# |    value_loss         | 8.29e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.359   |
# | time/                 |          |
# |    fps                | 816      |
# |    iterations         | 2900     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.457   |
# |    explained_variance | -0.264   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.025    |
# |    value_loss         | 0.00186  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.359   |
# | time/                 |          |
# |    fps                | 820      |
# |    iterations         | 3000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | -0.584   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 6.31e-05 |
# |    value_loss         | 1.6e-05  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.359    |
# | time/                 |           |
# |    fps                | 825       |
# |    iterations         | 3100      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.132    |
# |    explained_variance | -0.258    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -6.43e-05 |
# |    value_loss         | 7.66e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.359    |
# | time/                 |           |
# |    fps                | 829       |
# |    iterations         | 3200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.801    |
# |    explained_variance | -2.14e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -0.00599  |
# |    value_loss         | 0.026     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.359   |
# | time/                 |          |
# |    fps                | 832      |
# |    iterations         | 3300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.762   |
# |    explained_variance | -13.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00807  |
# |    value_loss         | 0.000126 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.359   |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 3400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.74    |
# |    explained_variance | -32.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00369 |
# |    value_loss         | 5.2e-05  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.359    |
# | time/                 |           |
# |    fps                | 840       |
# |    iterations         | 3500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.702    |
# |    explained_variance | -2.72e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.000668  |
# |    value_loss         | 1.24e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.359    |
# | time/                 |           |
# |    fps                | 842       |
# |    iterations         | 3600      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.671    |
# |    explained_variance | -1.27e+06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.0036    |
# |    value_loss         | 4.61e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.359   |
# | time/                 |          |
# |    fps                | 845      |
# |    iterations         | 3700     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -67.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.00682 |
# |    value_loss         | 0.00678  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.359    |
# | time/                 |           |
# |    fps                | 847       |
# |    iterations         | 3800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.636    |
# |    explained_variance | -34.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.000799 |
# |    value_loss         | 6.62e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 851      |
# |    iterations         | 3900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.0278  |
# |    explained_variance | -1.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 3.41e-06 |
# |    value_loss         | 5.12e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 853      |
# |    iterations         | 4000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0279  |
# |    explained_variance | -16.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 2.37e-06 |
# |    value_loss         | 1.69e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.332    |
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 4100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0186   |
# |    explained_variance | -67.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -1.43e-06 |
# |    value_loss         | 1.55e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 858      |
# |    iterations         | 4200     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.0278  |
# |    explained_variance | 0.611    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 2.49e-05 |
# |    value_loss         | 4.32e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 4300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.721   |
# |    explained_variance | -6.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000199 |
# |    value_loss         | 1.59e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.332    |
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 4400      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.694    |
# |    explained_variance | -16.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -5.12e-05 |
# |    value_loss         | 2.06e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.332    |
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 4500      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.696    |
# |    explained_variance | -1.24e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 0.00131   |
# |    value_loss         | 5.7e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 869      |
# |    iterations         | 4600     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.701   |
# |    explained_variance | -52.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00942 |
# |    value_loss         | 0.000366 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.332   |
# | time/                 |          |
# |    fps                | 872      |
# |    iterations         | 4700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.695   |
# |    explained_variance | -1.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.00108  |
# |    value_loss         | 7.99e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 873       |
# |    iterations         | 4800      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0532   |
# |    explained_variance | -123      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -4.36e-06 |
# |    value_loss         | 4.54e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.311   |
# | time/                 |          |
# |    fps                | 875      |
# |    iterations         | 4900     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.0215  |
# |    explained_variance | -39.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 7.31e-07 |
# |    value_loss         | 1.47e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 877       |
# |    iterations         | 5000      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.021    |
# |    explained_variance | -64.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -2.42e-06 |
# |    value_loss         | 2.13e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 876       |
# |    iterations         | 5100      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.0284   |
# |    explained_variance | -38.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -2.46e-06 |
# |    value_loss         | 7.17e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.311   |
# | time/                 |          |
# |    fps                | 875      |
# |    iterations         | 5200     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | -605     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0403  |
# |    value_loss         | 0.00398  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 871       |
# |    iterations         | 5300      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.582    |
# |    explained_variance | -27.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.000902 |
# |    value_loss         | 2.86e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 5400      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.537    |
# |    explained_variance | -895      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -3.53e-05 |
# |    value_loss         | 1.64e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.311   |
# | time/                 |          |
# |    fps                | 865      |
# |    iterations         | 5500     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | -18.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.000317 |
# |    value_loss         | 5.25e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.311   |
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 5600     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.708   |
# |    explained_variance | -259     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0478   |
# |    value_loss         | 0.00293  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.311    |
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 5700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.593    |
# |    explained_variance | -2        |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000672 |
# |    value_loss         | 4.04e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.235   |
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 5800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.0163  |
# |    explained_variance | -82.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 1.09e-06 |
# |    value_loss         | 5.68e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.235    |
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 5900      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.0128   |
# |    explained_variance | -10.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -8.15e-07 |
# |    value_loss         | 3.69e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.235   |
# | time/                 |          |
# |    fps                | 856      |
# |    iterations         | 6000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.0143  |
# |    explained_variance | -53.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.62e-06 |
# |    value_loss         | 8.43e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.235    |
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 6100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.0118   |
# |    explained_variance | -257      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -1.48e-06 |
# |    value_loss         | 1.4e-06   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.235    |
# | time/                 |           |
# |    fps                | 858       |
# |    iterations         | 6200      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.226    |
# |    explained_variance | -3.54e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -3.82e-06 |
# |    value_loss         | 1.61e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.235   |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 6300     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | -7.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.000264 |
# |    value_loss         | 1.27e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.235    |
# | time/                 |           |
# |    fps                | 861       |
# |    iterations         | 6400      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.271    |
# |    explained_variance | -0.153    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000123 |
# |    value_loss         | 2.37e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.235   |
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 6500     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | -0.212   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00299  |
# |    value_loss         | 0.00161  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.235    |
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 6600      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.467    |
# |    explained_variance | -18.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.000522 |
# |    value_loss         | 5.95e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 865       |
# |    iterations         | 6700      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.0686   |
# |    explained_variance | 0.111     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -1.85e-05 |
# |    value_loss         | 2.96e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 6800      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0396   |
# |    explained_variance | -6.43e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 1.6e-06   |
# |    value_loss         | 1.87e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 868       |
# |    iterations         | 6900      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.0441   |
# |    explained_variance | -3.08     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -2.47e-06 |
# |    value_loss         | 1.22e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.299   |
# | time/                 |          |
# |    fps                | 869      |
# |    iterations         | 7000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.0956  |
# |    explained_variance | -7.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 7.92e-06 |
# |    value_loss         | 3.39e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 871       |
# |    iterations         | 7100      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.169    |
# |    explained_variance | 0.669     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000375 |
# |    value_loss         | 0.000104  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 872       |
# |    iterations         | 7200      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.214    |
# |    explained_variance | -3.76     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -3.93e-05 |
# |    value_loss         | 5.43e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.299    |
# | time/                 |           |
# |    fps                | 874       |
# |    iterations         | 7300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.262    |
# |    explained_variance | -25.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -9.33e-06 |
# |    value_loss         | 6.54e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.299   |
# | time/                 |          |
# |    fps                | 875      |
# |    iterations         | 7400     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | -1.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00171 |
# |    value_loss         | 1.44e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.299   |
# | time/                 |          |
# |    fps                | 876      |
# |    iterations         | 7500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | -844     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.0122   |
# |    value_loss         | 0.000215 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.78e+03 |
# |    ep_rew_mean        | -0.299   |
# | time/                 |          |
# |    fps                | 877      |
# |    iterations         | 7600     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | -0.0501  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.177    |
# |    value_loss         | 0.0461   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.78e+03  |
# |    ep_rew_mean        | -0.173    |
# | time/                 |           |
# |    fps                | 879       |
# |    iterations         | 7700      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.0317   |
# |    explained_variance | -23.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -1.64e-07 |
# |    value_loss         | 2.46e-07  |
# ...
# Step: 2245, Action: 1, Reward: 0
# Step: 2246, Action: 1, Reward: 0
# Step: 2247, Action: 1, Reward: 0
# Step: 2248, Action: 1, Reward: 0
# Step: 2249, Action: 1, Reward: 0
# Step: 2250, Action: 1, Reward: 0
# Step: 2251, Action: 1, Reward: 0
# Step: 2252, Action: 1, Reward: 0
# Step: 2253, Action: 1, Reward: 0
# Step: 2254, Action: 1, Reward: 0
# Step: 2255, Action: 1, Reward: 0
# Step: 2256, Action: 1, Reward: 0
# Step: 2257, Action: 1, Reward: 0
# Step: 2258, Action: 1, Reward: 0
# Step: 2259, Action: 1, Reward: 0
# Step: 2260, Action: 1, Reward: 0
# Step: 2261, Action: 1, Reward: 0
# Step: 2262, Action: 1, Reward: 0
# Step: 2263, Action: 1, Reward: 0
# Step: 2264, Action: 1, Reward: 0
# Step: 2265, Action: 1, Reward: 0
# Step: 2266, Action: 1, Reward: 0
# Step: 2267, Action: 1, Reward: 0
# Step: 2268, Action: 1, Reward: 0
# Step: 2269, Action: 1, Reward: 0
# Step: 2270, Action: 1, Reward: 0
# Step: 2271, Action: 1, Reward: 0
# Step: 2272, Action: 1, Reward: 0
# Step: 2273, Action: 1, Reward: 0
# Step: 2274, Action: 1, Reward: 0
# Step: 2275, Action: 1, Reward: 0
# Step: 2276, Action: 1, Reward: 0
# Step: 2277, Action: 1, Reward: 0
# Step: 2278, Action: 1, Reward: 0
# Step: 2279, Action: 1, Reward: 0
# Step: 2280, Action: 1, Reward: 0
# Step: 2281, Action: 1, Reward: 0
# Step: 2282, Action: 1, Reward: 0
# Step: 2283, Action: 1, Reward: 0
# Step: 2284, Action: 1, Reward: 0
# Step: 2285, Action: 1, Reward: 0
# Step: 2286, Action: 1, Reward: 0
# Step: 2287, Action: 1, Reward: 0
# Step: 2288, Action: 1, Reward: 0
# Step: 2289, Action: 1, Reward: 0
# Step: 2290, Action: 1, Reward: 0
# Step: 2291, Action: 1, Reward: 0
# Step: 2292, Action: 1, Reward: 0
# Step: 2293, Action: 1, Reward: 0
# Step: 2294, Action: 1, Reward: 0
# Step: 2295, Action: 1, Reward: 0
# Step: 2296, Action: 1, Reward: 0
# Step: 2297, Action: 1, Reward: 0
# Step: 2298, Action: 1, Reward: 0
# Step: 2299, Action: 1, Reward: 0
# Step: 2300, Action: 1, Reward: 0
# Step: 2301, Action: 1, Reward: 0
# Step: 2302, Action: 1, Reward: 0
# Step: 2303, Action: 1, Reward: 0
# Step: 2304, Action: 1, Reward: 0
# Step: 2305, Action: 1, Reward: 0
# Step: 2306, Action: 1, Reward: 0
# Step: 2307, Action: 1, Reward: 0
# Step: 2308, Action: 1, Reward: 0
# Step: 2309, Action: 1, Reward: 0
# Step: 2310, Action: 1, Reward: 0
# Step: 2311, Action: 1, Reward: 0
# Step: 2312, Action: 1, Reward: 0
# Step: 2313, Action: 1, Reward: 0
# Step: 2314, Action: 1, Reward: 0
# Step: 2315, Action: 1, Reward: 0
# Step: 2316, Action: 1, Reward: 0
# Step: 2317, Action: 1, Reward: 0
# Step: 2318, Action: 1, Reward: 0
# Step: 2319, Action: 1, Reward: 0
# Step: 2320, Action: 1, Reward: 0
# Step: 2321, Action: 1, Reward: 0
# Step: 2322, Action: 1, Reward: 0
#
# --- Agent Report ---
# Agent starts with 0 holdings (neutral position), Initial Balance: 10000
# Agent sells (short) at 10.15, Current Balance: 10000, Holdings: 1 Short
# Agent closes short at 8.8, profit: 1.3499999999999996, Current Balance: 10001.35, Holdings: 0
# Agent buys at 8.7, Current Balance: 10001.35, Holdings: 1 Long
# Agent closes long at 8.3, profit: -0.3999999999999986, Current Balance: 10000.95, Holdings: 0
# Agent buys at 8.27, Current Balance: 10000.95, Holdings: 1 Long
# Agent closes long at 8.27, profit: 0.0, Current Balance: 10000.95, Holdings: 0
# Agent buys at 8.28, Current Balance: 10000.95, Holdings: 1 Long
# Agent closes long at 8.32, profit: 0.040000000000000924, Current Balance: 10000.990000000002, Holdings: 0
# Agent buys at 8.295, Current Balance: 10000.990000000002, Holdings: 1 Long
# Agent closes long at 8.335, profit: 0.040000000000000924, Current Balance: 10001.030000000002, Holdings: 0
# Agent buys at 8.37, Current Balance: 10001.030000000002, Holdings: 1 Long
# Agent sells (short) at 8.19, Current Balance: 10000.675000000003, Holdings: 1 Short
# Agent closes short at 8.02, profit: 0.16999999999999993, Current Balance: 10000.845000000003, Holdings: 0
# Agent buys at 8.04, Current Balance: 10000.845000000003, Holdings: 1 Long
# Agent closes long at 8.03, profit: -0.009999999999999787, Current Balance: 10000.835000000003, Holdings: 0
# Agent sells (short) at 8.01, Current Balance: 10000.835000000003, Holdings: 1 Short
# Agent closes short at 7.99, profit: 0.019999999999999574, Current Balance: 10000.855000000003, Holdings: 0
# Agent buys at 7.955, Current Balance: 10000.855000000003, Holdings: 1 Long
# Agent closes long at 8.02, profit: 0.0649999999999995, Current Balance: 10000.920000000004, Holdings: 0
# Agent sells (short) at 8.12, Current Balance: 10000.920000000004, Holdings: 1 Short
# Agent closes short at 7.925, profit: 0.1949999999999994, Current Balance: 10001.115000000003, Holdings: 0
# Agent buys at 7.905, Current Balance: 10001.115000000003, Holdings: 1 Long
# Agent closes long at 7.8, profit: -0.10500000000000043, Current Balance: 10001.010000000004, Holdings: 0
# Agent buys at 7.77, Current Balance: 10001.010000000004, Holdings: 1 Long
# Agent closes long at 7.815, profit: 0.04500000000000082, Current Balance: 10001.055000000004, Holdings: 0
# Agent buys at 7.875, Current Balance: 10001.055000000004, Holdings: 1 Long
# Agent closes long at 8.03, profit: 0.15499999999999936, Current Balance: 10001.210000000005, Holdings: 0
# Agent sells (short) at 7.92, Current Balance: 10001.210000000005, Holdings: 1 Short
# Agent closes short at 7.905, profit: 0.01499999999999968, Current Balance: 10001.225000000004, Holdings: 0
# Agent buys at 7.93, Current Balance: 10001.225000000004, Holdings: 1 Long
# Agent closes long at 7.88, profit: -0.04999999999999982, Current Balance: 10001.175000000005, Holdings: 0
# Agent buys at 7.87, Current Balance: 10001.175000000005, Holdings: 1 Long
# Agent closes long at 7.71, profit: -0.16000000000000014, Current Balance: 10001.015000000005, Holdings: 0
# Agent buys at 7.845, Current Balance: 10001.015000000005, Holdings: 1 Long
# Agent closes long at 7.93, profit: 0.08499999999999996, Current Balance: 10001.100000000004, Holdings: 0
# Agent sells (short) at 7.91, Current Balance: 10001.100000000004, Holdings: 1 Short
# Agent closes short at 7.94, profit: -0.03000000000000025, Current Balance: 10001.070000000003, Holdings: 0
# Agent buys at 7.97, Current Balance: 10001.070000000003, Holdings: 1 Long
# Agent closes long at 7.84, profit: -0.1299999999999999, Current Balance: 10000.940000000004, Holdings: 0
# Agent buys at 7.835, Current Balance: 10000.940000000004, Holdings: 1 Long
# Agent closes long at 7.86, profit: 0.025000000000000355, Current Balance: 10000.965000000004, Holdings: 0
# Agent buys at 7.83, Current Balance: 10000.965000000004, Holdings: 1 Long
# Agent closes long at 7.685, profit: -0.14500000000000046, Current Balance: 10000.820000000003, Holdings: 0
# Agent buys at 7.685, Current Balance: 10000.820000000003, Holdings: 1 Long
# Agent closes long at 7.86, profit: 0.1750000000000007, Current Balance: 10000.995000000003, Holdings: 0
# Agent buys at 7.7324, Current Balance: 10000.995000000003, Holdings: 1 Long
# Agent closes long at 7.82, profit: 0.08760000000000012, Current Balance: 10001.082600000003, Holdings: 0
# Agent buys at 7.835, Current Balance: 10001.082600000003, Holdings: 1 Long
# Agent closes long at 7.79, profit: -0.04499999999999993, Current Balance: 10001.037600000003, Holdings: 0
# Agent buys at 7.76, Current Balance: 10001.037600000003, Holdings: 1 Long
# Agent closes long at 7.63, profit: -0.1299999999999999, Current Balance: 10000.907600000004, Holdings: 0
# Agent buys at 7.675, Current Balance: 10000.907600000004, Holdings: 1 Long
# Agent closes long at 7.68, profit: 0.004999999999999893, Current Balance: 10000.912600000003, Holdings: 0
# Agent buys at 7.64, Current Balance: 10000.912600000003, Holdings: 1 Long
# Agent closes long at 7.905, profit: 0.26500000000000057, Current Balance: 10001.177600000003, Holdings: 0
# Agent sells (short) at 7.905, Current Balance: 10001.177600000003, Holdings: 1 Short
# Agent closes short at 7.98, profit: -0.07500000000000018, Current Balance: 10001.102600000002, Holdings: 0
# Agent sells (short) at 7.99, Current Balance: 10001.102600000002, Holdings: 1 Short
# Agent closes short at 7.925, profit: 0.06500000000000039, Current Balance: 10001.167600000002, Holdings: 0
# Agent buys at 7.99, Current Balance: 10001.167600000002, Holdings: 1 Long
# Agent closes long at 8.035, profit: 0.04499999999999993, Current Balance: 10001.212600000003, Holdings: 0
# Agent buys at 8.035, Current Balance: 10001.212600000003, Holdings: 1 Long
# Agent closes long at 8.17, profit: 0.1349999999999998, Current Balance: 10001.347600000003, Holdings: 0
# Agent buys at 8.165, Current Balance: 10001.347600000003, Holdings: 1 Long
# Agent closes long at 8.13, profit: -0.034999999999998366, Current Balance: 10001.312600000003, Holdings: 0
# Agent buys at 8.08, Current Balance: 10001.312600000003, Holdings: 1 Long
# Agent closes long at 8.05, profit: -0.02999999999999936, Current Balance: 10001.282600000002, Holdings: 0
# Agent sells (short) at 8.035, Current Balance: 10001.282600000002, Holdings: 1 Short
# Agent closes short at 8.04, profit: -0.004999999999999005, Current Balance: 10001.277600000003, Holdings: 0
# Agent sells (short) at 8.04, Current Balance: 10001.277600000003, Holdings: 1 Short
# Agent closes short at 8.23, profit: -0.19000000000000128, Current Balance: 10001.087600000003, Holdings: 0
# Agent sells (short) at 8.31, Current Balance: 10001.087600000003, Holdings: 1 Short
# Agent closes short at 8.28, profit: 0.030000000000001137, Current Balance: 10001.117600000003, Holdings: 0
# Agent sells (short) at 8.275, Current Balance: 10001.117600000003, Holdings: 1 Short
# Agent closes short at 8.199, profit: 0.07600000000000051, Current Balance: 10001.193600000002, Holdings: 0
# Agent sells (short) at 8.13, Current Balance: 10001.193600000002, Holdings: 1 Short
# Agent closes short at 8.39, profit: -0.2599999999999998, Current Balance: 10000.933600000002, Holdings: 0
# Agent sells (short) at 8.35, Current Balance: 10000.933600000002, Holdings: 1 Short
# Agent closes short at 8.25, profit: 0.09999999999999964, Current Balance: 10001.033600000002, Holdings: 0
# Agent buys at 8.26, Current Balance: 10001.033600000002, Holdings: 1 Long
# Agent closes long at 8.4, profit: 0.14000000000000057, Current Balance: 10001.173600000002, Holdings: 0
# Agent sells (short) at 8.15, Current Balance: 10001.173600000002, Holdings: 1 Short
# Agent closes short at 8.13, profit: 0.019999999999999574, Current Balance: 10001.193600000002, Holdings: 0
# Agent buys at 8.13, Current Balance: 10001.193600000002, Holdings: 1 Long
# Agent closes long at 8.03, profit: -0.10000000000000142, Current Balance: 10001.093600000002, Holdings: 0
# Agent sells (short) at 8.0, Current Balance: 10001.093600000002, Holdings: 1 Short
# Agent closes short at 7.885, profit: 0.11500000000000021, Current Balance: 10001.208600000002, Holdings: 0
# Agent buys at 7.81, Current Balance: 10001.208600000002, Holdings: 1 Long
# Agent closes long at 7.78, profit: -0.02999999999999936, Current Balance: 10001.178600000001, Holdings: 0
# Agent buys at 7.765, Current Balance: 10001.178600000001, Holdings: 1 Long
# Agent closes long at 7.515, profit: -0.25, Current Balance: 10000.928600000001, Holdings: 0
# Agent buys at 7.5041, Current Balance: 10000.928600000001, Holdings: 1 Long
# Agent closes long at 7.71, profit: 0.20589999999999975, Current Balance: 10001.134500000002, Holdings: 0
# Agent buys at 7.7, Current Balance: 10001.134500000002, Holdings: 1 Long
# Agent closes long at 7.78, profit: 0.08000000000000007, Current Balance: 10001.214500000002, Holdings: 0
# Agent sells (short) at 7.755, Current Balance: 10001.214500000002, Holdings: 1 Short
# Agent closes short at 7.77, profit: -0.01499999999999968, Current Balance: 10001.199500000002, Holdings: 0
# Agent buys at 7.77, Current Balance: 10001.199500000002, Holdings: 1 Long
# Agent closes long at 7.76, profit: -0.009999999999999787, Current Balance: 10001.189500000002, Holdings: 0
# Agent buys at 7.74, Current Balance: 10001.189500000002, Holdings: 1 Long
# Agent closes long at 7.56, profit: -0.1800000000000006, Current Balance: 10001.009500000002, Holdings: 0
# Agent buys at 7.535, Current Balance: 10001.009500000002, Holdings: 1 Long
# Agent closes long at 7.6, profit: 0.0649999999999995, Current Balance: 10001.074500000002, Holdings: 0
# Agent buys at 7.595, Current Balance: 10001.074500000002, Holdings: 1 Long
# Agent closes long at 7.625, profit: 0.03000000000000025, Current Balance: 10001.104500000003, Holdings: 0
# Agent buys at 7.585, Current Balance: 10001.104500000003, Holdings: 1 Long
# Final Balance: 10001.104500000003
# Total Profit: 1.1045000000030996
# Number of Holdings (Long): 1, Short: 0
# ----------------------------------------
#
# --- Testing Metrics ---
# Total Profit: 1.1045000000030996
# Cumulative Return: 0.00011045000000030996
# Win Rate: 0.5285714285714286
# Profit Factor: 1.3210755813953499
# Sharpe Ratio: 0.07593487716901436
# Sortino Ratio: 0.1736864958914856
# Maximum Drawdown: 8.848805411235286e-05

# %%
#ensemble learning single agent
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.log = []  # Log for detailed reporting
        self.scaler = scaler  # Store the scaler for inverse scaling

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        self.log = []  # Reset log

        # Log initial holdings
        self.log.append(f"Agent starts with 0 holdings (neutral position), Initial Balance: {self.balance}")
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        return obs

    def inverse_scale_price(self, price):
        # Inverse transform the scaled price to get the original value (considering the 'close' column)
        inverse_scaled = self.scaler.inverse_transform([[0, 0, 0, price, 0]])[0][3]
        return inverse_scaled

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        original_price = self.inverse_scale_price(current_price)  # Get original (inverse-scaled) price

        # If agent buys
        if action == 1:
            if self.position == 0:  # Only buy if neutral
                self.position = 1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent buys at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Long")
            elif self.position == -1:  # Close short position
                reward = self.entry_price - current_price  # Scaled reward
                original_reward = self.inverse_scale_price(self.entry_price) - original_price
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes short at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        # If agent sells
        elif action == 2:
            if self.position == 0:  # Only sell if neutral
                self.position = -1
                self.entry_price = current_price
                original_entry_price = self.inverse_scale_price(current_price)
                self.log.append(f"Agent sells (short) at {original_entry_price}, Current Balance: {self.balance}, Holdings: 1 Short")
            elif self.position == 1:  # Close long position
                reward = current_price - self.entry_price  # Scaled reward
                original_reward = original_price - self.inverse_scale_price(self.entry_price)
                self.balance += original_reward
                self.position = 0
                self.trades.append(original_reward)
                self.log.append(f"Agent closes long at {original_price}, profit: {original_reward}, Current Balance: {self.balance}, Holdings: 0")

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

    def generate_report(self):
        print("\n--- Agent Report ---")
        for log in self.log:
            print(log)
        print(f"Final Balance: {self.balance}")
        print(f"Total Profit: {self.balance - self.initial_balance}")
        print(f"Number of Holdings (Long): {1 if self.position == 1 else 0}, Short: {1 if self.position == -1 else 0}")
        print("-" * 40)

# Function to calculate metrics
def calculate_metrics(trades, initial_balance, final_balance):
    # Total Profit
    total_profit = final_balance - initial_balance

    # Cumulative Return
    cumulative_return = (final_balance - initial_balance) / initial_balance

    # Win Rate
    positive_trades = [trade for trade in trades if trade > 0]
    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Profit Factor
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf

    # Sharpe Ratio
    returns = np.array(trades)
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    sharpe_ratio = mean_return / std_return if std_return != 0 else 0

    # Sortino Ratio (using only downside standard deviation)
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = mean_return / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    balance_series = np.cumsum([initial_balance] + trades)  # Series of balance over time
    peak_balance = np.maximum.accumulate(balance_series)
    drawdowns = (peak_balance - balance_series) / peak_balance
    max_drawdown = np.max(drawdowns) if drawdowns.size > 0 else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Ensemble model function
def ensemble_predict(actions):
    # Convert numpy arrays to integers for each action
    actions = [int(action) for action in actions]
    # Perform a majority vote among the actions (hold, buy, sell)
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Train and evaluate the ensemble model
def train_and_evaluate():
    # Load and normalize the data
    train_file = 'LPL_TRAINING.csv'
    test_file = 'LPL_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Create the environment using the training data
    env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)

    # Initialize each model and train them separately
    ppo_model = PPO("MlpPolicy", env_train, verbose=1)
    dqn_model = DQN("MlpPolicy", env_train, verbose=1)
    a2c_model = A2C("MlpPolicy", env_train, verbose=1)

    # Train each model
    ppo_model.learn(total_timesteps=50000)
    dqn_model.learn(total_timesteps=50000)
    a2c_model.learn(total_timesteps=50000)

    # Test the ensemble model on the training data
    obs, _ = env_train.reset()
    done = False
    while not done:
        # Get predictions from each model
        ppo_action, _ = ppo_model.predict(obs)
        dqn_action, _ = dqn_model.predict(obs)
        a2c_action, _ = a2c_model.predict(obs)

        # Aggregate the actions through majority voting
        final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])

        # Step the environment with the final action
        obs, reward, done, truncated, info = env_train.step(final_action)

    # Calculate and display training metrics
    training_metrics = calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance)
    print("\n--- Training Metrics ---")
    for metric, value in training_metrics.items():
        print(f"{metric}: {value}")

    # Test the ensemble model on the testing data
    env_test = SingleAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        # Get predictions from each model
        ppo_action, _ = ppo_model.predict(obs)
        dqn_action, _ = dqn_model.predict(obs)
        a2c_action, _ = a2c_model.predict(obs)

        # Aggregate the actions through majority voting
        final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])

        # Step the environment with the final action
        obs, reward, done, truncated, info = env_test.step(final_action)

    # Generate report for the testing session
    env_test.generate_report()

    # Calculate and display testing metrics
    testing_metrics = calculate_metrics(env_test.trades, env_test.initial_balance, env_test.balance)
    print("\n--- Testing Metrics ---")
    for metric, value in testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1623 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012837998 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -20.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.007      |
# |    value_loss           | 0.00526     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012678015 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -1.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00369    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00945    |
# |    value_loss           | 0.00759     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | -0.361      |
# | time/                   |             |
# |    fps                  | 1254        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009567645 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00357    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -0.361       |
# | time/                   |              |
# |    fps                  | 1222         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0065226723 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0201      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00642     |
# |    value_loss           | 0.00306      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | -0.361       |
# | time/                   |              |
# |    fps                  | 1222         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067848917 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.112       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00692     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00822     |
# |    value_loss           | 0.00348      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.06e+03   |
# |    ep_rew_mean          | -0.361     |
# | time/                   |            |
# |    fps                  | 1196       |
# |    iterations           | 7          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00769297 |
# |    clip_fraction        | 0.0617     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00228    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0072    |
# |    value_loss           | 0.00306    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.06e+03  |
# |    ep_rew_mean          | 0.937     |
# | time/                   |           |
# |    fps                  | 1198      |
# |    iterations           | 8         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0086078 |
# |    clip_fraction        | 0.0578    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.03     |
# |    explained_variance   | 0.418     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00482   |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.00897  |
# |    value_loss           | 0.00197   |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 0.937        |
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049844007 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000542    |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 0.937        |
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0074638603 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | -0.0307      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00824     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00915     |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 0.937        |
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0067001996 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.934       |
# |    explained_variance   | 0.0289       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0217      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00983     |
# |    value_loss           | 0.00305      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 1.79         |
# | time/                   |              |
# |    fps                  | 1178         |
# |    iterations           | 12           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0074949926 |
# |    clip_fraction        | 0.0696       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000431    |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00794     |
# |    value_loss           | 0.00149      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008728423 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000755   |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008049943 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00761    |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008265357 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0.00675     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00704     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00371     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 16          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008152736 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00325     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0093     |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 17          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010861848 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008996928 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00815    |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 19          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009671892 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7.51         |
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 20           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0080846045 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0175       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00752     |
# |    value_loss           | 0.00181      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7.51         |
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 21           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0073202066 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.516        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00527     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 0.00297      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 7.51        |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 22          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006876423 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.031       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06e+03     |
# |    ep_rew_mean          | 7.51         |
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 23           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059378003 |
# |    clip_fraction        | 0.0677       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0236      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00681     |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 24          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016048446 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000856   |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06e+03    |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 25          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011209337 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00606    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.00416     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06e+03 |
# |    ep_rew_mean      | -0.008   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1099     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 32244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.26e-05 |
# |    n_updates        | 8035     |
# ----------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 816      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -17.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0329  |
# |    value_loss         | 0.00169  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 815      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -3.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.02    |
# |    value_loss         | 0.00125  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 816      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -3.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00144 |
# |    value_loss         | 0.000752 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 809      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -162     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.00422 |
# |    value_loss         | 0.000328 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 805       |
# |    iterations         | 500       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -1.94e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.108     |
# |    value_loss         | 0.0256    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 802       |
# |    iterations         | 600       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -1.31e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.0895   |
# |    value_loss         | 0.01      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 802      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -44.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.121    |
# |    value_loss         | 0.00765  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.872   |
# |    explained_variance | -0.477   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0607   |
# |    value_loss         | 0.00589  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 900       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.785    |
# |    explained_variance | -7.69e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 0.00643   |
# |    value_loss         | 0.000481  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 1000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -1.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 0.00134  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 1100      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.506    |
# |    explained_variance | 0.26      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -0.000222 |
# |    value_loss         | 0.00191   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 1200      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.291    |
# |    explained_variance | -20.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -0.000208 |
# |    value_loss         | 2.29e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 804      |
# |    iterations         | 1300     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | -115     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.000515 |
# |    value_loss         | 0.000108 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 805       |
# |    iterations         | 1400      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.274    |
# |    explained_variance | -1.47e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.000342 |
# |    value_loss         | 3.98e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 804      |
# |    iterations         | 1500     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.171   |
# |    explained_variance | 0.795    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 5.5e-05  |
# |    value_loss         | 2.5e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 805       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.154    |
# |    explained_variance | -4.1e+03  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -3.46e-05 |
# |    value_loss         | 4.17e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 1700     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | -730     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00312  |
# |    value_loss         | 0.000191 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 1800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.315   |
# |    explained_variance | 0.0376   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.00979  |
# |    value_loss         | 0.000447 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 805       |
# |    iterations         | 1900      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.34     |
# |    explained_variance | -6.79     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -5.34e-05 |
# |    value_loss         | 1.2e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 805      |
# |    iterations         | 2000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.66    |
# |    explained_variance | -0.503   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0036  |
# |    value_loss         | 0.000358 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 804      |
# |    iterations         | 2100     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.741   |
# |    explained_variance | -47.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0085   |
# |    value_loss         | 0.00685  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 2200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | -6.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.00359  |
# |    value_loss         | 0.00169  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 2300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | -5.29e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.0181    |
# |    value_loss         | 0.00244   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 2400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | -446     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00106 |
# |    value_loss         | 0.000909 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 2500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.255    |
# |    explained_variance | 0.156     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -0.000354 |
# |    value_loss         | 3.02e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 2600     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.864   |
# |    explained_variance | -1.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.043   |
# |    value_loss         | 0.0033   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 2700      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.513    |
# |    explained_variance | -18.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -0.000975 |
# |    value_loss         | 3.86e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 2800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.291   |
# |    explained_variance | -3.14    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.000927 |
# |    value_loss         | 0.000138 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 802       |
# |    iterations         | 2900      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.292    |
# |    explained_variance | -33.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -1.81e-05 |
# |    value_loss         | 1.05e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 3000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.245   |
# |    explained_variance | -139     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00251  |
# |    value_loss         | 1.13e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 3100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.244    |
# |    explained_variance | 0.296     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -0.000101 |
# |    value_loss         | 2.54e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -2.86     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 3200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.158    |
# |    explained_variance | -90.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -7.09e-06 |
# |    value_loss         | 3.66e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 3300     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | 0.386    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0168   |
# |    value_loss         | 0.000514 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 803       |
# |    iterations         | 3400      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.103    |
# |    explained_variance | -7.1      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -1.79e-05 |
# |    value_loss         | 1.74e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 3500     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.308   |
# |    explained_variance | -80.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.000108 |
# |    value_loss         | 7.21e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 801       |
# |    iterations         | 3600      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.563    |
# |    explained_variance | -1.42e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.00032   |
# |    value_loss         | 1.75e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 3700     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.564   |
# |    explained_variance | -109     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0345   |
# |    value_loss         | 0.029    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 800       |
# |    iterations         | 3800      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.267    |
# |    explained_variance | -74.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.000184 |
# |    value_loss         | 0.000251  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 3900     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | -26.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0017   |
# |    value_loss         | 0.000216 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 4000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | -574     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000132 |
# |    value_loss         | 5.41e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 4100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0826   |
# |    explained_variance | -28.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -7.64e-06 |
# |    value_loss         | 1.07e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 799       |
# |    iterations         | 4200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.171    |
# |    explained_variance | -251      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.000161 |
# |    value_loss         | 0.000133  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 8.06e+03  |
# |    ep_rew_mean        | -1.94     |
# | time/                 |           |
# |    fps                | 798       |
# |    iterations         | 4300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.189    |
# |    explained_variance | -2.93     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -0.000233 |
# |    value_loss         | 3.18e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.06e+03 |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 4400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 22000    |
# ...
# Agent closes long at 145.5, profit: 0.12999999999999545, Current Balance: 10380.43820000001, Holdings: 0
# Agent sells (short) at 145.32, Current Balance: 10380.43820000001, Holdings: 1 Short
# Agent closes short at 144.5, profit: 0.8199999999999932, Current Balance: 10381.25820000001, Holdings: 0
# Agent sells (short) at 144.48, Current Balance: 10381.25820000001, Holdings: 1 Short
# Agent closes short at 141.145, profit: 3.3349999999999795, Current Balance: 10384.593200000008, Holdings: 0
# Agent sells (short) at 140.5801, Current Balance: 10384.593200000008, Holdings: 1 Short
# Agent closes short at 141.29, profit: -0.7099000000000046, Current Balance: 10383.883300000009, Holdings: 0
# Agent buys at 141.15, Current Balance: 10383.883300000009, Holdings: 1 Long
# Agent closes long at 140.99, profit: -0.1599999999999966, Current Balance: 10383.723300000009, Holdings: 0
# Agent sells (short) at 141.31, Current Balance: 10383.723300000009, Holdings: 1 Short
# Agent closes short at 142.31, profit: -1.0, Current Balance: 10382.723300000009, Holdings: 0
# Agent sells (short) at 142.28, Current Balance: 10382.723300000009, Holdings: 1 Short
# Agent closes short at 141.36, profit: 0.9199999999999875, Current Balance: 10383.643300000009, Holdings: 0
# Agent buys at 141.9607, Current Balance: 10383.643300000009, Holdings: 1 Long
# Agent closes long at 141.18, profit: -0.780699999999996, Current Balance: 10382.86260000001, Holdings: 0
# Agent buys at 141.56, Current Balance: 10382.86260000001, Holdings: 1 Long
# Agent closes long at 141.2509, profit: -0.3091000000000008, Current Balance: 10382.553500000009, Holdings: 0
# Agent sells (short) at 144.19, Current Balance: 10382.553500000009, Holdings: 1 Short
# Agent closes short at 148.18, profit: -3.990000000000009, Current Balance: 10378.56350000001, Holdings: 0
# Agent buys at 147.26, Current Balance: 10378.56350000001, Holdings: 1 Long
# Agent closes long at 147.41, profit: 0.15000000000000568, Current Balance: 10378.713500000009, Holdings: 0
# Agent buys at 147.96, Current Balance: 10378.713500000009, Holdings: 1 Long
# Agent closes long at 148.27, profit: 0.3100000000000023, Current Balance: 10379.023500000008, Holdings: 0
# Agent sells (short) at 148.211, Current Balance: 10379.023500000008, Holdings: 1 Short
# Agent closes short at 147.92, profit: 0.29100000000002524, Current Balance: 10379.314500000008, Holdings: 0
# Agent buys at 148.2043, Current Balance: 10379.314500000008, Holdings: 1 Long
# Agent closes long at 148.8357, profit: 0.6314000000000135, Current Balance: 10379.945900000008, Holdings: 0
# Agent buys at 148.33, Current Balance: 10379.945900000008, Holdings: 1 Long
# Agent closes long at 148.2, profit: -0.13000000000002387, Current Balance: 10379.815900000009, Holdings: 0
# Agent sells (short) at 148.15, Current Balance: 10379.815900000009, Holdings: 1 Short
# Agent closes short at 148.37, profit: -0.21999999999999886, Current Balance: 10379.59590000001, Holdings: 0
# Agent sells (short) at 148.25, Current Balance: 10379.59590000001, Holdings: 1 Short
# Agent closes short at 146.24, profit: 2.009999999999991, Current Balance: 10381.60590000001, Holdings: 0
# Agent sells (short) at 146.4699, Current Balance: 10381.60590000001, Holdings: 1 Short
# Agent closes short at 147.8, profit: -1.3301000000000158, Current Balance: 10380.27580000001, Holdings: 0
# Agent sells (short) at 147.4407, Current Balance: 10380.27580000001, Holdings: 1 Short
# Agent closes short at 147.5, profit: -0.05930000000000746, Current Balance: 10380.21650000001, Holdings: 0
# Agent sells (short) at 147.85, Current Balance: 10380.21650000001, Holdings: 1 Short
# Agent closes short at 146.61, profit: 1.2399999999999807, Current Balance: 10381.45650000001, Holdings: 0
# Agent buys at 146.88, Current Balance: 10381.45650000001, Holdings: 1 Long
# Agent closes long at 146.85, profit: -0.030000000000001137, Current Balance: 10381.426500000009, Holdings: 0
# Agent sells (short) at 146.96, Current Balance: 10381.426500000009, Holdings: 1 Short
# Agent closes short at 142.9615, profit: 3.998500000000007, Current Balance: 10385.425000000008, Holdings: 0
# Agent sells (short) at 143.11, Current Balance: 10385.425000000008, Holdings: 1 Short
# Agent closes short at 141.74, profit: 1.3700000000000045, Current Balance: 10386.79500000001, Holdings: 0
# Agent sells (short) at 141.95, Current Balance: 10386.79500000001, Holdings: 1 Short
# Agent closes short at 141.35, profit: 0.5999999999999943, Current Balance: 10387.39500000001, Holdings: 0
# Agent sells (short) at 140.58, Current Balance: 10387.39500000001, Holdings: 1 Short
# Agent closes short at 140.8599, profit: -0.2798999999999978, Current Balance: 10387.11510000001, Holdings: 0
# Agent sells (short) at 141.8801, Current Balance: 10387.11510000001, Holdings: 1 Short
# Agent closes short at 141.08, profit: 0.8000999999999863, Current Balance: 10387.91520000001, Holdings: 0
# Agent sells (short) at 140.89, Current Balance: 10387.91520000001, Holdings: 1 Short
# Agent closes short at 140.865, profit: 0.024999999999977263, Current Balance: 10387.94020000001, Holdings: 0
# Agent sells (short) at 140.745, Current Balance: 10387.94020000001, Holdings: 1 Short
# Agent closes short at 140.94, profit: -0.19499999999999318, Current Balance: 10387.74520000001, Holdings: 0
# Agent buys at 140.95, Current Balance: 10387.74520000001, Holdings: 1 Long
# Agent closes long at 140.99, profit: 0.040000000000020464, Current Balance: 10387.785200000011, Holdings: 0
# Agent sells (short) at 140.7, Current Balance: 10387.785200000011, Holdings: 1 Short
# Agent closes short at 141.41, profit: -0.710000000000008, Current Balance: 10387.075200000012, Holdings: 0
# Agent buys at 141.3, Current Balance: 10387.075200000012, Holdings: 1 Long
# Agent closes long at 141.61, profit: 0.3100000000000023, Current Balance: 10387.385200000012, Holdings: 0
# Agent sells (short) at 142.05, Current Balance: 10387.385200000012, Holdings: 1 Short
# Agent closes short at 142.8041, profit: -0.754099999999994, Current Balance: 10386.631100000011, Holdings: 0
# Agent sells (short) at 142.43, Current Balance: 10386.631100000011, Holdings: 1 Short
# Agent closes short at 142.71, profit: -0.28000000000000114, Current Balance: 10386.35110000001, Holdings: 0
# Agent sells (short) at 142.68, Current Balance: 10386.35110000001, Holdings: 1 Short
# Agent closes short at 142.73, profit: -0.04999999999998295, Current Balance: 10386.301100000012, Holdings: 0
# Agent sells (short) at 143.35, Current Balance: 10386.301100000012, Holdings: 1 Short
# Agent closes short at 144.03, profit: -0.6800000000000068, Current Balance: 10385.621100000011, Holdings: 0
# Agent sells (short) at 142.75, Current Balance: 10385.621100000011, Holdings: 1 Short
# Agent closes short at 141.765, profit: 0.9850000000000136, Current Balance: 10386.606100000012, Holdings: 0
# Agent sells (short) at 144.295, Current Balance: 10386.606100000012, Holdings: 1 Short
# Agent closes short at 142.19, profit: 2.1049999999999898, Current Balance: 10388.711100000011, Holdings: 0
# Agent buys at 141.96, Current Balance: 10388.711100000011, Holdings: 1 Long
# Agent closes long at 141.99, profit: 0.030000000000001137, Current Balance: 10388.741100000012, Holdings: 0
# Agent buys at 141.95, Current Balance: 10388.741100000012, Holdings: 1 Long
# Agent closes long at 142.54, profit: 0.5900000000000034, Current Balance: 10389.331100000012, Holdings: 0
# Agent sells (short) at 142.52, Current Balance: 10389.331100000012, Holdings: 1 Short
# Agent closes short at 142.679, profit: -0.15899999999999181, Current Balance: 10389.172100000013, Holdings: 0
# Agent sells (short) at 141.77, Current Balance: 10389.172100000013, Holdings: 1 Short
# Agent closes short at 144.3, profit: -2.530000000000001, Current Balance: 10386.642100000012, Holdings: 0
# Agent sells (short) at 144.38, Current Balance: 10386.642100000012, Holdings: 1 Short
# Agent closes short at 144.69, profit: -0.3100000000000023, Current Balance: 10386.332100000012, Holdings: 0
# Agent sells (short) at 144.89, Current Balance: 10386.332100000012, Holdings: 1 Short
# Agent closes short at 145.065, profit: -0.17500000000001137, Current Balance: 10386.157100000013, Holdings: 0
# Agent sells (short) at 145.3, Current Balance: 10386.157100000013, Holdings: 1 Short
# Agent closes short at 145.14, profit: 0.160000000000025, Current Balance: 10386.317100000013, Holdings: 0
# Agent buys at 145.49, Current Balance: 10386.317100000013, Holdings: 1 Long
# Agent closes long at 145.08, profit: -0.4099999999999966, Current Balance: 10385.907100000013, Holdings: 0
# Agent sells (short) at 145.25, Current Balance: 10385.907100000013, Holdings: 1 Short
# Agent closes short at 143.42, profit: 1.8300000000000125, Current Balance: 10387.737100000013, Holdings: 0
# Agent sells (short) at 143.34, Current Balance: 10387.737100000013, Holdings: 1 Short
# Agent closes short at 136.775, profit: 6.564999999999998, Current Balance: 10394.302100000014, Holdings: 0
# Agent sells (short) at 136.91, Current Balance: 10394.302100000014, Holdings: 1 Short
# Agent closes short at 136.28, profit: 0.6299999999999955, Current Balance: 10394.932100000013, Holdings: 0
# Agent sells (short) at 136.35, Current Balance: 10394.932100000013, Holdings: 1 Short
# Agent closes short at 135.5, profit: 0.8499999999999943, Current Balance: 10395.782100000013, Holdings: 0
# Agent buys at 136.7, Current Balance: 10395.782100000013, Holdings: 1 Long
# Agent closes long at 136.47, profit: -0.22999999999998977, Current Balance: 10395.552100000014, Holdings: 0
# Agent sells (short) at 136.635, Current Balance: 10395.552100000014, Holdings: 1 Short
# Agent closes short at 132.1726, profit: 0.07740000000001146, Current Balance: 10400.778800000013, Holdings: 0
# Agent sells (short) at 132.17, Current Balance: 10400.778800000013, Holdings: 1 Short
# Agent closes short at 131.84, profit: 0.3299999999999841, Current Balance: 10401.108800000013, Holdings: 0
# Agent sells (short) at 132.51, Current Balance: 10401.108800000013, Holdings: 1 Short
# Agent closes short at 132.19, profit: 0.3199999999999932, Current Balance: 10401.428800000012, Holdings: 0
# Agent buys at 132.2, Current Balance: 10401.428800000012, Holdings: 1 Long
# Agent closes long at 132.09, profit: -0.10999999999998522, Current Balance: 10401.318800000012, Holdings: 0
# Agent sells (short) at 130.0179, Current Balance: 10401.318800000012, Holdings: 1 Short
# Agent closes short at 130.8701, profit: -0.8522000000000105, Current Balance: 10400.466600000012, Holdings: 0
# Agent buys at 130.875, Current Balance: 10400.466600000012, Holdings: 1 Long
# Agent closes long at 131.7189, profit: 0.8438999999999908, Current Balance: 10401.310500000012, Holdings: 0
# Agent buys at 131.86, Current Balance: 10401.310500000012, Holdings: 1 Long
# Agent closes long at 131.75, profit: -0.11000000000001364, Current Balance: 10401.200500000012, Holdings: 0
# Agent sells (short) at 131.78, Current Balance: 10401.200500000012, Holdings: 1 Short
# Agent closes short at 129.675, profit: 2.1049999999999898, Current Balance: 10403.305500000011, Holdings: 0
# Agent sells (short) at 130.1884, Current Balance: 10403.305500000011, Holdings: 1 Short
# Agent closes short at 130.05, profit: 0.1383999999999901, Current Balance: 10403.443900000011, Holdings: 0
# Agent buys at 130.02, Current Balance: 10403.443900000011, Holdings: 1 Long
# Agent closes long at 129.96, profit: -0.060000000000002274, Current Balance: 10403.383900000012, Holdings: 0
# Agent sells (short) at 129.97, Current Balance: 10403.383900000012, Holdings: 1 Short
# Agent closes short at 129.84, profit: 0.12999999999999545, Current Balance: 10403.51390000001, Holdings: 0
# Agent sells (short) at 130.0, Current Balance: 10403.51390000001, Holdings: 1 Short
# Agent closes short at 126.6245, profit: 3.3755000000000024, Current Balance: 10406.889400000011, Holdings: 0
# Agent sells (short) at 127.635, Current Balance: 10406.889400000011, Holdings: 1 Short
# Agent closes short at 127.085, profit: 0.5500000000000114, Current Balance: 10407.43940000001, Holdings: 0
# Agent sells (short) at 126.84, Current Balance: 10407.43940000001, Holdings: 1 Short
# Agent closes short at 126.84, profit: 0.0, Current Balance: 10407.43940000001, Holdings: 0
# Agent sells (short) at 126.9, Current Balance: 10407.43940000001, Holdings: 1 Short
# Agent closes short at 129.52, profit: -2.6200000000000045, Current Balance: 10404.81940000001, Holdings: 0
# Agent sells (short) at 129.52, Current Balance: 10404.81940000001, Holdings: 1 Short
# Final Balance: 10404.81940000001
# Total Profit: 404.8194000000094
# Number of Holdings (Long): 0, Short: 1
# ----------------------------------------
#
# --- Testing Metrics ---
# Total Profit: 404.8194000000094
# Cumulative Return: 0.04048194000000094
# Win Rate: 0.5811789038262668
# Profit Factor: 2.4116380633030743
# Sharpe Ratio: 0.25885017550480843
# Sortino Ratio: 0.6657395052313693
# Maximum Drawdown: 0.0010463994220927671
