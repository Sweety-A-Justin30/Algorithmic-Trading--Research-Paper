# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NVDA_TRAINING.csv'
    test_file = 'NVDA_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 859  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0115012415 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -18.4        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000696     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00736     |
# |    value_loss           | 0.00341      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0073414613 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.54        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0247      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00592     |
# |    value_loss           | 0.00213      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074141724 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0321       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00884     |
# |    value_loss           | 0.00223      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005617071 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000456    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 0.00531     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008603372 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00911    |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009241702 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.713      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0065514864 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0271      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0094      |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0072213905 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0199       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 0.00335      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 927          |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073940796 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | -0.453       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00588      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00937     |
# |    value_loss           | 0.00105      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 11           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0057018576 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | -0.257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0093      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00859     |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 1.62         |
# | time/                   |              |
# |    fps                  | 938          |
# |    iterations           | 12           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0036267336 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00868     |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.62        |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 13          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006738983 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00714     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.62        |
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 14          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009693895 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | -0.516      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.62        |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 15          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008582041 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -0.113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00629    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.000978    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.4         |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 16          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007537813 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.4         |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 17          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008656291 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000331   |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00485     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.4         |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 18          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010340493 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -0.562      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.033      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.93e+03   |
# |    ep_rew_mean          | 2.4        |
# | time/                   |            |
# |    fps                  | 947        |
# |    iterations           | 19         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00964605 |
# |    clip_fraction        | 0.0911     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.928     |
# |    explained_variance   | 0.0386     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0083    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00851   |
# |    value_loss           | 0.0011     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 20          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008311717 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.93e+03   |
# |    ep_rew_mean          | 3.21       |
# | time/                   |            |
# |    fps                  | 933        |
# |    iterations           | 21         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00545658 |
# |    clip_fraction        | 0.0705     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.761     |
# |    explained_variance   | -0.183     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.018     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00667   |
# |    value_loss           | 0.00416    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 22          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009275574 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | -0.565      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0136     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.000814    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.21         |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 23           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0054772175 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | -0.0307      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0142      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00902     |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 4.42        |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 24          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008311519 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00789     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00612    |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 4.42         |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 25           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0128489975 |
# |    clip_fraction        | 0.0989       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00498     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 0.00352      |
# ------------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 1.9665608851846628
# Cumulative Return: 0.0001966560885184663
# Win Rate: 0.571072319201995
# Profit Factor: 1.6362195621281823
# Sharpe Ratio: 0.16177954364257924
# Sortino Ratio: 0.25628661279997533
# Maximum Drawdown: 0.36268125959048403
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1361 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0067835627 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -2.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0484       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 0.00424      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010539492 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00697     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005568647 |
# |    clip_fraction        | 0.0216      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 0.00519     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.93e+03   |
# |    ep_rew_mean          | 1.05       |
# | time/                   |            |
# |    fps                  | 1002       |
# |    iterations           | 5          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00853039 |
# |    clip_fraction        | 0.0474     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00478   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00484   |
# |    value_loss           | 0.00578    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 6           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009603672 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0361     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008415882 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0639      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 987          |
# |    iterations           | 8            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0075307293 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0183      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 9           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006043953 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00795    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 0.00533     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 10          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007271166 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.00118     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 919          |
# |    iterations           | 11           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0058113234 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.316       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0167       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0076      |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.04        |
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 12          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006498066 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0341     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00744    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.04        |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 13          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006927039 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0348     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 0.00508     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.04         |
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 14           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0076948116 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0869      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0089      |
# |    value_loss           | 0.000901     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.04         |
# | time/                   |              |
# |    fps                  | 894          |
# |    iterations           | 15           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0069612404 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.171       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00203     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.000845     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.36         |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 16           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0074754567 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.0919      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000914    |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.36        |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008283861 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 0.00471     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.36        |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008391633 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | -0.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.0009      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.36        |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004595194 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 0.000944    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.19        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 20          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007708881 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.19        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 21          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011821072 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | -0.182      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0249      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 0.00446     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.19         |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 22           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0052374927 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | -0.218       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00518      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 0.000933     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.19        |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 23          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008113211 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00102     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.91        |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 24          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009114695 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00757    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.91         |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 25           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0059890384 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | -0.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0275      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 0.0027       |
# ------------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 1.8874225776908133
# Cumulative Return: 0.00018874225776908132
# Win Rate: 0.5293255131964809
# Profit Factor: 1.4548197742423918
# Sharpe Ratio: 0.11677089535773054
# Sortino Ratio: 0.15652556531041273
# Maximum Drawdown: 0.30239320555969873
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 881  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009144236 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -11.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00548    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.00919     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066985083 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0143       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 0.00507      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.54         |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073035336 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0266      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00945     |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.54        |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005641381 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0307     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 0.00446     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.54        |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007514212 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -1.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.54        |
# ...
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009174902 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.659      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0349     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.93e+03  |
# |    ep_rew_mean          | -1.05     |
# | time/                   |           |
# |    fps                  | 783       |
# |    iterations           | 11        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0113892 |
# |    clip_fraction        | 0.129     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | -0.0114   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0387   |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.014    |
# |    value_loss           | 0.00128   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.93e+03   |
# |    ep_rew_mean          | 0.441      |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 12         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00565655 |
# |    clip_fraction        | 0.0318     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | -0.333     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000649  |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00727   |
# |    value_loss           | 0.00158    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 0.441       |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009647451 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00443    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 0.00437     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 0.441       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007048223 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.397      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0135     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 0.441        |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 15           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0062806834 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00899      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00764     |
# |    value_loss           | 0.0015       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 16          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007561979 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0856      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00597    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.11         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 17           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0073111774 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0196      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00637     |
# |    value_loss           | 0.00417      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.11         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 18           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074149636 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00263     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.000822     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007934887 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00894    |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.16         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 20           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0076358374 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | -0.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0204      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00896     |
# |    value_loss           | 0.00215      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.16         |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 21           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0107064005 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00798     |
# |    value_loss           | 0.00452      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.16        |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009312902 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00563     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.16        |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006641872 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00853    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 4.28        |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008409003 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00424     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00738    |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 4.28        |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 25          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010241745 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.0307      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00072     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 0.00243     |
# -----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 3.9896278620144585
# Cumulative Return: 0.00039896278620144584
# Win Rate: 0.5874125874125874
# Profit Factor: 2.2620019875753012
# Sharpe Ratio: 0.2558993701458527
# Sortino Ratio: 0.4346069497481233
# Maximum Drawdown: 0.20139694216359771
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 2.971439215386508
# Cumulative Return: 0.00029714392153865077
# Win Rate: 0.5650614790687712
# Profit Factor: 1.9007441554709121
# Sharpe Ratio: 0.19874108208786823
# Sortino Ratio: 0.3159855236599093
# Maximum Drawdown: 0.3009893006384277
# --- Agent 1 Testing Metrics ---
# Total Profit: 14.662891536683674
# Cumulative Return: 0.0014662891536683673
# Win Rate: 0.6056338028169014
# Profit Factor: 2.8804466756159646
# Sharpe Ratio: 0.31746287522127536
# Sortino Ratio: 0.6070888744828945
# Maximum Drawdown: 0.49286116978835004
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 10.52940020764072
# Cumulative Return: 0.001052940020764072
# Win Rate: 0.5748792270531401
# Profit Factor: 2.1309575405538963
# Sharpe Ratio: 0.24234208137457372
# Sortino Ratio: 0.45049020113699756
# Maximum Drawdown: 0.43084592033460156
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 18.51808105841883
# Cumulative Return: 0.001851808105841883
# Win Rate: 0.6206088992974239
# Profit Factor: 3.8185695604975933
# Sharpe Ratio: 0.3806844811058458
# Sortino Ratio: 0.9216651156865749
# Maximum Drawdown: 0.21299595280572703
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 15.753809011315752
# Cumulative Return: 0.0015753809011315753
# Win Rate: 0.6572379367720466
# Profit Factor: 4.554107391793602
# Sharpe Ratio: 0.389924603382706
# Sortino Ratio: 1.0712979265478637
# Maximum Drawdown: 0.2404970730316709
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 15.332808920835106
# Cumulative Return: 0.0015332808920835105
# Win Rate: 0.6194410686972369
# Profit Factor: 3.502882648227861
# Sharpe Ratio: 0.34310689599655897
# Sortino Ratio: 0.8046291642791379
# Maximum Drawdown: 0.32751999547785016

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NVDA_TRAINING.csv'
    test_file = 'NVDA_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -2.61    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1096     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 31732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.32e-05 |
# |    n_updates        | 7907     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | 0.108    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1105     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 31732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000169 |
# |    n_updates        | 7907     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -0.207   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1017     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 31732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.33e-05 |
# |    n_updates        | 7907     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -3.78    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1108     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 31732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.06e-05 |
# |    n_updates        | 7907     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0
# Cumulative Return: 0
# Win Rate: 0
# Profit Factor: 0
# Sharpe Ratio: 0
# Sortino Ratio: 0
# Maximum Drawdown: 0
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.1948392133012136
# Cumulative Return: 0.00011948392133012133
# Win Rate: 0.4705775633573096
# Profit Factor: 1.1584084753749595
# Sharpe Ratio: 0.04008141869897702
# Sortino Ratio: 0.07187369329301407
# Maximum Drawdown: 1.33764461201174

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NVDA_TRAINING.csv'
    test_file = 'NVDA_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=100000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -0.836    |
# |    explained_variance | -4.26e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0283    |
# |    value_loss         | 0.00971   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 784       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.723    |
# |    explained_variance | -2.56e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.0211   |
# |    value_loss         | 0.00776   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 800       |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.396    |
# |    explained_variance | -1.53e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.0104    |
# |    value_loss         | 0.0149    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 806      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | -197     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.00226 |
# |    value_loss         | 0.00272  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 809      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | -30.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.00295 |
# |    value_loss         | 0.00274  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 812       |
# |    iterations         | 600       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.758    |
# |    explained_variance | -1.03e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.0007   |
# |    value_loss         | 0.00109   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 777      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.917   |
# |    explained_variance | -367     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0434   |
# |    value_loss         | 0.0032   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 753       |
# |    iterations         | 800       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.846    |
# |    explained_variance | -3.01e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.00551  |
# |    value_loss         | 0.000551  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 753      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.699   |
# |    explained_variance | -30.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.00576 |
# |    value_loss         | 0.000505 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 738      |
# |    iterations         | 1000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | -753     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0571  |
# |    value_loss         | 0.00214  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 727       |
# |    iterations         | 1100      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.659    |
# |    explained_variance | -5.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.00337   |
# |    value_loss         | 0.000707  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 734      |
# |    iterations         | 1200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.934   |
# |    explained_variance | -392     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00618 |
# |    value_loss         | 0.000242 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 738      |
# |    iterations         | 1300     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.994   |
# |    explained_variance | -92.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0055  |
# |    value_loss         | 0.000156 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 743      |
# |    iterations         | 1400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.744   |
# |    explained_variance | -321     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.00988  |
# |    value_loss         | 0.000213 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 741      |
# |    iterations         | 1500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | -816     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0019  |
# |    value_loss         | 0.00013  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 743      |
# |    iterations         | 1600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | -1.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.000224 |
# |    value_loss         | 2.89e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 746      |
# |    iterations         | 1700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.593   |
# |    explained_variance | -92.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00593 |
# |    value_loss         | 8.81e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 750      |
# |    iterations         | 1800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | -773     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.00245 |
# |    value_loss         | 7.69e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 746      |
# |    iterations         | 1900     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | -28.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00703 |
# |    value_loss         | 0.000107 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 738      |
# |    iterations         | 2000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | -68.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00514  |
# |    value_loss         | 0.000166 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 2100     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | -107     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0113   |
# |    value_loss         | 0.000338 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 2200      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.449    |
# |    explained_variance | -3.19e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.00591  |
# |    value_loss         | 4.52e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 714       |
# |    iterations         | 2300      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.375    |
# |    explained_variance | -1.98e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.000473  |
# |    value_loss         | 8.28e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 718       |
# |    iterations         | 2400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.241    |
# |    explained_variance | -5.71e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.000124 |
# |    value_loss         | 1.74e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 722       |
# |    iterations         | 2500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.307    |
# |    explained_variance | -61.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -0.000242 |
# |    value_loss         | 1.7e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 725      |
# |    iterations         | 2600     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.285   |
# |    explained_variance | -14      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0009  |
# |    value_loss         | 0.000182 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 728       |
# |    iterations         | 2700      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.14     |
# |    explained_variance | -25.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -0.000286 |
# |    value_loss         | 0.000125  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 731       |
# |    iterations         | 2800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.179    |
# |    explained_variance | -52       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -0.000324 |
# |    value_loss         | 8.46e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 734       |
# |    iterations         | 2900      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.168    |
# |    explained_variance | -71.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -8.35e-05 |
# |    value_loss         | 1.1e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 737      |
# |    iterations         | 3000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.263   |
# |    explained_variance | -27.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 9.98e-05 |
# |    value_loss         | 8.6e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 739      |
# |    iterations         | 3100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.165   |
# |    explained_variance | -28.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -6.6e-05 |
# |    value_loss         | 6.56e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 742      |
# |    iterations         | 3200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.079   |
# |    explained_variance | -81.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 3.31e-05 |
# |    value_loss         | 9.33e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 744      |
# |    iterations         | 3300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.0911  |
# |    explained_variance | -2.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 4.61e-05 |
# |    value_loss         | 8.48e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 746       |
# |    iterations         | 3400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.0661   |
# |    explained_variance | -193      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -5.99e-06 |
# |    value_loss         | 4.69e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 748       |
# |    iterations         | 3500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.0498   |
# |    explained_variance | -2.61e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -3.82e-05 |
# |    value_loss         | 4.76e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 750      |
# |    iterations         | 3600     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.0724  |
# |    explained_variance | -231     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 3.99e-05 |
# |    value_loss         | 1.52e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 751       |
# |    iterations         | 3700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.149    |
# |    explained_variance | -1.91e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 0.000133  |
# |    value_loss         | 2.81e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 752      |
# |    iterations         | 3800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.159   |
# |    explained_variance | -215     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00556  |
# |    value_loss         | 2.24e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 754       |
# |    iterations         | 3900      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.487    |
# |    explained_variance | -280      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.000508 |
# |    value_loss         | 2.49e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 755       |
# |    iterations         | 4000      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.415    |
# |    explained_variance | -0.607    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000243 |
# |    value_loss         | 1.22e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 756       |
# |    iterations         | 4100      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | -692      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.000697 |
# |    value_loss         | 1.11e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 4200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.495   |
# |    explained_variance | -4.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00264 |
# |    value_loss         | 5.12e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 759      |
# |    iterations         | 4300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.287   |
# |    explained_variance | -196     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.00287 |
# |    value_loss         | 2.07e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 761      |
# |    iterations         | 4400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.168   |
# |    explained_variance | -18.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 2.04e-05 |
# |    value_loss         | 7.23e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 762       |
# |    iterations         | 4500      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.22     |
# |    explained_variance | -1.54e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 6.56e-05  |
# |    value_loss         | 5.43e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 764       |
# |    iterations         | 4600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.129    |
# |    explained_variance | -4.25     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -4.09e-05 |
# |    value_loss         | 3.23e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 4700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.11    |
# |    explained_variance | -558     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.00668 |
# |    value_loss         | 5.06e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 766       |
# |    iterations         | 4800      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0716   |
# |    explained_variance | -493      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -9.38e-06 |
# |    value_loss         | 2.97e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 767      |
# |    iterations         | 4900     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.0446  |
# |    explained_variance | -41.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 2.98e-06 |
# |    value_loss         | 4.89e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 768      |
# |    iterations         | 5000     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.0651  |
# |    explained_variance | -105     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 1.47e-05 |
# |    value_loss         | 2.12e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 769       |
# |    iterations         | 5100      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.0605   |
# |    explained_variance | -767      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -1.17e-06 |
# |    value_loss         | 3.77e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 771       |
# |    iterations         | 5200      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.0883   |
# |    explained_variance | -3.5      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -6.07e-07 |
# |    value_loss         | 4.66e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 772       |
# |    iterations         | 5300      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.175    |
# |    explained_variance | -20       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -3.07e-05 |
# |    value_loss         | 1.48e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 773       |
# |    iterations         | 5400      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.0843   |
# |    explained_variance | -29.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -1.27e-05 |
# |    value_loss         | 1.18e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 773      |
# |    iterations         | 5500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.161   |
# |    explained_variance | -108     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 6.39e-05 |
# |    value_loss         | 5.5e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 5600      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.11     |
# |    explained_variance | -43.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -2.72e-05 |
# |    value_loss         | 6.21e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 775      |
# |    iterations         | 5700     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.13    |
# |    explained_variance | -60.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 4.8e-07  |
# |    value_loss         | 6.43e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 776       |
# |    iterations         | 5800      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.255    |
# |    explained_variance | -3.84e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -6.03e-05 |
# |    value_loss         | 5.99e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 777       |
# |    iterations         | 5900      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.345    |
# |    explained_variance | -13.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -1.58e-05 |
# |    value_loss         | 3.47e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 778      |
# |    iterations         | 6000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.487   |
# |    explained_variance | -179     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.00107  |
# |    value_loss         | 7.83e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 779      |
# |    iterations         | 6100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -18.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.000464 |
# |    value_loss         | 4.1e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 779       |
# |    iterations         | 6200      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.444    |
# |    explained_variance | -10.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.000149 |
# |    value_loss         | 1.66e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 780       |
# |    iterations         | 6300      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.441    |
# |    explained_variance | -3.72     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0.000431 |
# |    value_loss         | 1.25e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 781       |
# |    iterations         | 6400      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.411    |
# |    explained_variance | -1.23e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.00176  |
# |    value_loss         | 4.92e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 782       |
# |    iterations         | 6500      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.34     |
# |    explained_variance | -1.53e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | 4.14e-05  |
# |    value_loss         | 1.91e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 782      |
# |    iterations         | 6600     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.436   |
# |    explained_variance | -110     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.000564 |
# |    value_loss         | 2.19e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 783      |
# |    iterations         | 6700     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.359   |
# |    explained_variance | -79      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000104 |
# |    value_loss         | 2.22e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 780      |
# |    iterations         | 6800     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.381   |
# |    explained_variance | -743     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 3.12e-05 |
# |    value_loss         | 3.76e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 779      |
# |    iterations         | 6900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.276   |
# |    explained_variance | -82.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 3.27e-06 |
# |    value_loss         | 6.38e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 775      |
# |    iterations         | 7000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.294   |
# |    explained_variance | -3.76    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00247 |
# |    value_loss         | 3.25e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 770       |
# |    iterations         | 7100      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.147    |
# |    explained_variance | -2.32     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -2.76e-05 |
# |    value_loss         | 1.13e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 764       |
# |    iterations         | 7200      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.303    |
# |    explained_variance | -2.27e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | 0.000163  |
# |    value_loss         | 8.16e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 762      |
# |    iterations         | 7300     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.206   |
# |    explained_variance | -16.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 5.02e-06 |
# |    value_loss         | 4.79e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 760       |
# |    iterations         | 7400      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.252    |
# |    explained_variance | 0.209     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -0.000133 |
# |    value_loss         | 1.98e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 7500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | -51.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.00183  |
# |    value_loss         | 5.99e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 7600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.257   |
# |    explained_variance | -6.37    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.00172 |
# |    value_loss         | 1.52e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 759      |
# |    iterations         | 7700     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | -14.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.000242 |
# |    value_loss         | 4.09e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 758       |
# |    iterations         | 7800      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -0.0946   |
# |    explained_variance | -31.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# ...
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 753      |
# |    iterations         | 17800    |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.719   |
# |    explained_variance | -167     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 6.71e-05 |
# |    value_loss         | 2.27e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 754      |
# |    iterations         | 17900    |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.789   |
# |    explained_variance | -17      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 0.00431  |
# |    value_loss         | 1.09e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 754       |
# |    iterations         | 18000     |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -0.662    |
# |    explained_variance | -18.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -0.000494 |
# |    value_loss         | 9.72e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 755      |
# |    iterations         | 18100    |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.849   |
# |    explained_variance | -6.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.00108  |
# |    value_loss         | 5.32e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 755      |
# |    iterations         | 18200    |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.902   |
# |    explained_variance | -13.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | 0.000282 |
# |    value_loss         | 1.39e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 756      |
# |    iterations         | 18300    |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.523   |
# |    explained_variance | -6.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 0.000519 |
# |    value_loss         | 1.71e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 757      |
# |    iterations         | 18400    |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.606   |
# |    explained_variance | -10.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 0.000572 |
# |    value_loss         | 3.71e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 757       |
# |    iterations         | 18500     |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.887    |
# |    explained_variance | -33       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -0.000607 |
# |    value_loss         | 1.43e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 758      |
# |    iterations         | 18600    |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.895   |
# |    explained_variance | -419     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.00109  |
# |    value_loss         | 8.05e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 758       |
# |    iterations         | 18700     |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -0.887    |
# |    explained_variance | -86.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -0.000214 |
# |    value_loss         | 1.06e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 759       |
# |    iterations         | 18800     |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -0.841    |
# |    explained_variance | 0.614     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -0.000595 |
# |    value_loss         | 2.34e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 760      |
# |    iterations         | 18900    |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.777   |
# |    explained_variance | 0.0528   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.00125  |
# |    value_loss         | 2.39e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 760      |
# |    iterations         | 19000    |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.942   |
# |    explained_variance | -811     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | 0.000223 |
# |    value_loss         | 5.42e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 760      |
# |    iterations         | 19100    |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.464   |
# |    explained_variance | -162     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.000413 |
# |    value_loss         | 8.49e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 761       |
# |    iterations         | 19200     |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.409    |
# |    explained_variance | -8.43     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -0.000559 |
# |    value_loss         | 1.74e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 762      |
# |    iterations         | 19300    |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.386   |
# |    explained_variance | -2.7e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 1.77e-06 |
# |    value_loss         | 1.58e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 762      |
# |    iterations         | 19400    |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.38    |
# |    explained_variance | -19      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 9.79e-05 |
# |    value_loss         | 8.41e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 763       |
# |    iterations         | 19500     |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.27     |
# |    explained_variance | -4.54e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -6.68e-05 |
# |    value_loss         | 1.12e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 19600    |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.28    |
# |    explained_variance | -10      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 9.01e-05 |
# |    value_loss         | 2e-06    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 764       |
# |    iterations         | 19700     |
# |    time_elapsed       | 128       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.258    |
# |    explained_variance | -6.52     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -6.17e-05 |
# |    value_loss         | 1.12e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -7.93     |
# | time/                 |           |
# |    fps                | 764       |
# |    iterations         | 19800     |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.403    |
# |    explained_variance | -16.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -6.18e-05 |
# |    value_loss         | 4.04e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 19900    |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.223   |
# |    explained_variance | -6.77    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 0.000185 |
# |    value_loss         | 3.99e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -7.93    |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 20000    |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | -13.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 1.08e-05 |
# |    value_loss         | 1.34e-07 |
# ------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.0575051769392303
# Cumulative Return: 0.00010575051769392303
# Win Rate: 0.5714285714285714
# Profit Factor: 7.617255194260692
# Sharpe Ratio: 0.657874986917901
# Sortino Ratio: 4.097583948117928
# Maximum Drawdown: 0.10047512684607085
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.7121569110895507
# Cumulative Return: 0.00017121569110895506
# Win Rate: 0.5637254901960784
# Profit Factor: 1.2056131918591555
# Sharpe Ratio: 0.06253620880383483
# Sortino Ratio: 0.09948509887226493
# Maximum Drawdown: 1.1381622252687673
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'NVDA_TRAINING.csv'
    test_file = 'NVDA_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1696 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1339        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007874569 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -17         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1277       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00705444 |
# |    clip_fraction        | 0.0424     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -6.81      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0155    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00675   |
# |    value_loss           | 0.00373    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | -0.266       |
# | time/                   |              |
# |    fps                  | 1234         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0062105414 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0146      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 0.00201      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | -0.266      |
# | time/                   |             |
# |    fps                  | 1220        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004955747 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0098     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 0.00595     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | -0.266       |
# | time/                   |              |
# |    fps                  | 1212         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0059867967 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.885       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00597      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00655     |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | -0.266      |
# | time/                   |             |
# |    fps                  | 1209        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008441354 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -2.19       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00539    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 0.129        |
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0069347518 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00315     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00893     |
# |    value_loss           | 0.00163      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 0.129        |
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0074826023 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00184      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00976     |
# |    value_loss           | 0.00342      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 0.129       |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009138569 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.67       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00986    |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 0.129        |
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0060199364 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.216       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0214      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00906     |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 1.13         |
# | time/                   |              |
# |    fps                  | 1122         |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0067380806 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00322     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 0.00134      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 13          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007492232 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00676    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00547     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008449885 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.000989    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008666325 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -0.0972     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 0.000827    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.23         |
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0063558742 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0205      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00807     |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 2.23         |
# | time/                   |              |
# |    fps                  | 1072         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0074686995 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.0357       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00978     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0095      |
# |    value_loss           | 0.00485      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.23        |
# | time/                   |             |
# |    fps                  | 1066        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008387763 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 0.00119     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 2.23        |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 19          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007851956 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.953      |
# |    explained_variance   | -0.0277     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.71        |
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 20          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007973216 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0031     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.71        |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 21          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013371274 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -0.431      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 3.71        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 22          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009372881 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | -0.547      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 0.00086     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.93e+03     |
# |    ep_rew_mean          | 3.71         |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 23           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0056558987 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.0378       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0275      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00799     |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 5.4         |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011966708 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 0.00402     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93e+03    |
# |    ep_rew_mean          | 5.4         |
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 25          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008707606 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00399     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 0.00394     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -1.06    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1130     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 31732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61e-05 |
# |    n_updates        | 7907     |
# ----------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 877       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -2.96e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0891    |
# |    value_loss         | 0.0127    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 875       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -3.06e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 0.00498   |
# |    value_loss         | 0.00132   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 872      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -28.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.00862  |
# |    value_loss         | 0.00227  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 873       |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.961    |
# |    explained_variance | -1.33e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.004     |
# |    value_loss         | 0.00027   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 873      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.851   |
# |    explained_variance | -398     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.063    |
# |    value_loss         | 0.00791  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 872      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.976   |
# |    explained_variance | 0.831    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0182   |
# |    value_loss         | 0.000545 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 872      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.89    |
# |    explained_variance | 0.693    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0224  |
# |    value_loss         | 0.000308 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 869      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.902   |
# |    explained_variance | -35      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.00813  |
# |    value_loss         | 0.00013  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.974   |
# |    explained_variance | -1.63    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.00132  |
# |    value_loss         | 0.00221  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -12.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0182  |
# |    value_loss         | 0.000611 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 1100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -16.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0645   |
# |    value_loss         | 0.00616  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.383   |
# |    explained_variance | -45.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00166  |
# |    value_loss         | 0.000369 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.194   |
# |    explained_variance | -50.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.000664 |
# |    value_loss         | 0.00035  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 1400      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.195    |
# |    explained_variance | -3.16     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.000194 |
# |    value_loss         | 2.87e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 863       |
# |    iterations         | 1500      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.206    |
# |    explained_variance | -17       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.000404 |
# |    value_loss         | 0.000111  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.438    |
# | time/                 |           |
# |    fps                | 861       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.759    |
# |    explained_variance | -5.51e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.000218 |
# |    value_loss         | 2.45e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -222     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00383 |
# |    value_loss         | 0.000768 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 1800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.52    |
# |    explained_variance | -47.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.000256 |
# |    value_loss         | 1.14e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 1900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.622   |
# |    explained_variance | -92.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0233  |
# |    value_loss         | 0.0017   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 2000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.871   |
# |    explained_variance | -34      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00666 |
# |    value_loss         | 7e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 2100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.804   |
# |    explained_variance | -2.89    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00418 |
# |    value_loss         | 0.000262 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 2200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.896   |
# |    explained_variance | -701     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0856  |
# |    value_loss         | 0.0144   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 2300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.864   |
# |    explained_variance | -17.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00204 |
# |    value_loss         | 9.94e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 2400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.844   |
# |    explained_variance | -3.56    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0107  |
# |    value_loss         | 0.000192 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 2500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | -157     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00241  |
# |    value_loss         | 0.000236 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 2600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -63      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0226   |
# |    value_loss         | 0.00158  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 865      |
# |    iterations         | 2700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -0.906   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.125   |
# |    value_loss         | 0.0154   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 865      |
# |    iterations         | 2800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | -143     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00485  |
# |    value_loss         | 0.00018  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 865      |
# |    iterations         | 2900     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.732   |
# |    explained_variance | -2.55    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00214  |
# |    value_loss         | 1.34e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 865      |
# |    iterations         | 3000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.76    |
# |    explained_variance | -38.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00024 |
# |    value_loss         | 6.7e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.438    |
# | time/                 |           |
# |    fps                | 865       |
# |    iterations         | 3100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.706    |
# |    explained_variance | -23.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -0.000635 |
# |    value_loss         | 3.68e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.203    |
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 3200      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.256    |
# |    explained_variance | -4.67     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -9.58e-05 |
# |    value_loss         | 4.12e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 866      |
# |    iterations         | 3300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.317   |
# |    explained_variance | 0.226    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0222  |
# |    value_loss         | 0.000247 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.203    |
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 3400      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.633    |
# |    explained_variance | -3.54     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.000484 |
# |    value_loss         | 1.13e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 3500     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.867   |
# |    explained_variance | -136     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0336   |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 3600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.739   |
# |    explained_variance | -24.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00012 |
# |    value_loss         | 1.21e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.203    |
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 3700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.929    |
# |    explained_variance | -664      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -2.64e-05 |
# |    value_loss         | 4.43e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 3800     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.928   |
# |    explained_variance | -36.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0196  |
# |    value_loss         | 0.000585 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 3900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | -2.75    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00161  |
# |    value_loss         | 4.81e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 4000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.655   |
# |    explained_variance | 0.107    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00121 |
# |    value_loss         | 5.61e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 4100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -0.463   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0079  |
# |    value_loss         | 0.000216 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 4200     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -59.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0357  |
# |    value_loss         | 0.00131  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 4300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | 0.0487   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.134   |
# |    value_loss         | 0.009    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 4400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 22000    |
# ...
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 8e-05    |
# |    value_loss         | 1.2e-08  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.248   |
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 7700     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.272   |
# |    explained_variance | 0.288    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 2.01e-05 |
# |    value_loss         | 6.34e-10 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.248   |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 7800     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.439   |
# |    explained_variance | -418     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 1.53e-06 |
# |    value_loss         | 2.49e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.248   |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 7900     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.512   |
# |    explained_variance | -0.00649 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.00199  |
# |    value_loss         | 5.33e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 938       |
# |    iterations         | 8000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.0567   |
# |    explained_variance | -7.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -2.11e-07 |
# |    value_loss         | 5.84e-09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 8100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.0617  |
# |    explained_variance | 0.00829  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.037   |
# |    value_loss         | 0.000887 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 8200     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | -0.0372  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 3.38e-05 |
# |    value_loss         | 1.86e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 8300     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.0164   |
# |    value_loss         | 0.0005   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 8400      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -0.571    |
# |    explained_variance | -0.261    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -9.01e-06 |
# |    value_loss         | 2.59e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 8500     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.846   |
# |    explained_variance | 0.119    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.0244   |
# |    value_loss         | 0.00229  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 8600     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.715   |
# |    explained_variance | -0.132   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.00775 |
# |    value_loss         | 0.000153 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 8700     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.742   |
# |    explained_variance | -1.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 0.00109  |
# |    value_loss         | 1.12e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 8800      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.791    |
# |    explained_variance | -499      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.000931 |
# |    value_loss         | 3.25e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 8900      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.648    |
# |    explained_variance | -0.175    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.000909 |
# |    value_loss         | 8.98e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 9000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.738   |
# |    explained_variance | 0.25     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 0.00844  |
# |    value_loss         | 0.000156 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 9100     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -0.159   |
# |    explained_variance | 0.0801   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 0.00014  |
# |    value_loss         | 2.43e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 937       |
# |    iterations         | 9200      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -0.203    |
# |    explained_variance | -0.139    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | -5.55e-05 |
# |    value_loss         | 2.14e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 9300     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | 0.249    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 1.38e-05 |
# |    value_loss         | 1.58e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.93e+03  |
# |    ep_rew_mean        | -0.376    |
# | time/                 |           |
# |    fps                | 939       |
# |    iterations         | 9400      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -0.25     |
# |    explained_variance | 0.284     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | -1.51e-05 |
# |    value_loss         | 8.9e-08   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.376   |
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 9500     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -0.0856  |
# |    explained_variance | 0.118    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | 2.87e-06 |
# |    value_loss         | 3.96e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.459   |
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 9600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.631   |
# |    explained_variance | 0.0975   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | 0.000468 |
# |    value_loss         | 8.26e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.459   |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 9700     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.00466  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | -0.00523 |
# |    value_loss         | 0.000141 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.459   |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 9800     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | -0.0787  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 0.00352  |
# |    value_loss         | 4.13e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.459   |
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 9900     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -0.463   |
# |    explained_variance | 0.0165   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | 0.0106   |
# |    value_loss         | 0.000301 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.93e+03 |
# |    ep_rew_mean        | -0.459   |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 10000    |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.481   |
# |    explained_variance | 0.607    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | 0.014    |
# |    value_loss         | 4.76e-05 |
# ------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.38849700684615146
# Cumulative Return: 3.8849700684615154e-05
# Win Rate: 0.5433587761326552
# Profit Factor: 1.17339367439718
# Sharpe Ratio: 0.05163679654841415
# Sortino Ratio: 0.08443211305653786
# Maximum Drawdown: 0.3444980580451527
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 14.64876878960925
# Cumulative Return: 0.0014648768789609248
# Win Rate: 0.6357773705483689
# Profit Factor: 3.7420807575578285
# Sharpe Ratio: 0.3618540044878247
# Sortino Ratio: 1.1252448479009642
# Maximum Drawdown: 0.321387351803533
